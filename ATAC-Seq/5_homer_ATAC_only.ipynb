# %%
import subprocess
import glob
import os
from os.path import exists
import re
import pandas as pd
from multiprocessing import Pool

# %%
def process_csv_to_bed(input_csv, output_directory):
    # Ensure the output directory exists
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # Load the CSV into a pandas DataFrame
    df = pd.read_csv(input_csv)

    # Derive the base filename without extension
    base_filename = os.path.splitext(os.path.basename(input_csv))[0]

    # Filter rows based on the conditions
    upregulated = df[(df['Fold'] > 1) & (df['FDR'] < 0.05)]
    downregulated = df[(df['Fold'] < -1) & (df['FDR'] < 0.05)]

    # Select the required columns and save to BED format
    upregulated_bed = os.path.join(output_directory, f"{base_filename}_Up.bed")
    downregulated_bed = os.path.join(output_directory, f"{base_filename}_Down.bed")

    upregulated[['seqnames', 'start', 'end', 'width', 'strand']].to_csv(upregulated_bed, sep='\t', header=False, index=False)
    downregulated[['seqnames', 'start', 'end', 'width', 'strand']].to_csv(downregulated_bed, sep='\t', header=False, index=False)
    print(f"Generated {upregulated_bed} and {downregulated_bed}\n")

# Execute the function for both CSV files
csv_directory = "/media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7"
DM1_DM2d_dir =  os.path.join(csv_directory,  "motif_DiffPeakAnno_DM1_DM2d")
DM6_DM7_dir =   os.path.join(csv_directory,  "motif_DiffPeakAnno_DM6_DM7")


process_csv_to_bed(os.path.join(csv_directory, "DiffPeakAnno_DM1_DM2d.csv"), DM1_DM2d_dir)
process_csv_to_bed(os.path.join(csv_directory, "DiffPeakAnno_DM6_DM7.csv"), DM6_DM7_dir)
# Out:
# Generated /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Up.bed and /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Down.bed
#
# Generated /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Up.bed and /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Down.bed

# %% [markdown]
# ### the bed file of peaks from Chipseeker

# %% [markdown]
# ## compare enriched genes vs random background

# %%
import os
import subprocess
from multiprocessing import Pool

def find_motifs_task(bed_file):
    motif_directory = os.path.dirname(bed_file)
    output_folder = os.path.splitext(os.path.basename(bed_file))[0]
    output_path = os.path.join(motif_directory, output_folder)

    # Create the output directory if it doesn't exist
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    # Run the HOMER command
    cmd = [
        "findMotifsGenome.pl",
        bed_file,
        os.path.join('/media/HDD2/Genomes/Ath_Ensembl56', 'Arabidopsis_thaliana.TAIR10.dna.toplevel.fa'),
        output_path,
        "-p", "20",
        "-mset", "plants"
    ]
    result = subprocess.run(cmd, capture_output=True, text=True)

    # Append both stderr and stdout to the log file
    with open(os.path.join(motif_directory, "HOMER.log"), "a") as log_file:
        log_file.write(result.stdout)
        log_file.write(result.stderr)

def run_find_motifs(directories):
    # Gather all bed files from the provided directories
    bed_files = []
    for directory in directories:
        bed_files.extend([os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.bed')])

    # Use Pool to run the tasks in parallel
    with Pool(4) as p:
        p.map(find_motifs_task, bed_files)



directories_to_search = [
   DM1_DM2d_dir,
   DM6_DM7_dir ]

run_find_motifs(directories_to_search)

# %% [markdown]
# ## compare enriched up vs down regulated genes

# %%
DM1_DM2d_beds = glob.glob( os.path.join(
    DM1_DM2d_dir,
    '*.bed'))
DM6_DM7_beds = glob.glob( os.path.join(
    DM6_DM7_dir,
    '*.bed'))

# %%
DM1_DM2d_beds
# Out:
# ['/media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Down.bed',
#  '/media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Up.bed']

# %%
DM6_DM7_beds
# Out:
# ['/media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Up.bed',
#  '/media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Down.bed']

# %%
def find_motifs_task_with_bg(bed_file, background_file, genome_path, species='plants'):
    motif_directory = os.path.dirname(bed_file)
    output_folder = os.path.splitext(os.path.basename(bed_file))[0] + '_vs_' + os.path.splitext(os.path.basename(background_file))[0]
    output_path = os.path.join(motif_directory, output_folder)

    # Create the output directory if it doesn't exist
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    # Run the HOMER command with background BED
    cmd = [
        "findMotifsGenome.pl",
        bed_file,
        genome_path,
        output_path,
        "-bg", background_file,
        "-p", "20",
        "-mset", species,
    ]
    result = subprocess.run(cmd, capture_output=True, text=True)
    print(result.stdout)
    if result.stderr:
        print(result.stderr)

genome_fa = '/media/HDD2/Genomes/Ath_Ensembl56/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa'

# %%
# Run motif analysis for up-regulated regions using down-regulated as background
find_motifs_task_with_bg(
    os.path.join(DM1_DM2d_dir, 'DiffPeakAnno_' + 'DM1_DM2d' + '_Up.bed'),
    os.path.join(DM1_DM2d_dir, 'DiffPeakAnno_' + 'DM1_DM2d' + '_Down.bed'),
                     genome_fa)

# Run motif analysis for down-regulated regions using up-regulated as background
find_motifs_task_with_bg(
    os.path.join(DM1_DM2d_dir, 'DiffPeakAnno_' + 'DM1_DM2d' + '_Down.bed'),
    os.path.join(DM1_DM2d_dir, 'DiffPeakAnno_' + 'DM1_DM2d' + '_Up.bed'),
                 genome_fa)
# Out:
# 	Position file = /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Up.bed
# 	Genome = /media/HDD2/Genomes/Ath_Ensembl56/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa
# 	Output Directory = /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Up_vs_DiffPeakAnno_DM1_DM2d_Down
# 	background position file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Down.bed
# 	Using 20 CPUs
# 	Using Custom Genome
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 237
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 237
# 		Redundant Peak IDs: 29
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Redunant Peaks found: Remove or rename these or some programs may have trouble...
#
# 	29 duplicate peak IDs out of 237 total peaks
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 1704
# 		peakfile formatted lines: 0
# 	822 duplicate peak IDs out of 1704 total peaks
# 	Max distance to merge: 200 bp
# 	Calculating co-bound peaks relative to reference: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Up_vs_DiffPeakAnno_DM1_DM2d_Down/bg.clean.pos
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 	**	/media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Up_vs_DiffPeakAnno_DM1_DM2d_Down/target.clean..pos	0	0.00	0.08
#
# 	**	Pairwise stats are approx with fixed distance (-d 200) and -cobound #
# 		They get worse as the size increases and peaks from a single file start overlapping
# 		To get accurate ones, adjust peak sizes first with adjustPeakFile.pl and
# 		then rerun mergePeaks with the "-d given" option (only applies to -cobound #)
#
# 	Co-bound by 0 peaks: 1704
# 	Co-bound by 1 peaks: 0 (max: 0 effective total)
# 	Custom genome sequence file: /media/HDD2/Genomes/Ath_Ensembl56/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa
#
# 	Extracting sequences from file: /media/HDD2/Genomes/Ath_Ensembl56/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa
# 	Looking for peak sequences in a single file (/media/HDD2/Genomes/Ath_Ensembl56/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa)
# 	Extracting 460 sequences from 1
# 	Extracting 385 sequences from 2
# 	Extracting 391 sequences from 3
# 	Extracting 299 sequences from 4
# 	Extracting 406 sequences from 5
#
# 	Not removing redundant sequences
#
#
# 	Sequences processed:
# 		Auto detected maximum sequence length of 201 bp
# 		1941 total
#
# 	Frequency Bins: 0.2 0.25 0.3 0.35 0.4 0.45 0.5 0.6 0.7 0.8
# 	Freq	Bin	Count
# 	0.25	1	30
# 	0.3	2	330
# 	0.35	3	668
# 	0.4	4	551
# 	0.45	5	229
# 	0.5	6	103
# 	0.6	7	29
# 	0.7	8	1
# 	Bin	# Targets	# Background	Background Weight
# 	1	5	25	1.326
# 	2	77	253	2.017
# 	3	121	547	1.466
# 	4	29	522	0.368
# 	5	5	224	0.148
# 	Normalizing lower order oligos using homer2
#
# 	Reading input files...
# 	1808 total sequences read
# 	Autonormalization: 1-mers (4 total)
# 		A	34.16%	34.09%	1.002
# 		C	15.84%	15.91%	0.995
# 		G	15.84%	15.91%	0.995
# 		T	34.16%	34.09%	1.002
# 	Autonormalization: 2-mers (16 total)
# 		AA	12.64%	12.56%	1.007
# 		CA	5.97%	6.34%	0.942
# 		GA	5.64%	5.57%	1.014
# 		TA	9.90%	9.62%	1.029
# 		AC	5.62%	5.34%	1.052
# 		CC	2.43%	2.86%	0.850
# 		GC	2.14%	2.14%	1.001
# 		TC	5.64%	5.57%	1.014
# 		AG	5.14%	4.97%	1.035
# 		CG	2.29%	1.74%	1.316
# 		GG	2.43%	2.86%	0.850
# 		TG	5.97%	6.34%	0.942
# 		AT	10.75%	11.22%	0.958
# 		CT	5.14%	4.97%	1.035
# 		GT	5.62%	5.34%	1.052
# 		TT	12.64%	12.56%	1.007
# 	Autonormalization: 3-mers (64 total)
# 	Normalization weights can be found in file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Up_vs_DiffPeakAnno_DM1_DM2d_Down/seq.autonorm.tsv
# 	Converging on autonormalization solution:
# 	...............................................................................
# 	Final normalization:	Autonormalization: 1-mers (4 total)
# 		A	34.16%	33.97%	1.006
# 		C	15.84%	16.03%	0.988
# 		G	15.84%	16.03%	0.988
# 		T	34.16%	33.97%	1.006
# 	Autonormalization: 2-mers (16 total)
# 		AA	12.64%	12.50%	1.011
# 		CA	5.97%	6.13%	0.974
# 		GA	5.64%	5.61%	1.006
# 		TA	9.90%	9.72%	1.019
# 		AC	5.62%	5.57%	1.010
# 		CC	2.43%	2.65%	0.917
# 		GC	2.14%	2.19%	0.979
# 		TC	5.64%	5.61%	1.006
# 		AG	5.14%	5.08%	1.012
# 		CG	2.29%	2.16%	1.062
# 		GG	2.43%	2.65%	0.917
# 		TG	5.97%	6.13%	0.974
# 		AT	10.75%	10.83%	0.993
# 		CT	5.14%	5.08%	1.012
# 		GT	5.62%	5.57%	1.010
# 		TT	12.64%	12.50%	1.011
# 	Autonormalization: 3-mers (64 total)
# 	Finished preparing sequence/group files
#
# 	----------------------------------------------------------
# 	Known motif enrichment
#
# 	Reading input files...
# 	1808 total sequences read
# 	506 motifs loaded
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 506 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Preparing HTML output with sequence logos...
# 		1 of 506 (1e-30) WRKY28(WRKY)/col-WRKY28-DAP-Seq(GSE60143)/Homer
# 		2 of 506 (1e-28) WRKY29(WRKY)/colamp-WRKY29-DAP-Seq(GSE60143)/Homer
# 		3 of 506 (1e-28) WRKY25(WRKY)/colamp-WRKY25-DAP-Seq(GSE60143)/Homer
# 		4 of 506 (1e-28) WRKY18(WRKY)/col-WRKY18-DAP-Seq(GSE60143)/Homer
# 		5 of 506 (1e-27) WRKY14(WRKY)/colamp-WRKY14-DAP-Seq(GSE60143)/Homer
# 		6 of 506 (1e-27) WRKY24(WRKY)/colamp-WRKY24-DAP-Seq(GSE60143)/Homer
# 		7 of 506 (1e-27) WRKY50(WRKY)/col-WRKY50-DAP-Seq(GSE60143)/Homer
# 		8 of 506 (1e-26) WRKY75(WRKY)/col-WRKY75-DAP-Seq(GSE60143)/Homer
# 		9 of 506 (1e-25) WRKY55(WRKY)/col-WRKY55-DAP-Seq(GSE60143)/Homer
# 		10 of 506 (1e-25) WRKY15(WRKY)/col-WRKY15-DAP-Seq(GSE60143)/Homer
# 		11 of 506 (1e-24) WRKY40(WRKY)/colamp-WRKY40-DAP-Seq(GSE60143)/Homer
# 		12 of 506 (1e-23) WRKY27(WRKY)/colamp-WRKY27-DAP-Seq(GSE60143)/Homer
# 		13 of 506 (1e-22) WRKY71(WRKY)/col-WRKY71-DAP-Seq(GSE60143)/Homer
# 		14 of 506 (1e-22) WRKY6(WRKY)/colamp-WRKY6-DAP-Seq(GSE60143)/Homer
# 		15 of 506 (1e-21) WRKY33(WRKY)/col-WRKY33-DAP-Seq(GSE60143)/Homer
# 		16 of 506 (1e-21) WRKY45(WRKY)/col-WRKY45-DAP-Seq(GSE60143)/Homer
# 		17 of 506 (1e-21) WRKY65(WRKY)/colamp-WRKY65-DAP-Seq(GSE60143)/Homer
# 		18 of 506 (1e-18) WRKY31(WRKY)/colamp-WRKY31-DAP-Seq(GSE60143)/Homer
# 		19 of 506 (1e-16) WRKY20(WRKY)/col-WRKY20-DAP-Seq(GSE60143)/Homer
# 		20 of 506 (1e-16) WRKY22(WRKY)/colamp-WRKY22-DAP-Seq(GSE60143)/Homer
# 		21 of 506 (1e-14) WRKY3(WRKY)/col-WRKY3-DAP-Seq(GSE60143)/Homer
# 		22 of 506 (1e-13) WRKY43(WRKY)/colamp-WRKY43-DAP-Seq(GSE60143)/Homer
# 		23 of 506 (1e-13) WRKY26(WRKY)/colamp-WRKY26-DAP-Seq(GSE60143)/Homer
# 		24 of 506 (1e-12) CRF4(AP2EREBP)/colamp-CRF4-DAP-Seq(GSE60143)/Homer
# 		25 of 506 (1e-10) WRKY8(WRKY)/colamp-WRKY8-DAP-Seq(GSE60143)/Homer
# 		26 of 506 (1e-10) WRKY42(WRKY)/colamp-WRKY42-DAP-Seq(GSE60143)/Homer
# 		27 of 506 (1e-9) NAP(NAC)/col-NAP-DAP-Seq(GSE60143)/Homer
# 		28 of 506 (1e-9) ERF105(AP2EREBP)/colamp-ERF105-DAP-Seq(GSE60143)/Homer
# 		29 of 506 (1e-8) ANAC046(NAC)/colamp-ANAC046-DAP-Seq(GSE60143)/Homer
# 		30 of 506 (1e-7) ANAC047(NAC)/colamp-ANAC047-DAP-Seq(GSE60143)/Homer
# 		31 of 506 (1e-7) WRKY47(WRKY)/colamp-WRKY47-DAP-Seq(GSE60143)/Homer
# 		32 of 506 (1e-7) NAM(NAC)/col-NAM-DAP-Seq(GSE60143)/Homer
# 		33 of 506 (1e-7) ERF1(AP2EREBP)/colamp-ERF1-DAP-Seq(GSE60143)/Homer
# 		34 of 506 (1e-7) ERF2(AP2EREBP)/colamp-ERF2-DAP-Seq(GSE60143)/Homer
# 		35 of 506 (1e-6) ERF10(AP2EREBP)/col-ERF10-DAP-Seq(GSE60143)/Homer
# 		36 of 506 (1e-5) ERF5(AP2EREBP)/colamp-ERF5-DAP-Seq(GSE60143)/Homer
# 		37 of 506 (1e-5) ERF13(AP2EREBP)/colamp-ERF13-DAP-Seq(GSE60143)/Homer
# 		38 of 506 (1e-5) RAP212(AP2EREBP)/col-RAP212-DAP-Seq(GSE60143)/Homer
# 		39 of 506 (1e-5) WRKY30(WRKY)/colamp-WRKY30-DAP-Seq(GSE60143)/Homer
# 		40 of 506 (1e-5) ANAC038(NAC)/col-ANAC038-DAP-Seq(GSE60143)/Homer
# 		41 of 506 (1e-5) VND2(NAC)/col-VND2-DAP-Seq(GSE60143)/Homer
# 		42 of 506 (1e-5) ATAF1(NAC)/col-ATAF1-DAP-Seq(GSE60143)/Homer
# 		43 of 506 (1e-4) SMB(NAC)/colamp-SMB-DAP-Seq(GSE60143)/Homer
# 		44 of 506 (1e-4) WRKY21(WRKY)/colamp-WRKY21-DAP-Seq(GSE60143)/Homer
# 		45 of 506 (1e-4) MYB49(MYB)/col-MYB49-DAP-Seq(GSE60143)/Homer
# 		46 of 506 (1e-4) AT4G18450(AP2EREBP)/col-AT4G18450-DAP-Seq(GSE60143)/Homer
# 		47 of 506 (1e-4) ERF15(AP2EREBP)/colamp-ERF15-DAP-Seq(GSE60143)/Homer
# 		48 of 506 (1e-4) ANAC079(NAC)/colamp-ANAC079-DAP-Seq(GSE60143)/Homer
# 		49 of 506 (1e-4) ATHB34(ZFHD)/colamp-ATHB34-DAP-Seq(GSE60143)/Homer
# 		50 of 506 (1e-4) ABR1(AP2EREBP)/colamp-ABR1-DAP-Seq(GSE60143)/Homer
# 		51 of 506 (1e-4) WRKY11(WRKY)/col-WRKY11-DAP-Seq(GSE60143)/Homer
# 		52 of 506 (1e-3) ATHB23(ZFHD)/col-ATHB23-DAP-Seq(GSE60143)/Homer
# 		53 of 506 (1e-3) AT5G23930(mTERF)/col-AT5G23930-DAP-Seq(GSE60143)/Homer
# 		54 of 506 (1e-3) NTM2(NAC)/col-NTM2-DAP-Seq(GSE60143)/Homer
# 		55 of 506 (1e-3) VND1(NAC)/col-VND1-DAP-Seq(GSE60143)/Homer
# 		56 of 506 (1e-3) At2g33710(AP2EREBP)/colamp-At2g33710-DAP-Seq(GSE60143)/Homer
# 		57 of 506 (1e-3) CAMTA1(CAMTA)/col-CAMTA1-DAP-Seq(GSE60143)/Homer
# 		58 of 506 (1e-3) ERF3(AP2EREBP)/colamp-ERF3-DAP-Seq(GSE60143)/Homer
# 		59 of 506 (1e-3) ATHB24(ZFHD)/colamp-ATHB24-DAP-Seq(GSE60143)/Homer
# 		60 of 506 (1e-3) ATHB33(ZFHD)/col-ATHB33-DAP-Seq(GSE60143)/Homer
# 		61 of 506 (1e-3) ERF104(AP2EREBP)/col-ERF104-DAP-Seq(GSE60143)/Homer
# 		62 of 506 (1e-3) ATHB25(ZFHD)/colamp-ATHB25-DAP-Seq(GSE60143)/Homer
# 		63 of 506 (1e-3) ANAC004(NAC)/colamp-ANAC004-DAP-Seq(GSE60143)/Homer
# 		64 of 506 (1e-3) AT5G56840(MYBrelated)/colamp-AT5G56840-DAP-Seq(GSE60143)/Homer
# 		65 of 506 (1e-3) VND3(NAC)/colamp-VND3-DAP-Seq(GSE60143)/Homer
# 		66 of 506 (1e-3) VND6(NAC)/col-VND6-DAP-Seq(GSE60143)/Homer
# 		67 of 506 (1e-3) ANAC071(NAC)/col-ANAC071-DAP-Seq(GSE60143)/Homer
# 		68 of 506 (1e-3) At2g41835(C2H2)/col-At2g41835-DAP-Seq(GSE60143)/Homer
# 		69 of 506 (1e-3) At1g49010(MYBrelated)/col-At1g49010-DAP-Seq(GSE60143)/Homer
# 		70 of 506 (1e-2) ANAC096(NAC)/colamp-ANAC096-DAP-Seq(GSE60143)/Homer
# 		71 of 506 (1e-2) VND4(NAC)/colamp-VND4-DAP-Seq(GSE60143)/Homer
# 		72 of 506 (1e-2) MYB118(MYB)/colamp-MYB118-DAP-Seq(GSE60143)/Homer
# 		73 of 506 (1e-2) AT1G72740(MYBrelated)/colamp-AT1G72740-DAP-Seq(GSE60143)/Homer
# 		74 of 506 (1e-2) ERF4(AP2EREBP)/colamp-ERF4-DAP-Seq(GSE60143)/Homer
# 		75 of 506 (1e-2) At5g47390(MYBrelated)/col-At5g47390-DAP-Seq(GSE60143)/Homer
# 		76 of 506 (1e-2) RRTF1(AP2EREBP)/colamp-RRTF1-DAP-Seq(GSE60143)/Homer
# 		77 of 506 (1e-2) ANAC020(NAC)/col-ANAC020-DAP-Seq(GSE60143)/Homer
# 		78 of 506 (1e-2) AT3G42860(zfGRF)/col-AT3G42860-DAP-Seq(GSE60143)/Homer
# 		79 of 506 (1e-2) ANAC103(NAC)/col-ANAC103-DAP-Seq(GSE60143)/Homer
# 		80 of 506 (1e-2) ESE1(AP2EREBP)/col-ESE1-DAP-Seq(GSE60143)/Homer
# 		81 of 506 (1e-2) ERF11(AP2EREBP)/col-ERF11-DAP-Seq(GSE60143)/Homer
# 		82 of 506 (1e-2) SOL1(CPP)/colamp-SOL1-DAP-Seq(GSE60143)/Homer
# 		83 of 506 (1e-2) ANAC062(NAC)/colamp-ANAC062-DAP-Seq(GSE60143)/Homer
# 		84 of 506 (1e-2) WRKY46(WRKY)/colamp-WRKY46-DAP-Seq(GSE60143)/Homer
# 		85 of 506 (1e-2) ANAC045(NAC)/col-ANAC045-DAP-Seq(GSE60143)/Homer
# 		86 of 506 (1e-2) AT5G61620(MYBrelated)/colamp-AT5G61620-DAP-Seq(GSE60143)/Homer
# 		87 of 506 (1e-2) AT4G00250(GeBP)/col-AT4G00250-DAP-Seq(GSE60143)/Homer
# 		88 of 506 (1e-2) ANAC058(NAC)/col-ANAC058-DAP-Seq(GSE60143)/Homer
# 		89 of 506 (1e-2) ERF73(AP2EREBP)/col-ERF73-DAP-Seq(GSE60143)/Homer
# 		90 of 506 (1e-2) ANAC053(NAC)/colamp-ANAC053-DAP-Seq(GSE60143)/Homer
# 		91 of 506 (1e-2) ERF8(AP2EREBP)/colamp-ERF8-DAP-Seq(GSE60143)/Homer
# 		92 of 506 (1e-2) ERF7(AP2EREBP)/col-ERF7-DAP-Seq(GSE60143)/Homer
# 		93 of 506 (1e-2) SND2(NAC)/colamp-SND2-DAP-Seq(GSE60143)/Homer
# 		94 of 506 (1e-2) CUC1(NAC)/col-CUC1-DAP-Seq(GSE60143)/Homer
# 		95 of 506 (1e-2) MYB93(MYB)/colamp-MYB93-DAP-Seq(GSE60143)/Homer
# 	----------------------------------------------------------
# 	De novo motif finding (HOMER)
#
# 	Number of Trial motifs (-T) set to 20 (from 10) to work well with 20 CPUs
# 	Scanning input files...
# 	Parsing sequences...
# 	|0%                                   50%                                  100%|
# 	==================================================================================
# 	Total number of Oligos: 30690
# 	Autoadjustment for sequence coverage in background: 1.00x
#
# 	Oligos: 30690 of 34497 max
# 	Tree  : 63500 of 172485 max
# 	Optimizing memory usage...
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Global Optimization Phase: Looking for enriched oligos with up to 2 mismatches...
#
# 	Screening oligos 30690 (allowing 0 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		43.79% skipped, 56.21% checked (17250 of 30690), of those checked:
# 		43.79% not in target, 0.00% increased p-value, 0.00% high p-value
#
# 	Screening oligos 30690 (allowing 1 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		43.79% skipped, 56.21% checked (17250 of 30690), of those checked:
# 		0.00% not in target, 29.39% increased p-value, 27.08% high p-value
#
# 	Screening oligos 30690 (allowing 2 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		84.42% skipped, 15.58% checked (4781 of 30690), of those checked:
# 		0.00% not in target, 13.28% increased p-value, 0.00% high p-value
# 	Reading input files...
# 	1808 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Local Optimization Phase:
# 	1 of 25 Initial Sequence: GTTGACTT... (-36.196)
# 		Round 1: -66.83 GTTGACTT T:180.0(53.28%),B:303.9(19.97%),P:1e-29
# 		Round 2: -66.83 GTTGACTT T:180.0(53.28%),B:303.9(19.97%),P:1e-29
# 		=Final=: -75.73 GTTGACTT T:118.0(49.79%),B:217.7(16.00%),P:1e-32
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	2 of 25 Initial Sequence: ACGCCGCC... (-19.791)
# 		Round 1: -36.90 ACGCCGCC T:14.0(5.75%),B:3.5(0.22%),P:1e-16
# 		Round 2: -36.90 ACGCCGCC T:14.0(5.75%),B:3.5(0.22%),P:1e-16
# 		=Final=: -28.51 ACGCCGCC T:12.0(5.06%),B:3.5(0.26%),P:1e-12
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	3 of 25 Initial Sequence: TTTGACAA... (-18.440)
# 		Round 1: -40.40 TTTGACAA T:137.0(43.97%),B:289.9(19.14%),P:1e-17
# 		Round 2: -40.40 TTTGACAA T:137.0(43.97%),B:289.9(19.14%),P:1e-17
# 		=Final=: -34.93 TTTGACAA T:77.0(32.49%),B:169.6(12.47%),P:1e-15
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	4 of 25 Initial Sequence: ACGTAAGA... (-17.578)
# 		Round 1: -25.10 ACGTAAGA T:132.0(42.77%),B:353.6(22.86%),P:1e-10
# 		Round 2: -25.10 ACGTAAGA T:132.0(42.77%),B:353.6(22.86%),P:1e-10
# 		=Final=: -25.33 ACGTAAGA T:81.0(34.18%),B:220.4(16.21%),P:1e-11
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	5 of 25 Initial Sequence: ATTCAAAG... (-16.235)
# 		Round 1: -25.79 ATTCAAAG T:38.0(14.84%),B:52.4(3.75%),P:1e-11
# 		Round 2: -28.55 ATTCAACG T:34.0(13.39%),B:38.0(2.68%),P:1e-12
# 		Round 3: -28.55 ATTCAACG T:34.0(13.39%),B:38.0(2.68%),P:1e-12
# 		=Final=: -26.17 ATTCAACG T:30.0(12.66%),B:37.7(2.77%),P:1e-11
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	6 of 25 Initial Sequence: ACTAATTA... (-14.245)
# 		Round 1: -14.33 ACTAATTA T:28.0(11.17%),B:50.8(3.61%),P:1e-6
# 		Round 2: -16.23 ACTAATTA T:41.0(15.92%),B:85.0(5.99%),P:1e-7
# 		Round 3: -17.02 RCTAATTA T:40.0(15.56%),B:78.7(5.57%),P:1e-7
# 		Round 4: -19.32 RHTRMTTA T:44.0(16.98%),B:85.9(6.06%),P:1e-8
# 		Round 5: -19.32 RHTRMTTA T:44.0(16.98%),B:85.9(6.06%),P:1e-8
# 		=Final=: -17.34 RHTRMTTA T:38.0(16.03%),B:81.0(5.96%),P:1e-7
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	7 of 25 Initial Sequence: CATGGATA... (-13.708)
# 		Round 1: -13.71 CATGGATA T:6.0(2.51%),B:2.5(0.15%),P:1e-5
# 		Round 2: -13.71 CATGGATA T:6.0(2.51%),B:2.5(0.15%),P:1e-5
# 		=Final=: -13.26 CATGGATA T:6.0(2.53%),B:2.5(0.19%),P:1e-5
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	8 of 25 Initial Sequence: TTCCAACC... (-13.708)
# 		Round 1: -19.46 TTCCAACC T:9.0(3.73%),B:3.6(0.22%),P:1e-8
# 		Round 2: -19.46 TTCCAACC T:9.0(3.73%),B:3.6(0.22%),P:1e-8
# 		=Final=: -16.36 TTCCAACC T:8.0(3.38%),B:3.6(0.27%),P:1e-7
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	9 of 25 Initial Sequence: CGTGTGAA... (-13.708)
# 		Round 1: -13.71 CGTGTGAA T:6.0(2.51%),B:2.9(0.15%),P:1e-5
# 		Round 2: -13.71 CGTGTGAA T:6.0(2.51%),B:2.9(0.15%),P:1e-5
# 		=Final=: -10.38 CGTGTGAA T:5.0(2.11%),B:2.9(0.21%),P:1e-4
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	10 of 25 Initial Sequence: GTAGCGTA... (-12.314)
# 		Round 1: -37.92 GTAGCGTA T:29.0(11.54%),B:19.9(1.39%),P:1e-16
# 		Round 2: -37.92 GTAGCGTA T:29.0(11.54%),B:19.9(1.39%),P:1e-16
# 		=Final=: -31.27 GTAGCGTA T:24.0(10.13%),B:18.4(1.35%),P:1e-13
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	11 of 25 Initial Sequence: AAGTAACG... (-13.708)
# 		Round 1: -18.64 AAGTAACG T:20.0(8.11%),B:22.8(1.60%),P:1e-8
# 		Round 2: -18.64 AAGTAACG T:20.0(8.11%),B:22.8(1.60%),P:1e-8
# 		=Final=: -19.64 AAGTAACG T:20.0(8.44%),B:22.7(1.67%),P:1e-8
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	12 of 25 Initial Sequence: AGAAGTCT... (-12.084)
# 		Round 1: -20.67 AGAAGTCT T:40.0(15.56%),B:67.6(4.81%),P:1e-8
# 		Round 2: -20.67 AGAAGTCT T:40.0(15.56%),B:67.6(4.81%),P:1e-8
# 		=Final=: -23.32 AGAAGTCT T:38.0(16.03%),B:65.5(4.82%),P:1e-10
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	13 of 25 Initial Sequence: GGTAATCT... (-11.164)
# 		Round 1: -17.75 GGTAATCT T:131.0(42.53%),B:403.0(25.65%),P:1e-7
# 		Round 2: -17.75 GGTAATCT T:131.0(42.53%),B:403.0(25.65%),P:1e-7
# 		=Final=: -14.96 GGTAATCT T:108.0(45.57%),B:408.3(30.02%),P:1e-6
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	14 of 25 Initial Sequence: GACTATGT... (-10.329)
# 		Round 1: -14.21 GACTATGT T:9.0(3.73%),B:5.6(0.37%),P:1e-6
# 		Round 2: -17.27 GACTATGT T:7.0(2.92%),B:1.9(0.07%),P:1e-7
# 		Round 3: -17.27 GACTATGT T:7.0(2.92%),B:1.9(0.07%),P:1e-7
# 		=Final=: -17.27 GACTATGT T:6.0(2.53%),B:1.9(0.14%),P:1e-7
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	15 of 25 Initial Sequence: CGTTTAAA... (-10.329)
# 		Round 1: -10.33 CGTTTAAA T:5.0(2.09%),B:2.4(0.15%),P:1e-4
# 		Round 2: -10.33 CGTTTAAA T:5.0(2.09%),B:2.4(0.15%),P:1e-4
# 		=Final=: -10.38 CGTTTAAA T:5.0(2.11%),B:2.1(0.15%),P:1e-4
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	16 of 25 Initial Sequence: GTAAACGG... (-10.329)
# 		Round 1: -13.71 GTAAACGG T:6.0(2.51%),B:3.0(0.15%),P:1e-5
# 		Round 2: -13.71 GTAAACGG T:6.0(2.51%),B:3.0(0.15%),P:1e-5
# 		=Final=: -13.26 GTAAACGG T:6.0(2.53%),B:3.0(0.22%),P:1e-5
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	17 of 25 Initial Sequence: GAGGACTT... (-10.329)
# 		Round 1: -16.81 GAGGACTT T:10.0(4.14%),B:5.8(0.37%),P:1e-7
# 		Round 2: -24.85 GARGACTC T:9.0(3.73%),B:2.8(0.15%),P:1e-10
# 		Round 3: -24.85 GARGACTC T:9.0(3.73%),B:2.8(0.15%),P:1e-10
# 		=Final=: -22.74 GARGACTC T:9.0(3.80%),B:2.8(0.20%),P:1e-9
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	18 of 25 Initial Sequence: TCAGCCCT... (-9.635)
# 		Round 1: -19.34 TCAGCCCT T:15.0(6.15%),B:11.9(0.81%),P:1e-8
# 		Round 2: -19.34 TCAGCCCT T:15.0(6.15%),B:11.9(0.81%),P:1e-8
# 		=Final=: -18.16 TCAGCCCT T:14.0(5.91%),B:11.7(0.86%),P:1e-7
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	19 of 25 Initial Sequence: AGTTTTGA... (-9.292)
# 		Round 1: -14.01 AGTTTTGA T:36.0(14.12%),B:77.8(5.50%),P:1e-6
# 		Round 2: -14.01 AGTTTTGA T:36.0(14.12%),B:77.8(5.50%),P:1e-6
# 		=Final=: -16.45 AGTTTTGA T:32.0(13.50%),B:63.7(4.68%),P:1e-7
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	20 of 25 Initial Sequence: GAAACTTC... (-8.497)
# 		Round 1: -10.18 GAAACTTC T:9.0(3.73%),B:8.7(0.59%),P:1e-4
# 		Round 2: -11.02 GAAACTGC T:13.0(5.35%),B:17.0(1.17%),P:1e-4
# 		Round 3: -11.02 GAAACTGC T:13.0(5.35%),B:17.0(1.17%),P:1e-4
# 		=Final=: -10.40 GAAACTGC T:12.0(5.06%),B:17.0(1.25%),P:1e-4
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	Remaining seeds don't look promising (After initial 5 motifs, logp -8.369 > -8.375)
#
# 	Finalizing Enrichment Statistics (new in v3.4)
# 	Reading input files...
# 	1808 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 20 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Output in file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Up_vs_DiffPeakAnno_DM1_DM2d_Down/homerMotifs.motifs8
#
#
# 	Number of Trial motifs (-T) set to 20 (from 10) to work well with 20 CPUs
# 	Scanning input files...
# 	Parsing sequences...
# 	|0%                                   50%                                  100%|
# 	==================================================================================
# 	Total number of Oligos: 183159
# 	Autoadjustment for sequence coverage in background: 1.00x
#
# 	Oligos: 183159 of 347136 max
# 	Tree  : 432472 of 1735680 max
# 	Optimizing memory usage...
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Global Optimization Phase: Looking for enriched oligos with up to 2 mismatches...
#
# 	Screening oligos 183159 (allowing 0 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		78.98% skipped, 21.02% checked (38505 of 183159), of those checked:
# 		78.98% not in target, 0.00% increased p-value, 0.00% high p-value
#
# 	Screening oligos 183159 (allowing 1 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		78.98% skipped, 21.02% checked (38505 of 183159), of those checked:
# 		0.00% not in target, 15.38% increased p-value, 2.87% high p-value
#
# 	Screening oligos 183159 (allowing 2 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		94.97% skipped, 5.03% checked (9212 of 183159), of those checked:
# 		0.00% not in target, 3.44% increased p-value, 0.00% high p-value
# 	Reading input files...
# 	1808 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Local Optimization Phase:
# 	1 of 25 Initial Sequence: AGTTGACTTT... (-29.285)
# 		Round 1: -45.26 AGTTGACTTT T:107.0(36.39%),B:185.2(12.72%),P:1e-19
# 		Round 2: -45.75 AATTGACTTT T:14.0(5.75%),B:2.3(0.15%),P:1e-19
# 		Round 3: -45.75 AATTGACTTT T:14.0(5.75%),B:2.3(0.15%),P:1e-19
# 		=Final=: -40.65 AATTGACTTT T:14.0(5.91%),B:2.3(0.17%),P:1e-17
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	2 of 25 Initial Sequence: AAGTCTTCGT... (-26.089)
# 		Round 1: -40.07 AAGTCTTCGT T:71.0(25.93%),B:105.0(7.36%),P:1e-17
# 		Round 2: -42.33 AAGTCTTCGT T:47.0(18.02%),B:46.0(3.25%),P:1e-18
# 		Round 3: -42.33 AAGTCTTCGT T:47.0(18.02%),B:46.0(3.25%),P:1e-18
# 		=Final=: -29.56 AAGTCTTCGT T:34.0(14.35%),B:42.3(3.11%),P:1e-12
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	3 of 25 Initial Sequence: ACGTAACGTA... (-25.265)
# 		Round 1: -37.11 ACGTAACGTA T:107.0(36.39%),B:213.5(14.50%),P:1e-16
# 		Round 2: -37.11 ACGTAACGTA T:107.0(36.39%),B:213.5(14.50%),P:1e-16
# 		=Final=: -24.34 ACGTAACGTA T:83.0(35.02%),B:233.6(17.18%),P:1e-10
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	4 of 25 Initial Sequence: TAGTCAACTG... (-24.121)
# 		Round 1: -39.68 TAGTCAACTG T:58.0(21.75%),B:73.8(5.23%),P:1e-17
# 		Round 2: -42.63 TAGTCAACTG T:143.0(45.37%),B:295.8(19.50%),P:1e-18
# 		Round 3: -42.63 TAGTCAACTG T:143.0(45.37%),B:295.8(19.50%),P:1e-18
# 		=Final=: -51.81 TAGTCAACTG T:111.0(46.84%),B:252.6(18.58%),P:1e-22
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	5 of 25 Initial Sequence: CTGACTTGGT... (-17.272)
# 		Round 1: -28.83 CTGACTTGGT T:10.0(4.14%),B:1.6(0.07%),P:1e-12
# 		Round 2: -28.83 CTGACTTGGT T:10.0(4.14%),B:1.6(0.07%),P:1e-12
# 		=Final=: -28.83 CTGACTTGGT T:9.0(3.80%),B:1.6(0.11%),P:1e-12
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	6 of 25 Initial Sequence: AGTACGGATA... (-17.272)
# 		Round 1: -17.27 AGTACGGATA T:7.0(2.92%),B:2.5(0.15%),P:1e-7
# 		Round 2: -17.27 AGTACGGATA T:7.0(2.92%),B:2.5(0.15%),P:1e-7
# 		=Final=: -16.29 AGTACGGATA T:7.0(2.95%),B:2.5(0.19%),P:1e-7
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	7 of 25 Initial Sequence: AACGAGTTCT... (-17.272)
# 		Round 1: -25.21 AACGAGTTCT T:13.0(5.35%),B:5.2(0.37%),P:1e-10
# 		Round 2: -25.21 AACGAGTTCT T:13.0(5.35%),B:5.2(0.37%),P:1e-10
# 		=Final=: -25.44 AACGAGTTCT T:13.0(5.49%),B:5.2(0.38%),P:1e-11
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	8 of 25 Initial Sequence: TCTTGACTAT... (-16.123)
# 		Round 1: -23.87 TCTTGACTAT T:15.0(6.15%),B:8.0(0.59%),P:1e-10
# 		Round 2: -25.33 TCTTGACTAT T:12.0(4.95%),B:4.9(0.29%),P:1e-11
# 		Round 3: -25.33 TCTTGACTAT T:12.0(4.95%),B:4.9(0.29%),P:1e-11
# 		=Final=: -22.24 TCTTGACTAT T:10.0(4.22%),B:3.4(0.25%),P:1e-9
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	9 of 25 Initial Sequence: GTCAATCTTA... (-16.123)
# 		Round 1: -32.92 GTCAATCTTA T:11.0(4.54%),B:2.4(0.15%),P:1e-14
# 		Round 2: -37.11 GTCAATCTTA T:12.0(4.95%),B:2.9(0.15%),P:1e-16
# 		Round 3: -37.11 GTCAATCTTA T:12.0(4.95%),B:2.9(0.15%),P:1e-16
# 		=Final=: -33.22 GTCAATCTTA T:12.0(5.06%),B:2.9(0.22%),P:1e-14
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	10 of 25 Initial Sequence: GTCTTACTTG... (-14.948)
# 		Round 1: -24.85 GTCTTACTTG T:9.0(3.73%),B:0.5(0.00%),P:1e-10
# 		Round 2: -24.85 GTCTTACTTG T:9.0(3.73%),B:0.5(0.00%),P:1e-10
# 		=Final=: -28.83 GTCTTACTTG T:9.0(3.80%),B:0.5(0.04%),P:1e-12
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	11 of 25 Initial Sequence: TTCTTACGTT... (-14.942)
# 		Round 1: -21.37 TTCTTACGTT T:14.0(5.75%),B:8.8(0.59%),P:1e-9
# 		Round 2: -21.37 TTCTTACGTT T:14.0(5.75%),B:8.8(0.59%),P:1e-9
# 		=Final=: -22.16 TTCTTACGTT T:14.0(5.91%),B:8.8(0.65%),P:1e-9
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	12 of 25 Initial Sequence: CATTTTGAAA... (-13.708)
# 		Round 1: -30.33 CATTTTGAAA T:19.0(7.72%),B:10.5(0.73%),P:1e-13
# 		Round 2: -32.92 CATTTTGAAA T:11.0(4.54%),B:1.8(0.07%),P:1e-14
# 		Round 3: -32.92 CATTTTGAAA T:11.0(4.54%),B:1.8(0.07%),P:1e-14
# 		=Final=: -37.11 CATTTTGAAA T:11.0(4.64%),B:1.8(0.13%),P:1e-16
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	13 of 25 Initial Sequence: AAATTATATG... (-13.708)
# 		Round 1: -19.46 AAATTATATG T:9.0(3.73%),B:3.8(0.22%),P:1e-8
# 		Round 2: -19.46 AAATTATATG T:9.0(3.73%),B:3.8(0.22%),P:1e-8
# 		=Final=: -19.24 AAATTATATG T:9.0(3.80%),B:3.8(0.28%),P:1e-8
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	14 of 25 Initial Sequence: GACTACTCTC... (-13.708)
# 		Round 1: -13.71 GACTACTCTC T:6.0(2.51%),B:2.2(0.15%),P:1e-5
# 		Round 2: -13.71 GACTACTCTC T:6.0(2.51%),B:2.2(0.15%),P:1e-5
# 		=Final=: -13.26 GACTACTCTC T:6.0(2.53%),B:2.1(0.16%),P:1e-5
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	15 of 25 Initial Sequence: TAAGAGCGAA... (-13.597)
# 		Round 1: -20.99 TAAGAGCGAA T:8.0(3.33%),B:2.0(0.15%),P:1e-9
# 		Round 2: -20.99 TAAGAGCGAA T:8.0(3.33%),B:2.0(0.15%),P:1e-9
# 		=Final=: -19.46 TAAGAGCGAA T:8.0(3.38%),B:2.0(0.15%),P:1e-8
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	16 of 25 Initial Sequence: TTAAACGCGT... (-13.597)
# 		Round 1: -19.06 TTAAACGCGT T:17.0(6.94%),B:15.5(1.10%),P:1e-8
# 		Round 2: -19.06 TTAAACGCGT T:17.0(6.94%),B:15.5(1.10%),P:1e-8
# 		=Final=: -19.12 TTAAACGCGT T:15.0(6.33%),B:12.4(0.91%),P:1e-8
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	17 of 25 Initial Sequence: GGTTTGAAAA... (-13.301)
# 		Round 1: -27.10 GGTTTGAAAA T:17.0(6.94%),B:9.4(0.66%),P:1e-11
# 		Round 2: -31.82 GTTTTGAAAA T:21.0(8.50%),B:13.0(0.88%),P:1e-13
# 		Round 3: -31.82 GTTTTGAAAA T:21.0(8.50%),B:13.0(0.88%),P:1e-13
# 		=Final=: -32.62 GTTTTGAAAA T:21.0(8.86%),B:12.5(0.92%),P:1e-14
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	18 of 25 Initial Sequence: TTTTCACACG... (-13.185)
# 		Round 1: -26.14 TTTTCACACG T:11.0(4.54%),B:3.3(0.22%),P:1e-11
# 		Round 2: -26.14 TTTTCACACG T:11.0(4.54%),B:3.3(0.22%),P:1e-11
# 		=Final=: -22.24 TTTTCACACG T:10.0(4.22%),B:3.3(0.24%),P:1e-9
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	19 of 25 Initial Sequence: TCAAACTACT... (-13.148)
# 		Round 1: -22.32 TCAAACTACT T:12.0(4.95%),B:5.4(0.37%),P:1e-9
# 		Round 2: -22.32 TCAAACTACT T:12.0(4.95%),B:5.4(0.37%),P:1e-9
# 		=Final=: -22.69 TCAAACTACT T:12.0(5.06%),B:5.4(0.39%),P:1e-9
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	20 of 25 Initial Sequence: GATCAACGTT... (-12.572)
# 		Round 1: -20.99 GATCAAMGTT T:8.0(3.33%),B:1.2(0.07%),P:1e-9
# 		Round 2: -20.99 GATCAAMGTT T:8.0(3.33%),B:1.2(0.07%),P:1e-9
# 		=Final=: -24.85 GATCAAMGTT T:8.0(3.38%),B:1.2(0.09%),P:1e-10
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	21 of 25 Initial Sequence: TATACGACTT... (-12.572)
# 		Round 1: -24.85 TATACGACTT T:9.0(3.73%),B:1.1(0.07%),P:1e-10
# 		Round 2: -24.85 TATACGACTT T:9.0(3.73%),B:1.1(0.07%),P:1e-10
# 		=Final=: -24.85 TATACGACTT T:8.0(3.38%),B:1.1(0.08%),P:1e-10
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	22 of 25 Initial Sequence: AGAGAAAGGG... (-11.932)
# 		Round 1: -16.91 AGAGAAAGGG T:21.0(8.50%),B:27.5(1.97%),P:1e-7
# 		Round 2: -17.72 AGAGGAAAAG T:29.0(11.54%),B:45.1(3.25%),P:1e-7
# 		Round 3: -17.88 AGAGRAAAGG T:22.0(8.88%),B:28.8(2.04%),P:1e-7
# 		Round 4: -17.88 AGAGRAAAGG T:22.0(8.88%),B:28.8(2.04%),P:1e-7
# 		=Final=: -5.66 AGAGRAAAGG T:8.0(3.38%),B:14.1(1.04%),P:1e-2
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	23 of 25 Initial Sequence: TATCATTGAC... (-11.701)
# 		Round 1: -20.65 TATCATTGAC T:13.0(5.35%),B:7.5(0.51%),P:1e-8
# 		Round 2: -20.65 TATCATTGAC T:13.0(5.35%),B:7.5(0.51%),P:1e-8
# 		=Final=: -21.37 TATCATTGAC T:13.0(5.49%),B:7.5(0.56%),P:1e-9
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	24 of 25 Initial Sequence: AGTCAACATA... (-11.255)
# 		Round 1: -28.83 AGTCAACATA T:10.0(4.14%),B:1.9(0.07%),P:1e-12
# 		Round 2: -28.83 AGTCAACATA T:10.0(4.14%),B:1.9(0.07%),P:1e-12
# 		=Final=: -28.83 AGTCAACATA T:9.0(3.80%),B:1.9(0.14%),P:1e-12
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	25 of 25 Initial Sequence: ATTCTAAGAA... (-10.995)
# 		Round 1: -25.21 ATTCTAAGAA T:13.0(5.35%),B:5.4(0.37%),P:1e-10
# 		Round 2: -25.21 ATTCTAAGAA T:13.0(5.35%),B:5.4(0.37%),P:1e-10
# 		=Final=: -22.69 ATTCTAAGAA T:12.0(5.06%),B:5.4(0.40%),P:1e-9
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
#
# 	Finalizing Enrichment Statistics (new in v3.4)
# 	Reading input files...
# 	1808 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 25 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Output in file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Up_vs_DiffPeakAnno_DM1_DM2d_Down/homerMotifs.motifs10
#
#
# 	Number of Trial motifs (-T) set to 20 (from 10) to work well with 20 CPUs
# 	-blen automatically set to 2
# 	Scanning input files...
# 	Parsing sequences...
# 	|0%                                   50%                                  100%|
# 	==================================================================================
# 	Total number of Oligos: 309454
# 	Autoadjustment for sequence coverage in background: 1.00x
#
# 	Oligos: 309454 of 343520 max
# 	Tree  : 868232 of 1717600 max
# 	Optimizing memory usage...
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Global Optimization Phase: Looking for enriched oligos with up to 2 mismatches...
#
# 	Screening oligos 309454 (allowing 0 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		85.75% skipped, 14.25% checked (44103 of 309454), of those checked:
# 		85.75% not in target, 0.00% increased p-value, 0.00% high p-value
#
# 	Screening oligos 309454 (allowing 1 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		85.75% skipped, 14.25% checked (44103 of 309454), of those checked:
# 		0.00% not in target, 10.97% increased p-value, 0.18% high p-value
#
# 	Screening oligos 309454 (allowing 2 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		96.73% skipped, 3.27% checked (10105 of 309454), of those checked:
# 		0.00% not in target, 2.56% increased p-value, 0.00% high p-value
# 	Reading input files...
# 	1808 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Local Optimization Phase:
# 	1 of 25 Initial Sequence: TTTTTGGTCAAT... (-24.851)
# 		Round 1: -59.30 TTTTTGGTCAAT T:17.0(6.94%),B:1.5(0.07%),P:1e-25
# 		Round 2: -59.30 TTTTTGGTCAAT T:17.0(6.94%),B:1.5(0.07%),P:1e-25
# 		=Final=: -63.95 TTTTTGGTCAAT T:17.0(7.17%),B:1.5(0.11%),P:1e-27
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	2 of 25 Initial Sequence: AAAAGTCAAATA... (-19.455)
# 		Round 1: -44.47 AAAAGTCAAATA T:16.0(6.54%),B:4.0(0.22%),P:1e-19
# 		Round 2: -50.20 MAAAGTCAAATA T:15.0(6.15%),B:2.6(0.15%),P:1e-21
# 		Round 3: -54.71 MAAAGTCAAMTW T:16.0(6.54%),B:0.9(0.00%),P:1e-23
# 		Round 4: -54.71 MAAAGTCAAMTW T:16.0(6.54%),B:0.9(0.00%),P:1e-23
# 		=Final=: -54.71 MAAAGTCAAMTW T:15.0(6.33%),B:0.9(0.07%),P:1e-23
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	3 of 25 Initial Sequence: GACGACTTCGTA... (-17.272)
# 		Round 1: -31.10 GAMGACTTCGTA T:22.0(8.88%),B:14.5(1.02%),P:1e-13
# 		Round 2: -40.65 GAWGACTTYTTA T:15.0(6.15%),B:3.9(0.22%),P:1e-17
# 		Round 3: -40.65 GAWGACTTYTTA T:15.0(6.15%),B:3.9(0.22%),P:1e-17
# 		=Final=: -38.54 GAWGACTTYTTA T:15.0(6.33%),B:3.9(0.29%),P:1e-16
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	4 of 25 Initial Sequence: TCAAACCAATTG... (-17.272)
# 		Round 1: -29.67 TCAAACCAATTG T:18.0(7.33%),B:9.4(0.66%),P:1e-12
# 		Round 2: -29.67 TCAAACCAATTG T:18.0(7.33%),B:9.4(0.66%),P:1e-12
# 		=Final=: -25.37 TCAAACCAATTG T:16.0(6.75%),B:9.4(0.69%),P:1e-11
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	5 of 25 Initial Sequence: TAAGGGCTGAAT... (-17.272)
# 		Round 1: -17.27 TAAGGGCTGAAT T:7.0(2.92%),B:3.0(0.15%),P:1e-7
# 		Round 2: -17.27 TAAGGGCTGAAT T:7.0(2.92%),B:3.0(0.15%),P:1e-7
# 		=Final=: -16.29 TAAGGGCTGAAT T:7.0(2.95%),B:3.0(0.22%),P:1e-7
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	6 of 25 Initial Sequence: ATTTTGACAACT... (-17.272)
# 		Round 1: -20.99 ATTTTGACAACT T:8.0(3.33%),B:0.9(0.00%),P:1e-9
# 		Round 2: -31.25 ATTTTGACAADT T:38.0(14.84%),B:43.0(3.11%),P:1e-13
# 		Round 3: -31.25 ATTTTGACAADT T:38.0(14.84%),B:43.0(3.11%),P:1e-13
# 		=Final=: -31.95 ATTTTGACAADT T:35.0(14.77%),B:41.2(3.03%),P:1e-13
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	7 of 25 Initial Sequence: CTTTTCAACAAT... (-17.272)
# 		Round 1: -23.25 CTTTTCAACAAT T:24.0(9.65%),B:23.9(1.68%),P:1e-10
# 		Round 2: -23.25 CTTTTCAACAAT T:24.0(9.65%),B:23.9(1.68%),P:1e-10
# 		=Final=: -23.25 CTTTTCAACAAT T:22.0(9.28%),B:22.2(1.63%),P:1e-10
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	8 of 25 Initial Sequence: ATGTTAATTAGT... (-17.272)
# 		Round 1: -32.92 ATGTTAATTAGT T:11.0(4.54%),B:0.8(0.00%),P:1e-14
# 		Round 2: -37.11 ATGTTAATTAGT T:12.0(4.95%),B:1.0(0.00%),P:1e-16
# 		Round 3: -37.11 ATGTTAATTAGT T:12.0(4.95%),B:1.0(0.00%),P:1e-16
# 		=Final=: -41.39 ATGTTAATTAGT T:12.0(5.06%),B:1.0(0.07%),P:1e-17
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	9 of 25 Initial Sequence: TCCTTACGTCTG... (-17.272)
# 		Round 1: -20.99 TCCTTACGTCTG T:8.0(3.33%),B:0.0(0.00%),P:1e-9
# 		Round 2: -20.99 TCCTTACGTCTG T:8.0(3.33%),B:0.0(0.00%),P:1e-9
# 		=Final=: -24.85 TCCTTACGTCTG T:8.0(3.38%),B:0.0(0.00%),P:1e-10
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	10 of 25 Initial Sequence: ATTCCAAGTTTC... (-17.272)
# 		Round 1: -25.88 ATTCAAAGTTTC T:15.0(6.15%),B:8.0(0.51%),P:1e-11
# 		Round 2: -28.83 ATTYAAAGTTTY T:10.0(4.14%),B:2.9(0.15%),P:1e-12
# 		Round 3: -28.83 ATTYAAAGTTTY T:10.0(4.14%),B:2.9(0.15%),P:1e-12
# 		=Final=: -26.14 ATTYAAAGTTTY T:10.0(4.22%),B:2.9(0.21%),P:1e-11
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	11 of 25 Initial Sequence: CGTGCACGATAA... (-17.272)
# 		Round 1: -23.12 CGTGCACGATAA T:22.0(8.88%),B:21.4(1.53%),P:1e-10
# 		Round 2: -41.39 CGTRCACGATAA T:13.0(5.35%),B:2.9(0.15%),P:1e-17
# 		Round 3: -41.39 CGTRCACGATAA T:13.0(5.35%),B:2.9(0.15%),P:1e-17
# 		=Final=: -37.11 CGTRCACGATAA T:11.0(4.64%),B:1.7(0.12%),P:1e-16
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	12 of 25 Initial Sequence: GTTTTCCTAGGT... (-15.299)
# 		Round 1: -37.11 GTTTTCMTAGGT T:12.0(4.95%),B:0.5(0.00%),P:1e-16
# 		Round 2: -37.11 GTTTTCMTAGGT T:12.0(4.95%),B:0.5(0.00%),P:1e-16
# 		=Final=: -41.39 GTTTTCMTAGGT T:12.0(5.06%),B:0.5(0.03%),P:1e-17
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	13 of 25 Initial Sequence: AGAGGGAAAGAG... (-15.130)
# 		Round 1: -17.43 AGAGRGAAAGAG T:11.0(4.54%),B:6.6(0.44%),P:1e-7
# 		Round 2: -22.98 AGAGGGAAAGAG T:16.0(6.54%),B:10.1(0.73%),P:1e-9
# 		Round 3: -22.98 AGAGGGAAAGAG T:16.0(6.54%),B:10.1(0.73%),P:1e-9
# 		=Final=: -5.22 AGAGGGAAAGAG T:3.0(1.27%),B:2.0(0.15%),P:1e-2
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	14 of 25 Initial Sequence: GGCTGATGCATG... (-14.369)
# 		Round 1: -32.92 GGCTGATGCATG T:11.0(4.54%),B:1.1(0.07%),P:1e-14
# 		Round 2: -32.92 GGCTGATGCATG T:11.0(4.54%),B:1.1(0.07%),P:1e-14
# 		=Final=: -28.83 GGCTGATGCATG T:9.0(3.80%),B:1.1(0.08%),P:1e-12
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	15 of 25 Initial Sequence: ATCTTTAATTAA... (-14.208)
# 		Round 1: -24.85 ATCTTTAATTAA T:9.0(3.73%),B:1.7(0.07%),P:1e-10
# 		Round 2: -24.85 ATCTTTAATTAA T:9.0(3.73%),B:1.7(0.07%),P:1e-10
# 		=Final=: -28.83 ATCTTTAATTAA T:9.0(3.80%),B:1.7(0.13%),P:1e-12
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	16 of 25 Initial Sequence: CTTGGTCAAACA... (-14.139)
# 		Round 1: -28.69 NNHGGTCAANNH T:115.0(38.51%),B:276.9(18.37%),P:1e-12
# 		Round 2: -28.69 NNHGGTCAANNH T:115.0(38.51%),B:276.9(18.37%),P:1e-12
# 		=Final=: -35.00 NNHGGTCAANNH T:94.0(39.66%),B:237.7(17.48%),P:1e-15
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	17 of 25 Initial Sequence: AATTTATGTCTT... (-17.272)
# 		Round 1: -28.83 AATTTATGTCTT T:10.0(4.14%),B:2.2(0.15%),P:1e-12
# 		Round 2: -28.83 AATTTATGTCTT T:10.0(4.14%),B:2.2(0.15%),P:1e-12
# 		=Final=: -19.46 AATTTATGTCTT T:8.0(3.38%),B:2.2(0.16%),P:1e-8
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	18 of 25 Initial Sequence: AAATATTTTCAA... (-17.272)
# 		Round 1: -19.46 AAATATTTTCAA T:9.0(3.73%),B:3.9(0.22%),P:1e-8
# 		Round 2: -37.11 AAATATTTTCAA T:12.0(4.95%),B:2.3(0.15%),P:1e-16
# 		Round 3: -37.11 AAATATTTTCAA T:12.0(4.95%),B:2.3(0.15%),P:1e-16
# 		=Final=: -33.22 AAATATTTTCAA T:12.0(5.06%),B:2.3(0.17%),P:1e-14
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	19 of 25 Initial Sequence: TAAGAATTTTGT... (-13.708)
# 		Round 1: -20.99 TAAGAATTTTGT T:8.0(3.33%),B:2.8(0.15%),P:1e-9
# 		Round 2: -22.74 TAAGAATTTTGT T:10.0(4.14%),B:3.8(0.22%),P:1e-9
# 		Round 3: -22.74 TAAGAATTTTGT T:10.0(4.14%),B:3.8(0.22%),P:1e-9
# 		=Final=: -22.24 TAAGAATTTTGT T:10.0(4.22%),B:3.8(0.28%),P:1e-9
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	20 of 25 Initial Sequence: AAAGAGAGAAAG... (-13.708)
# 		Round 1: -17.27 AAAGAGAGAAAG T:7.0(2.92%),B:2.2(0.15%),P:1e-7
# 		Round 2: -22.74 AACGAGAGAAAT T:10.0(4.14%),B:3.5(0.22%),P:1e-9
# 		Round 3: -28.83 AACGATAGAAAG T:10.0(4.14%),B:2.3(0.15%),P:1e-12
# 		Round 4: -28.83 AACGATAGAAAG T:10.0(4.14%),B:2.3(0.15%),P:1e-12
# 		=Final=: -10.38 AACGATAGAAAG T:5.0(2.11%),B:2.3(0.17%),P:1e-4
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	21 of 25 Initial Sequence: ATAAATTTGTGG... (-13.708)
# 		Round 1: -17.27 ATAAATTTGTGG T:7.0(2.92%),B:1.7(0.07%),P:1e-7
# 		Round 2: -17.27 ATAAATTTGTGG T:7.0(2.92%),B:1.7(0.07%),P:1e-7
# 		=Final=: -20.99 ATAAATTTGTGG T:7.0(2.95%),B:1.7(0.13%),P:1e-9
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	22 of 25 Initial Sequence: GCGATCAACGTT... (-13.708)
# 		Round 1: -24.85 DNGATCAACGTT T:9.0(3.73%),B:1.0(0.00%),P:1e-10
# 		Round 2: -24.85 DNGATCAACGTT T:9.0(3.73%),B:1.0(0.00%),P:1e-10
# 		=Final=: -24.85 DNGATCAACGTT T:8.0(3.38%),B:1.0(0.07%),P:1e-10
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	23 of 25 Initial Sequence: TAACTGTATAAA... (-13.708)
# 		Round 1: -20.99 TAACTGTATAAA T:8.0(3.33%),B:2.8(0.15%),P:1e-9
# 		Round 2: -20.99 TAACTGTATAAA T:8.0(3.33%),B:2.8(0.15%),P:1e-9
# 		=Final=: -20.99 TAACTGTATAAA T:7.0(2.95%),B:0.5(0.04%),P:1e-9
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	24 of 25 Initial Sequence: TACGCGACCATC... (-13.708)
# 		Round 1: -24.85 TACGCRACCATS T:9.0(3.73%),B:2.7(0.15%),P:1e-10
# 		Round 2: -25.33 TACGCGACCATM T:12.0(4.95%),B:4.3(0.29%),P:1e-11
# 		Round 3: -25.33 TACGCGACCATM T:12.0(4.95%),B:4.3(0.29%),P:1e-11
# 		=Final=: -25.21 TACGCGACCATM T:12.0(5.06%),B:4.3(0.32%),P:1e-10
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	25 of 25 Initial Sequence: AACATTTTACTT... (-13.708)
# 		Round 1: -27.19 AACATTTTACTT T:22.0(8.88%),B:18.0(1.24%),P:1e-11
# 		Round 2: -36.90 AACATTTTACTT T:14.0(5.75%),B:3.5(0.22%),P:1e-16
# 		Round 3: -36.90 AACATTTTACTT T:14.0(5.75%),B:3.5(0.22%),P:1e-16
# 		=Final=: -35.12 AACATTTTACTT T:14.0(5.91%),B:3.5(0.26%),P:1e-15
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
#
# 	Finalizing Enrichment Statistics (new in v3.4)
# 	Reading input files...
# 	1808 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 25 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Output in file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Up_vs_DiffPeakAnno_DM1_DM2d_Down/homerMotifs.motifs12
#
# 	(Motifs in homer2 format)
# 	Determining similar motifs... 70 reduced to 37 motifs
# 	Outputing HTML and sequence logos for motif comparison...
# 	Checking de novo motifs against known motifs...
# 	Formatting HTML page...
# 		1 of 37 (1e-32) similar to WRKY22(WRKY)/colamp-WRKY22-DAP-Seq(GSE60143)/Homer(0.960)
# 		2 of 37 (1e-27) similar to WRKY18(WRKY)/col-WRKY18-DAP-Seq(GSE60143)/Homer(0.724)
# 		3 of 37 (1e-17) similar to ZHD1/MA1329.2/Jaspar(0.816)
# 		4 of 37 (1e-17) similar to TBP(- other)/several species/AthaMap(0.596)
# 		5 of 37 (1e-17) similar to GT2(Trihelix)/colamp-GT2-DAP-Seq(GSE60143)/Homer(0.642)
# 		6 of 37 (1e-17) similar to At2g41835(C2H2)/col-At2g41835-DAP-Seq(GSE60143)/Homer(0.804)
# 		7 of 37 (1e-16) similar to At3g60580(C2H2)/col-At3g60580-DAP-Seq(GSE60143)/Homer(0.662)
# 		8 of 37 (1e-16) similar to At2g41835(C2H2)/col-At2g41835-DAP-Seq(GSE60143)/Homer(0.728)
# 		9 of 37 (1e-16) similar to AT3G51470(DBP)/col-AT3G51470-DAP-Seq(GSE60143)/Homer(0.661)
# 		10 of 37 (1e-13) similar to NAC083/MA1043.1/Jaspar(0.840)
# 		11 of 37 (1e-13) similar to ERF094/MA1049.1/Jaspar(0.902)
# 		12 of 37 (1e-12) similar to FUS3(ABI3VP1)/col-FUS3-DAP-Seq(GSE60143)/Homer(0.686)
# 		13 of 37 (1e-12) similar to ATHB23/MA1327.2/Jaspar(0.760)
# 		14 of 37 (1e-11) similar to NAC055/MA0937.1/Jaspar(0.805)
# 		15 of 37 (1e-11) similar to SOL1/MA1379.1/Jaspar(0.708)
# 		16 of 37 (1e-11) similar to CAMTA1(CAMTA)/col-CAMTA1-DAP-Seq(GSE60143)/Homer(0.612)
# 		17 of 37 (1e-11) similar to CBF(- other)/several species/AthaMap(0.633)
# 		18 of 37 (1e-10) similar to GATA20(C2C2gata)/colamp-GATA20-DAP-Seq(GSE60143)/Homer(0.673)
# 		19 of 37 (1e-10) similar to ARF16(ARF)/col-ARF16-DAP-Seq(GSE60143)/Homer(0.599)
# 		20 of 37 (1e-10) similar to MYB98/MA1392.1/Jaspar(0.794)
# 		21 of 37 (1e-10) similar to At2g41835(C2H2)/col-At2g41835-DAP-Seq(GSE60143)/Homer(0.738)
# 		22 of 37 (1e-10) similar to At2g41835(C2H2)/col-At2g41835-DAP-Seq(GSE60143)/Homer(0.675)
# 		23 of 37 (1e-9) similar to AT5G60130(ABI3VP1)/col-AT5G60130-DAP-Seq(GSE60143)/Homer(0.650)
# 		24 of 37 (1e-9) similar to AT2G40260(G2like)/colamp-AT2G40260-DAP-Seq(GSE60143)/Homer(0.773)
# 		25 of 37 (1e-9) similar to MYB77/MA1395.1/Jaspar(0.695)
# 		26 of 37 (1e-8) similar to AGP1(GATA)/Nicotiana tabacum/AthaMap(0.551)
# 		27 of 37 (1e-8) similar to KAN1/MA1027.1/Jaspar(0.621)
# 		28 of 37 (1e-7) similar to SGR5/MA1159.1/Jaspar(0.703)
# 		29 of 37 (1e-7) similar to P(MYB)/Zea mays/AthaMap(0.760)
# 		30 of 37 (1e-7) similar to SPL3/MA0577.2/Jaspar(0.809)
# 		31 of 37 (1e-7) similar to TBP3/MA1355.1/Jaspar(0.595)
# 		32 of 37 (1e-7) similar to CAMTA1(CAMTA)/col-CAMTA1-DAP-Seq(GSE60143)/Homer(0.788)
# 		33 of 37 (1e-5) similar to KAN4/MA1028.1/Jaspar(0.594)
# 		34 of 37 (1e-5) similar to At5g47390(MYBrelated)/col-At5g47390-DAP-Seq(GSE60143)/Homer(0.791)
# 		35 of 37 (1e-5) similar to WRKY45/MA1087.1/Jaspar(0.718)
# 		36 of 37 (1e-3) similar to BEH2/MA1332.1/Jaspar(0.687)
# 		37 of 37 (1e-2) similar to BPC6(BBRBPC)/col-BPC6-DAP-Seq(GSE60143)/Homer(0.683)
# 	Job finished - if results look good, please send beer to ..
#
# 	Cleaning up tmp files...
#
#
#
#
# 	Position file = /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Down.bed
# 	Genome = /media/HDD2/Genomes/Ath_Ensembl56/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa
# 	Output Directory = /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Down_vs_DiffPeakAnno_DM1_DM2d_Up
# 	background position file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Up.bed
# 	Using 20 CPUs
# 	Using Custom Genome
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 1704
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 1704
# 		Redundant Peak IDs: 822
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Redunant Peaks found: Remove or rename these or some programs may have trouble...
#
# 	822 duplicate peak IDs out of 1704 total peaks
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 237
# 		peakfile formatted lines: 0
# 	29 duplicate peak IDs out of 237 total peaks
# 	Max distance to merge: 200 bp
# ...
# 		Round 1: -201.55 CTGGCCCATA T:116.0(7.12%),B:2.9(0.96%),P:1e-87
# 		Round 2: -201.55 CTGGCCCATA T:116.0(7.12%),B:2.9(0.96%),P:1e-87
# 		=Final=: -71.50 CTGGCCCATA T:113.0(7.19%),B:5.0(2.38%),P:1e-31
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	23 of 25 Initial Sequence: TCACTGAGAG... (-149.184)
# 		Round 1: -149.18 TCACTGAGAG T:149.0(9.05%),B:4.7(1.90%),P:1e-64
# 		Round 2: -149.18 TCACTGAGAG T:149.0(9.05%),B:4.7(1.90%),P:1e-64
# 		=Final=: -107.22 TCACTGAGAG T:137.0(8.72%),B:4.7(2.26%),P:1e-46
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	24 of 25 Initial Sequence: TCCGGTTCAA... (-143.458)
# 		Round 1: -143.46 TCCGGTTCAA T:146.0(8.88%),B:4.5(1.90%),P:1e-62
# 		Round 2: -143.46 TCCGGTTCAA T:146.0(8.88%),B:4.5(1.90%),P:1e-62
# 		=Final=: -99.37 TCCGGTTCAA T:132.0(8.40%),B:4.5(2.18%),P:1e-43
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	25 of 25 Initial Sequence: GCCTTGTCTC... (-137.057)
# 		Round 1: -137.06 GCCTTGTCTC T:164.0(9.92%),B:5.3(2.37%),P:1e-59
# 		Round 2: -137.06 GCCTTGTCTC T:164.0(9.92%),B:5.3(2.37%),P:1e-59
# 		=Final=: -106.39 GCCTTGTCTC T:153.0(9.74%),B:5.3(2.57%),P:1e-46
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
#
# 	Finalizing Enrichment Statistics (new in v3.4)
# 	Reading input files...
# 	1808 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 25 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Output in file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Down_vs_DiffPeakAnno_DM1_DM2d_Up/homerMotifs.motifs10
#
#
# 	Number of Trial motifs (-T) set to 20 (from 10) to work well with 20 CPUs
# 	-blen automatically set to 2
# 	Scanning input files...
# 	Parsing sequences...
# 	|0%                                   50%                                  100%|
# 	==================================================================================
# 	Total number of Oligos: 309454
# 	Autoadjustment for sequence coverage in background: 1.00x
#
# 	Oligos: 309454 of 343520 max
# 	Tree  : 868232 of 1717600 max
# 	Optimizing memory usage...
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Global Optimization Phase: Looking for enriched oligos with up to 2 mismatches...
#
# 	Screening oligos 309454 (allowing 0 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		12.24% skipped, 87.76% checked (271564 of 309454), of those checked:
# 		12.24% not in target, 0.00% increased p-value, 0.00% high p-value
#
# 	Screening oligos 309454 (allowing 1 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		12.24% skipped, 87.76% checked (271564 of 309454), of those checked:
# 		0.00% not in target, 19.22% increased p-value, 66.05% high p-value
#
# 	Screening oligos 309454 (allowing 2 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		78.30% skipped, 21.70% checked (67155 of 309454), of those checked:
# 		0.00% not in target, 5.24% increased p-value, 5.49% high p-value
# 	Reading input files...
# 	1808 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Local Optimization Phase:
# 	1 of 25 Initial Sequence: ATCTCTCTCTCT... (-411.636)
# 		Round 1: -421.54 CTCTCTCTCTCT T:195.0(11.68%),B:2.3(0.96%),P:1e-183
# 		Round 2: -421.54 CTCTCTCTCTCT T:195.0(11.68%),B:2.3(0.96%),P:1e-183
# 		=Final=: -208.37 CTCTCTCTCTCT T:267.0(17.00%),B:9.0(4.32%),P:1e-90
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	2 of 25 Initial Sequence: AAACCAACAATA... (-300.538)
# 		Round 1: -300.54 AAACCAACAATA T:153.0(9.28%),B:2.0(0.96%),P:1e-130
# 		Round 2: -300.54 AAACCAACAATA T:153.0(9.28%),B:2.0(0.96%),P:1e-130
# 		=Final=: -211.61 AAACCAACAATA T:147.0(9.36%),B:2.0(0.98%),P:1e-91
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	3 of 25 Initial Sequence: AAAAGGGGAAAA... (-294.452)
# 		Round 1: -294.45 AAAAGGGGAAAA T:150.0(9.11%),B:2.7(0.96%),P:1e-127
# 		Round 2: -294.45 AAAAGGGGAAAA T:150.0(9.11%),B:2.7(0.96%),P:1e-127
# 		=Final=: -142.05 AAAAGGGGAAAA T:116.0(7.38%),B:2.4(1.16%),P:1e-61
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	4 of 25 Initial Sequence: AGACAAAAGAAT... (-244.969)
# 		Round 1: -244.97 AGACAAAAGAAT T:201.0(12.01%),B:4.0(1.90%),P:1e-106
# 		Round 2: -244.97 AGACAAAAGAAT T:201.0(12.01%),B:4.0(1.90%),P:1e-106
# 		=Final=: -197.61 AGACAAAAGAAT T:188.0(11.97%),B:4.0(1.95%),P:1e-85
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	5 of 25 Initial Sequence: ACAAAAACAGAA... (-209.247)
# 		Round 1: -209.25 ACAAAAACAGAA T:253.0(14.88%),B:7.8(3.31%),P:1e-90
# 		Round 2: -209.25 ACAAAAACAGAA T:253.0(14.88%),B:7.8(3.31%),P:1e-90
# 		=Final=: -175.12 ACAAAAACAGAA T:230.0(14.64%),B:7.9(3.78%),P:1e-76
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	6 of 25 Initial Sequence: TATCGTTTTTAT... (-264.493)
# 		Round 1: -264.49 TATCGTTTTTAT T:140.0(8.53%),B:2.5(0.96%),P:1e-114
# 		Round 2: -264.49 TATCGTTTTTAT T:140.0(8.53%),B:2.5(0.96%),P:1e-114
# 		=Final=: -181.47 TATCGTTTTTAT T:134.0(8.53%),B:2.8(1.34%),P:1e-78
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	7 of 25 Initial Sequence: TATTTGCATGTG... (-179.779)
# 		Round 1: -179.78 TATTTGCATGTG T:107.0(6.59%),B:2.9(0.96%),P:1e-78
# 		Round 2: -179.78 TATTTGCATGTG T:107.0(6.59%),B:2.9(0.96%),P:1e-78
# 		=Final=: -115.42 TATTTGCATGTG T:103.0(6.56%),B:2.9(1.42%),P:1e-50
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	8 of 25 Initial Sequence: ACATGAATACAT... (-226.779)
# 		Round 1: -232.49 ACATRMATACAT T:128.0(7.83%),B:1.0(0.00%),P:1e-100
# 		Round 2: -264.49 ACATACATACAT T:140.0(8.53%),B:2.9(0.96%),P:1e-114
# 		Round 3: -264.49 ACATACATACAT T:140.0(8.53%),B:2.9(0.96%),P:1e-114
# 		=Final=: -88.70 ACATACATACAT T:89.0(5.67%),B:2.9(1.39%),P:1e-38
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	9 of 25 Initial Sequence: TCTTTTTCACTC... (-174.437)
# 		Round 1: -174.44 TCTTTTTCACTC T:105.0(6.47%),B:2.3(0.96%),P:1e-75
# 		Round 2: -174.44 TCTTTTTCACTC T:105.0(6.47%),B:2.3(0.96%),P:1e-75
# 		=Final=: -96.11 TCTTTTTCACTC T:93.0(5.92%),B:2.3(1.13%),P:1e-41
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	10 of 25 Initial Sequence: TTTTGTGATATG... (-169.138)
# 		Round 1: -226.78 TTTTGTGATATG T:125.0(7.65%),B:2.0(0.96%),P:1e-98
# 		Round 2: -226.78 TTTTGTGATATG T:125.0(7.65%),B:2.0(0.96%),P:1e-98
# 		=Final=: -207.09 TTTTGTGATATG T:113.0(7.19%),B:1.7(0.82%),P:1e-89
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	11 of 25 Initial Sequence: GCAAAAGACAAA... (-218.286)
# 		Round 1: -218.29 GCAAAAGACAAA T:122.0(7.47%),B:2.7(0.96%),P:1e-94
# 		Round 2: -218.29 GCAAAAGACAAA T:122.0(7.47%),B:2.7(0.96%),P:1e-94
# 		=Final=: -142.05 GCAAAAGACAAA T:116.0(7.38%),B:2.7(1.31%),P:1e-61
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	12 of 25 Initial Sequence: AGTATTATTATG... (-150.933)
# 		Round 1: -150.93 AGTATTATTATG T:95.0(5.87%),B:1.7(0.48%),P:1e-65
# 		Round 2: -150.93 AGTATTATTATG T:95.0(5.87%),B:1.7(0.48%),P:1e-65
# 		=Final=: -143.30 AGTATTATTATG T:89.0(5.67%),B:1.7(0.82%),P:1e-62
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	13 of 25 Initial Sequence: ATATGGACCACA... (-148.378)
# 		Round 1: -356.63 ATATGGACCACA T:173.0(10.43%),B:3.0(0.96%),P:1e-154
# 		Round 2: -356.63 ATATGGACCACA T:173.0(10.43%),B:3.0(0.96%),P:1e-154
# 		=Final=: -225.95 ATATGGACCACA T:153.0(9.74%),B:3.0(1.43%),P:1e-98
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	14 of 25 Initial Sequence: ATCAACATCATC... (-138.272)
# 		Round 1: -138.27 ATCAACATCATC T:90.0(5.57%),B:1.2(0.48%),P:1e-60
# 		Round 2: -138.27 ATCAACATCATC T:90.0(5.57%),B:1.2(0.48%),P:1e-60
# 		=Final=: -97.59 ATCAACATCATC T:70.0(4.46%),B:1.2(0.60%),P:1e-42
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	15 of 25 Initial Sequence: AAGAAGAGAGGA... (-138.272)
# 		Round 1: -138.27 AAGAAGAGAGGA T:90.0(5.57%),B:2.8(0.96%),P:1e-60
# 		Round 2: -138.27 AAGAAGAGAGGA T:90.0(5.57%),B:2.8(0.96%),P:1e-60
# 		=Final=: -55.51 AAGAAGAGAGGA T:86.0(5.47%),B:3.4(1.64%),P:1e-24
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	16 of 25 Initial Sequence: TTTTGCATTTAT... (-130.377)
# 		Round 1: -182.46 TTTTRYWTTTAT T:108.0(6.65%),B:2.4(0.96%),P:1e-79
# 		Round 2: -182.46 TTTTRYWTTTAT T:108.0(6.65%),B:2.4(0.96%),P:1e-79
# 		=Final=: -148.38 TTTTRYWTTTAT T:91.0(5.79%),B:1.3(0.62%),P:1e-64
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	17 of 25 Initial Sequence: ATTCACATGTGA... (-116.254)
# 		Round 1: -264.49 ATTCACATGTGA T:139.0(8.47%),B:2.9(0.96%),P:1e-114
# 		Round 2: -264.49 ATTCACATGTGA T:139.0(8.47%),B:2.9(0.96%),P:1e-114
# 		=Final=: -135.76 ATTCACATGTGA T:113.0(7.19%),B:2.9(1.38%),P:1e-58
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	18 of 25 Initial Sequence: ATTTGTTATGTG... (-123.479)
# 		Round 1: -123.48 ATTTGTTATGTG T:84.0(5.21%),B:2.8(0.96%),P:1e-53
# 		Round 2: -123.48 ATTTGTTATGTG T:84.0(5.21%),B:2.8(0.96%),P:1e-53
# 		=Final=: -77.94 ATTTGTTATGTG T:83.0(5.28%),B:2.8(1.33%),P:1e-33
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	19 of 25 Initial Sequence: ACATGAAATGAA... (-109.512)
# 		Round 1: -198.79 NCATGAAATDAA T:115.0(7.06%),B:2.8(0.96%),P:1e-86
# 		Round 2: -198.79 NCATGAAATDAA T:115.0(7.06%),B:2.8(0.96%),P:1e-86
# 		=Final=: -137.06 NCATGAAATDAA T:155.0(9.87%),B:4.8(2.28%),P:1e-59
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	20 of 25 Initial Sequence: TTTTGGGACCAA... (-106.810)
# 		Round 1: -201.55 TTTTGGGACCAA T:116.0(7.12%),B:2.9(0.96%),P:1e-87
# 		Round 2: -201.55 TTTTGGGACCAA T:116.0(7.12%),B:2.9(0.96%),P:1e-87
# 		=Final=: -166.50 TTTTGGGACCAA T:98.0(6.24%),B:1.7(0.82%),P:1e-72
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	21 of 25 Initial Sequence: GATAATGAGATA... (-102.172)
# 		Round 1: -130.22 GATAATGAGATA T:159.0(9.63%),B:5.6(2.37%),P:1e-56
# 		Round 2: -153.50 GATAATGAGATA T:96.0(5.93%),B:2.8(0.96%),P:1e-66
# 		Round 3: -161.27 GATAATGAGATA T:100.0(6.17%),B:2.8(0.96%),P:1e-70
# 		Round 4: -171.78 GATAATGAGATA T:104.0(6.41%),B:2.8(0.96%),P:1e-74
# 		Round 5: -171.78 GATAATGAGATA T:104.0(6.41%),B:2.8(0.96%),P:1e-74
# 		=Final=: -115.42 GATAATGAGATA T:103.0(6.56%),B:2.8(1.36%),P:1e-50
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	22 of 25 Initial Sequence: TTTTTTTTTGGG... (-97.666)
# 		Round 1: -97.67 TTTTTTTTTGGG T:219.0(13.02%),B:10.7(4.69%),P:1e-42
# 		Round 2: -97.67 TTTTTTTTTGGG T:219.0(13.02%),B:10.7(4.69%),P:1e-42
# 		=Final=: -61.02 TTTTTTTTTGGG T:133.0(8.47%),B:6.4(3.09%),P:1e-26
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	23 of 25 Initial Sequence: ATTTCCTTTTAA... (-111.470)
# 		Round 1: -111.47 ATTTCCTTTTAA T:105.0(6.47%),B:3.9(1.43%),P:1e-48
# 		Round 2: -111.47 ATTTCCTTTTAA T:105.0(6.47%),B:3.9(1.43%),P:1e-48
# 		=Final=: -77.59 ATTTCCTTTTAA T:101.0(6.43%),B:3.9(1.89%),P:1e-33
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	24 of 25 Initial Sequence: CATTCTTTATAT... (-85.484)
# 		Round 1: -106.81 CATTCTTTATAT T:76.0(4.72%),B:2.1(0.96%),P:1e-46
# 		Round 2: -106.81 CATTCTTTATAT T:76.0(4.72%),B:2.1(0.96%),P:1e-46
# 		=Final=: -95.32 CATTCTTTATAT T:69.0(4.39%),B:1.8(0.84%),P:1e-41
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	25 of 25 Initial Sequence: AATAGAAGACAA... (-90.533)
# 		Round 1: -158.67 AATAGAAGACAA T:98.0(6.05%),B:2.8(0.96%),P:1e-68
# 		Round 2: -158.67 AATAGAAGACAA T:98.0(6.05%),B:2.8(0.96%),P:1e-68
# 		=Final=: -44.83 AATAGAAGACAA T:78.0(4.96%),B:3.7(1.76%),P:1e-19
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
#
# 	Finalizing Enrichment Statistics (new in v3.4)
# 	Reading input files...
# 	1808 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 25 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Output in file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM1_DM2d/DiffPeakAnno_DM1_DM2d_Down_vs_DiffPeakAnno_DM1_DM2d_Up/homerMotifs.motifs12
#
# 	(Motifs in homer2 format)
# 	Determining similar motifs... 75 reduced to 38 motifs
# 	Outputing HTML and sequence logos for motif comparison...
# 	Checking de novo motifs against known motifs...
# 	Formatting HTML page...
# 		1 of 38 (1e-251) similar to TCP16(TCP)/colamp-TCP16-DAP-Seq(GSE60143)/Homer(0.881)
# 		2 of 38 (1e-230) similar to DOF5.7/MA0984.1/Jaspar(0.651)
# 		3 of 38 (1e-191) similar to REF6(Zf)/Arabidopsis-REF6-ChIP-Seq(GSE106942)/Homer(0.759)
# 		4 of 38 (1e-190) similar to SPT/MA1061.1/Jaspar(0.852)
# 		5 of 38 (1e-164) similar to BHLH112/MA0961.1/Jaspar(0.894)
# 		6 of 38 (1e-151) similar to AIB/MA0959.1/Jaspar(0.758)
# 		7 of 38 (1e-121) similar to FRS9(ND)/col-FRS9-DAP-Seq(GSE60143)/Homer(0.703)
# 		8 of 38 (1e-118) similar to MF0011.1_HMG_class/Jaspar(0.717)
# 		9 of 38 (1e-117) similar to RAV1(1)(AP2/EREBP)/Arabidopsis thaliana/AthaMap(0.681)
# 		10 of 38 (1e-116) similar to ARALYDRAFT_484486/MA1098.1/Jaspar(0.803)
# 		11 of 38 (1e-93) similar to POL009.1_DCE_S_II/Jaspar(0.683)
# 		12 of 38 (1e-93) similar to ALFIN1(HD-PHD)/Medicago sativa/AthaMap(0.720)
# 		13 of 38 (1e-92) similar to MF0011.1_HMG_class/Jaspar(0.679)
# 		14 of 38 (1e-92) similar to ASHR1(ND)/col-ASHR1-DAP-Seq(GSE60143)/Homer(0.734)
# 		15 of 38 (1e-91) similar to MYB116(MYB)/colamp-MYB116-DAP-Seq(GSE60143)/Homer(0.719)
# 		16 of 38 (1e-88) similar to AP1/MA0940.1/Jaspar(0.760)
# 		17 of 38 (1e-86) similar to FRS9(ND)/col-FRS9-DAP-Seq(GSE60143)/Homer(0.647)
# 		18 of 38 (1e-79) similar to ARF36/MA1695.1/Jaspar(0.632)
# 		19 of 38 (1e-75) similar to At5g04390(C2H2)/col200-At5g04390-DAP-Seq(GSE60143)/Homer(0.684)
# 		20 of 38 (1e-75) similar to AGL55/MA1202.1/Jaspar(0.755)
# 		21 of 38 (1e-74) similar to ZmHOX2a(1)(HD-HOX)/Zea mays/AthaMap(0.759)
# 		22 of 38 (1e-68) similar to WUS1(Homeobox)/colamp-WUS1-DAP-Seq(GSE60143)/Homer(0.760)
# 		23 of 38 (1e-63) similar to TCP3(TCP)/colamp-TCP3-DAP-Seq(GSE60143)/Homer(0.740)
# 		24 of 38 (1e-63) similar to AT2G31460(REMB3)/col-AT2G31460-DAP-Seq(GSE60143)/Homer(0.832)
# 		25 of 38 (1e-62) similar to POL012.1_TATA-Box/Jaspar(0.620)
# 		26 of 38 (1e-59) similar to ZIM(C2C2gata)/col-ZIM-DAP-Seq(GSE60143)/Homer(0.692)
# 		27 of 38 (1e-56) similar to NAC078/MA1677.1/Jaspar(0.678)
# 		28 of 38 (1e-54) similar to ARF34/MA1693.1/Jaspar(0.757)
# 		29 of 38 (1e-54) similar to BEH3/MA1333.1/Jaspar(0.675)
# 		30 of 38 (1e-47) similar to ATHB-16/MA0951.1/Jaspar(0.663)
# 		31 of 38 (1e-47) similar to AT5G60130(ABI3VP1)/col-AT5G60130-DAP-Seq(GSE60143)/Homer(0.708)
# 		32 of 38 (1e-45) similar to VRN1(ABI3VP1)/col-VRN1-DAP-Seq(GSE60143)/Homer(0.822)
# 		33 of 38 (1e-45) similar to ZML2(C2C2gata)/col-ZML2-DAP-Seq(GSE60143)/Homer(0.782)
# 		34 of 38 (1e-42) similar to Unknown3/Arabidopsis-Promoters/Homer(0.797)
# 		35 of 38 (1e-32) similar to AT3G46070/MA1381.1/Jaspar(0.780)
# 		36 of 38 (1e-31) similar to FUS3/MA0565.2/Jaspar(0.619)
# 		37 of 38 (1e-26) similar to SGR5(C2H2)/colamp-SGR5-DAP-Seq(GSE60143)/Homer(0.753)
# 		38 of 38 (1e-26) similar to At1g49010/MA1186.1/Jaspar(0.636)
# 	Job finished - if results look good, please send beer to ..
#
# 	Cleaning up tmp files...

# %%
#do the same for DM6_DM7
find_motifs_task_with_bg(os.path.join(DM6_DM7_dir, 'DiffPeakAnno_' + 'DM6_DM7' + '_Up.bed'),
                         os.path.join(DM6_DM7_dir, 'DiffPeakAnno_' + 'DM6_DM7' + '_Down.bed'),
                         genome_fa)
find_motifs_task_with_bg(os.path.join(DM6_DM7_dir, 'DiffPeakAnno_' + 'DM6_DM7' + '_Down.bed'),
                         os.path.join(DM6_DM7_dir, 'DiffPeakAnno_' + 'DM6_DM7' + '_Up.bed'),
                         genome_fa)
# Out:
# 	Position file = /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Up.bed
# 	Genome = /media/HDD2/Genomes/Ath_Ensembl56/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa
# 	Output Directory = /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Up_vs_DiffPeakAnno_DM6_DM7_Down
# 	background position file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Down.bed
# 	Using 20 CPUs
# 	Using Custom Genome
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 16
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 16
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 390
# 		peakfile formatted lines: 0
# 	66 duplicate peak IDs out of 390 total peaks
# 	Max distance to merge: 200 bp
# 	Calculating co-bound peaks relative to reference: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Up_vs_DiffPeakAnno_DM6_DM7_Down/bg.clean.pos
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 	**	/media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Up_vs_DiffPeakAnno_DM6_DM7_Down/target.clean..pos	0	0.00	0.00
#
# 	**	Pairwise stats are approx with fixed distance (-d 200) and -cobound #
# 		They get worse as the size increases and peaks from a single file start overlapping
# 		To get accurate ones, adjust peak sizes first with adjustPeakFile.pl and
# 		then rerun mergePeaks with the "-d given" option (only applies to -cobound #)
#
# 	Co-bound by 0 peaks: 390
# 	Co-bound by 1 peaks: 0 (max: 0 effective total)
# 	Custom genome sequence file: /media/HDD2/Genomes/Ath_Ensembl56/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa
#
# 	Extracting sequences from file: /media/HDD2/Genomes/Ath_Ensembl56/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa
# 	Looking for peak sequences in a single file (/media/HDD2/Genomes/Ath_Ensembl56/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa)
# 	Extracting 95 sequences from 1
# 	Extracting 73 sequences from 2
# 	Extracting 76 sequences from 3
# 	Extracting 71 sequences from 4
# 	Extracting 91 sequences from 5
#
# 	Not removing redundant sequences
#
#
# 	Sequences processed:
# 		Auto detected maximum sequence length of 201 bp
# 		406 total
#
# 	Frequency Bins: 0.2 0.25 0.3 0.35 0.4 0.45 0.5 0.6 0.7 0.8
# 	Freq	Bin	Count
# 	0.25	1	5
# 	0.3	2	65
# 	0.35	3	174
# 	0.4	4	124
# 	0.45	5	33
# 	0.5	6	4
# 	0.6	7	1
# 	Bin	# Targets	# Background	Background Weight
# 	2	1	64	0.371
# 	3	5	169	0.703
# 	4	7	117	1.421
# 	5	3	30	2.375
# 	Normalizing lower order oligos using homer2
#
# 	Reading input files...
# 	396 total sequences read
# 	Autonormalization: 1-mers (4 total)
# 		A	32.03%	32.01%	1.001
# 		C	17.97%	17.99%	0.999
# 		G	17.97%	17.99%	0.999
# 		T	32.03%	32.01%	1.001
# 	Autonormalization: 2-mers (16 total)
# 		AA	10.41%	10.96%	0.950
# 		CA	6.85%	6.72%	1.019
# 		GA	5.89%	6.25%	0.942
# 		TA	8.86%	8.07%	1.098
# 		AC	5.61%	5.64%	0.994
# 		CC	2.89%	3.61%	0.800
# 		GC	3.58%	2.49%	1.438
# 		TC	5.89%	6.25%	0.942
# 		AG	5.67%	5.53%	1.026
# 		CG	2.61%	2.13%	1.223
# 		GG	2.89%	3.61%	0.800
# 		TG	6.85%	6.72%	1.019
# 		AT	10.33%	9.90%	1.044
# 		CT	5.67%	5.53%	1.026
# 		GT	5.61%	5.64%	0.994
# 		TT	10.41%	10.96%	0.950
# 	Autonormalization: 3-mers (64 total)
# 	Normalization weights can be found in file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Up_vs_DiffPeakAnno_DM6_DM7_Down/seq.autonorm.tsv
# 	Converging on autonormalization solution:
# 	...............................................................................
# 	Final normalization:	Autonormalization: 1-mers (4 total)
# 		A	32.03%	32.32%	0.991
# 		C	17.97%	17.68%	1.016
# 		G	17.97%	17.68%	1.016
# 		T	32.03%	32.32%	0.991
# 	Autonormalization: 2-mers (16 total)
# 		AA	10.41%	10.91%	0.954
# 		CA	6.85%	6.73%	1.017
# 		GA	5.89%	5.92%	0.994
# 		TA	8.86%	8.75%	1.013
# 		AC	5.61%	5.67%	0.989
# 		CC	2.89%	3.19%	0.906
# 		GC	3.58%	2.89%	1.237
# 		TC	5.89%	5.92%	0.994
# 		AG	5.67%	5.38%	1.053
# 		CG	2.61%	2.38%	1.097
# 		GG	2.89%	3.19%	0.906
# 		TG	6.85%	6.73%	1.017
# 		AT	10.33%	10.38%	0.996
# 		CT	5.67%	5.38%	1.053
# 		GT	5.61%	5.67%	0.989
# 		TT	10.41%	10.91%	0.954
# 	Autonormalization: 3-mers (64 total)
# 	Finished preparing sequence/group files
#
# 	----------------------------------------------------------
# 	Known motif enrichment
#
# 	Reading input files...
# 	396 total sequences read
# 	506 motifs loaded
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 506 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Preparing HTML output with sequence logos...
# 		1 of 506 (1e-8) ERF13(AP2EREBP)/colamp-ERF13-DAP-Seq(GSE60143)/Homer
# 		2 of 506 (1e-7) WRKY18(WRKY)/col-WRKY18-DAP-Seq(GSE60143)/Homer
# 		3 of 506 (1e-6) WRKY15(WRKY)/col-WRKY15-DAP-Seq(GSE60143)/Homer
# 		4 of 506 (1e-6) WRKY75(WRKY)/col-WRKY75-DAP-Seq(GSE60143)/Homer
# 		5 of 506 (1e-5) ERF104(AP2EREBP)/col-ERF104-DAP-Seq(GSE60143)/Homer
# 		6 of 506 (1e-5) WRKY50(WRKY)/col-WRKY50-DAP-Seq(GSE60143)/Homer
# 		7 of 506 (1e-5) WRKY45(WRKY)/col-WRKY45-DAP-Seq(GSE60143)/Homer
# 		8 of 506 (1e-4) ERF105(AP2EREBP)/colamp-ERF105-DAP-Seq(GSE60143)/Homer
# 		9 of 506 (1e-4) ERF10(AP2EREBP)/col-ERF10-DAP-Seq(GSE60143)/Homer
# 		10 of 506 (1e-4) ERF1(AP2EREBP)/colamp-ERF1-DAP-Seq(GSE60143)/Homer
# 		11 of 506 (1e-4) ERF2(AP2EREBP)/colamp-ERF2-DAP-Seq(GSE60143)/Homer
# 		12 of 506 (1e-4) ERF3(AP2EREBP)/colamp-ERF3-DAP-Seq(GSE60143)/Homer
# 		13 of 506 (1e-4) WRKY14(WRKY)/colamp-WRKY14-DAP-Seq(GSE60143)/Homer
# 		14 of 506 (1e-4) WRKY29(WRKY)/colamp-WRKY29-DAP-Seq(GSE60143)/Homer
# 		15 of 506 (1e-4) WRKY3(WRKY)/col-WRKY3-DAP-Seq(GSE60143)/Homer
# 		16 of 506 (1e-4) WRKY65(WRKY)/colamp-WRKY65-DAP-Seq(GSE60143)/Homer
# 		17 of 506 (1e-4) AT5G23930(mTERF)/col-AT5G23930-DAP-Seq(GSE60143)/Homer
# 		18 of 506 (1e-4) RAP212(AP2EREBP)/col-RAP212-DAP-Seq(GSE60143)/Homer
# 		19 of 506 (1e-4) WRKY25(WRKY)/colamp-WRKY25-DAP-Seq(GSE60143)/Homer
# 		20 of 506 (1e-4) WRKY33(WRKY)/col-WRKY33-DAP-Seq(GSE60143)/Homer
# 		21 of 506 (1e-4) WRKY55(WRKY)/col-WRKY55-DAP-Seq(GSE60143)/Homer
# 		22 of 506 (1e-4) AT1G28160(AP2EREBP)/colamp-AT1G28160-DAP-Seq(GSE60143)/Homer
# 		23 of 506 (1e-4) ERF11(AP2EREBP)/col-ERF11-DAP-Seq(GSE60143)/Homer
# 		24 of 506 (1e-3) WRKY28(WRKY)/col-WRKY28-DAP-Seq(GSE60143)/Homer
# 		25 of 506 (1e-3) ABR1(AP2EREBP)/colamp-ABR1-DAP-Seq(GSE60143)/Homer
# 		26 of 506 (1e-3) ERF15(AP2EREBP)/colamp-ERF15-DAP-Seq(GSE60143)/Homer
# 		27 of 506 (1e-3) ERF4(AP2EREBP)/colamp-ERF4-DAP-Seq(GSE60143)/Homer
# 		28 of 506 (1e-3) ERF7(AP2EREBP)/col-ERF7-DAP-Seq(GSE60143)/Homer
# 		29 of 506 (1e-3) WRKY6(WRKY)/colamp-WRKY6-DAP-Seq(GSE60143)/Homer
# 		30 of 506 (1e-3) ERF8(AP2EREBP)/colamp-ERF8-DAP-Seq(GSE60143)/Homer
# 		31 of 506 (1e-3) RAP26(AP2EREBP)/colamp-RAP26-DAP-Seq(GSE60143)/Homer
# 		32 of 506 (1e-3) WRKY24(WRKY)/colamp-WRKY24-DAP-Seq(GSE60143)/Homer
# 		33 of 506 (1e-3) WRKY31(WRKY)/colamp-WRKY31-DAP-Seq(GSE60143)/Homer
# 		34 of 506 (1e-3) WRKY71(WRKY)/col-WRKY71-DAP-Seq(GSE60143)/Homer
# 		35 of 506 (1e-2) AT4G18450(AP2EREBP)/col-AT4G18450-DAP-Seq(GSE60143)/Homer
# 		36 of 506 (1e-2) CRF4(AP2EREBP)/colamp-CRF4-DAP-Seq(GSE60143)/Homer
# 		37 of 506 (1e-2) ERF5(AP2EREBP)/colamp-ERF5-DAP-Seq(GSE60143)/Homer
# 		38 of 506 (1e-2) ESE1(AP2EREBP)/col-ESE1-DAP-Seq(GSE60143)/Homer
# 		39 of 506 (1e-2) WRKY22(WRKY)/colamp-WRKY22-DAP-Seq(GSE60143)/Homer
# 		40 of 506 (1e-2) At2g33710(AP2EREBP)/colamp-At2g33710-DAP-Seq(GSE60143)/Homer
# 		41 of 506 (1e-2) WRKY20(WRKY)/col-WRKY20-DAP-Seq(GSE60143)/Homer
# 		42 of 506 (1e-2) LBD23(LOBAS2)/colamp-LBD23-DAP-Seq(GSE60143)/Homer
# 		43 of 506 (1e-2) RAP211(AP2EREBP)/colamp-RAP211-DAP-Seq(GSE60143)/Homer
# 		44 of 506 (1e-2) ERF115(AP2EREBP)/colamp-ERF115-DAP-Seq(GSE60143)/Homer
# 		45 of 506 (1e-2) At5g29000(G2like)/col-At5g29000-DAP-Seq(GSE60143)/Homer
# 	----------------------------------------------------------
# 	De novo motif finding (HOMER)
#
# 	Number of Trial motifs (-T) set to 20 (from 10) to work well with 20 CPUs
# 	Scanning input files...
# 	Parsing sequences...
# 	|0%                                   50%                                  100%|
# 	==================================================================================================
# 	Total number of Oligos: 21761
# 	Autoadjustment for sequence coverage in background: 1.00x
#
# 	Oligos: 21761 of 34497 max
# 	Tree  : 47564 of 172485 max
# 	Optimizing memory usage...
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Global Optimization Phase: Looking for enriched oligos with up to 2 mismatches...
#
# 	Screening oligos 21761 (allowing 0 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		87.06% skipped, 12.94% checked (2815 of 21761), of those checked:
# 		87.06% not in target, 0.00% increased p-value, 0.00% high p-value
#
# 	Screening oligos 21761 (allowing 1 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		87.06% skipped, 12.94% checked (2815 of 21761), of those checked:
# 		0.00% not in target, 11.65% increased p-value, 2.01% high p-value
#
# 	Screening oligos 21761 (allowing 2 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		98.84% skipped, 1.16% checked (252 of 21761), of those checked:
# 		0.00% not in target, 1.15% increased p-value, 0.00% high p-value
# 	Reading input files...
# 	396 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Local Optimization Phase:
# 	1 of 25 Initial Sequence: TCAAAATG... (-15.779)
# 		Round 1: -15.78 TCAAAATG T:5.0(27.58%),B:1.3(0.30%),P:1e-6
# 		Round 2: -15.78 TCAAAATG T:5.0(27.58%),B:1.3(0.30%),P:1e-6
# 		=Final=: -11.14 TCAAAATG T:3.0(18.75%),B:1.3(0.40%),P:1e-4
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	2 of 25 Initial Sequence: ATTGACTT... (-11.144)
# 		Round 1: -17.90 ATTGACTT T:9.0(44.06%),B:8.9(2.36%),P:1e-7
# 		Round 2: -17.90 ATTGACTT T:9.0(44.06%),B:8.9(2.36%),P:1e-7
# 		=Final=: -17.68 ATTGACTT T:6.0(37.50%),B:4.5(1.35%),P:1e-7
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	3 of 25 Initial Sequence: GCATAATT... (-11.144)
# 		Round 1: -13.03 GCATAATT T:5.0(27.58%),B:3.5(0.89%),P:1e-5
# 		Round 2: -13.03 GCATAATT T:5.0(27.58%),B:3.5(0.89%),P:1e-5
# 		=Final=: -15.78 GCATAATT T:4.0(25.00%),B:1.3(0.39%),P:1e-6
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	4 of 25 Initial Sequence: GGGCTGCT... (-11.144)
# 		Round 1: -17.90 NGGCTGCT T:9.0(44.06%),B:8.6(2.36%),P:1e-7
# 		Round 2: -17.90 NGGCTGCT T:9.0(44.06%),B:8.6(2.36%),P:1e-7
# 		=Final=: -20.21 NGGCTGCT T:7.0(43.75%),B:5.4(1.61%),P:1e-8
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	5 of 25 Initial Sequence: ATCTTGAC... (-9.093)
# 		Round 1: -17.68 ATCTTGAC T:8.0(40.33%),B:5.7(1.48%),P:1e-7
# 		Round 2: -20.59 RYCKTGAM T:11.0(50.83%),B:9.3(2.65%),P:1e-8
# 		Round 3: -20.59 RYCKTGAM T:11.0(50.83%),B:9.3(2.65%),P:1e-8
# 		=Final=: -22.45 RYCKTGAM T:9.0(56.25%),B:10.2(3.06%),P:1e-9
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	Remaining seeds don't look promising (After initial 5 motifs, logp -6.869 > -7.204)
#
# 	Finalizing Enrichment Statistics (new in v3.4)
# 	Reading input files...
# 	396 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 5 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Output in file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Up_vs_DiffPeakAnno_DM6_DM7_Down/homerMotifs.motifs8
#
#
# 	Number of Trial motifs (-T) set to 20 (from 10) to work well with 20 CPUs
# 	Scanning input files...
# 	Parsing sequences...
# 	|0%                                   50%                                  100%|
# 	==================================================================================================
# 	Total number of Oligos: 59758
# 	Autoadjustment for sequence coverage in background: 1.00x
#
# 	Oligos: 59758 of 76032 max
# 	Tree  : 156784 of 380160 max
# 	Optimizing memory usage...
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Global Optimization Phase: Looking for enriched oligos with up to 2 mismatches...
#
# 	Screening oligos 59758 (allowing 0 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		94.91% skipped, 5.09% checked (3040 of 59758), of those checked:
# 		94.91% not in target, 0.00% increased p-value, 0.00% high p-value
#
# 	Screening oligos 59758 (allowing 1 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		94.91% skipped, 5.09% checked (3040 of 59758), of those checked:
# 		0.00% not in target, 4.66% increased p-value, 0.01% high p-value
#
# 	Screening oligos 59758 (allowing 2 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		99.58% skipped, 0.42% checked (253 of 59758), of those checked:
# 		0.00% not in target, 0.40% increased p-value, 0.00% high p-value
# 	Reading input files...
# 	396 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Local Optimization Phase:
# 	1 of 25 Initial Sequence: GGGCTGCTGT... (-11.442)
# 		Round 1: -15.78 GGGCTGCTGT T:5.0(27.58%),B:0.4(0.00%),P:1e-6
# 		Round 2: -20.72 TTGCTGCTTC T:6.0(32.11%),B:2.5(0.60%),P:1e-8
# 		Round 3: -20.72 TTGCTGCTTC T:6.0(32.11%),B:2.5(0.60%),P:1e-8
# 		=Final=: -17.28 TTGCTGCTTC T:5.0(31.25%),B:2.5(0.73%),P:1e-7
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	2 of 25 Initial Sequence: AGCCGCCTTG... (-11.442)
# 		Round 1: -21.74 AGCCGCCTTG T:9.0(44.06%),B:5.2(1.48%),P:1e-9
# 		Round 2: -21.74 AGCCGCCTTG T:9.0(44.06%),B:5.2(1.48%),P:1e-9
# 		=Final=: -25.92 AGCCGCCTTG T:6.0(37.50%),B:1.9(0.58%),P:1e-11
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	3 of 25 Initial Sequence: CCATTTTGAG... (-11.144)
# 		Round 1: -20.72 CAATTTTGAG T:6.0(32.11%),B:2.6(0.60%),P:1e-8
# 		Round 2: -20.72 CAATTTTGAG T:6.0(32.11%),B:2.6(0.60%),P:1e-8
# 		=Final=: -13.03 CAATTTTGAG T:4.0(25.00%),B:2.6(0.77%),P:1e-5
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	4 of 25 Initial Sequence: CAATTGACTT... (-10.512)
# 		Round 1: -15.78 CAATTGACTT T:5.0(27.58%),B:0.0(0.00%),P:1e-6
# 		Round 2: -15.78 CAATTGACTT T:5.0(27.58%),B:0.0(0.00%),P:1e-6
# 		=Final=: -11.14 CAATTGACTT T:3.0(18.75%),B:0.0(0.00%),P:1e-4
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	5 of 25 Initial Sequence: ATATGTCATT... (-7.220)
# 		Round 1: -11.89 ATATGTCATT T:6.0(32.11%),B:7.4(2.07%),P:1e-5
# 		Round 2: -20.72 DTATGTCATT T:6.0(32.11%),B:1.3(0.30%),P:1e-8
# 		Round 3: -20.72 DTATGTCATT T:6.0(32.11%),B:1.3(0.30%),P:1e-8
# 		=Final=: -15.78 DTATGTCATT T:4.0(25.00%),B:1.3(0.39%),P:1e-6
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	Remaining seeds don't look promising (After initial 5 motifs, logp -7.072 > -7.204)
#
# 	Finalizing Enrichment Statistics (new in v3.4)
# 	Reading input files...
# 	396 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 5 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Output in file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Up_vs_DiffPeakAnno_DM6_DM7_Down/homerMotifs.motifs10
#
#
# 	Number of Trial motifs (-T) set to 20 (from 10) to work well with 20 CPUs
# 	-blen automatically set to 2
# 	Scanning input files...
# 	Parsing sequences...
# 	|0%                                   50%                                  100%|
# 	==================================================================================================
# 	Total number of Oligos: 72467
# 	Autoadjustment for sequence coverage in background: 1.00x
#
# 	Oligos: 72467 of 75240 max
# 	Tree  : 214804 of 376200 max
# 	Optimizing memory usage...
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Global Optimization Phase: Looking for enriched oligos with up to 2 mismatches...
#
# 	Screening oligos 72467 (allowing 0 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		95.81% skipped, 4.19% checked (3036 of 72467), of those checked:
# 		95.81% not in target, 0.00% increased p-value, 0.00% high p-value
#
# 	Screening oligos 72467 (allowing 1 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		95.81% skipped, 4.19% checked (3036 of 72467), of those checked:
# 		0.00% not in target, 1.96% increased p-value, 0.00% high p-value
#
# 	Screening oligos 72467 (allowing 2 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		97.77% skipped, 2.23% checked (1619 of 72467), of those checked:
# 		0.00% not in target, 2.04% increased p-value, 0.00% high p-value
# 	Reading input files...
# 	396 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Local Optimization Phase:
# 	1 of 25 Initial Sequence: GCCGTCTCAAAA... (-11.144)
# 		Round 1: -20.72 GCCKTMTCAAAA T:6.0(32.11%),B:1.4(0.30%),P:1e-8
# 		Round 2: -20.72 GCCKTMTCAAAA T:6.0(32.11%),B:1.4(0.30%),P:1e-8
# 		=Final=: -20.72 GCCKTMTCAAAA T:5.0(31.25%),B:1.4(0.42%),P:1e-8
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	2 of 25 Initial Sequence: TCAATTGACTTA... (-8.596)
# 		Round 1: -20.72 TCAATTGACTTA T:6.0(32.11%),B:1.2(0.30%),P:1e-8
# 		Round 2: -20.72 TCAATTGACTTA T:6.0(32.11%),B:1.2(0.30%),P:1e-8
# 		=Final=: -15.78 TCAATTGACTTA T:4.0(25.00%),B:1.2(0.37%),P:1e-6
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	3 of 25 Initial Sequence: ATCTATTATCTA... (-6.869)
# 		Round 1: -9.46 ATCTATTATCTA T:5.0(27.58%),B:6.2(1.78%),P:1e-4
# 		Round 2: -15.78 ATGTATATTCTA T:5.0(27.58%),B:2.4(0.60%),P:1e-6
# 		Round 3: -17.28 ACCTATGTTCTA T:6.0(32.11%),B:3.4(0.89%),P:1e-7
# 		Round 4: -20.72 AWSTMWKWTCTM T:6.0(32.11%),B:2.8(0.60%),P:1e-8
# 		Round 5: -20.72 AWSTMWKWTCTM T:6.0(32.11%),B:2.8(0.60%),P:1e-8
# 		=Final=: -17.28 AWSTMWKWTCTM T:5.0(31.25%),B:2.5(0.75%),P:1e-7
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	4 of 25 Initial Sequence: CATGCGCATTCG... (-6.869)
# 		Round 1: -7.32 CATGCGMATWCG T:9.0(44.06%),B:38.2(10.73%),P:1e-3
# 		Round 2: -20.72 TATGCGCATKCG T:6.0(32.11%),B:2.7(0.60%),P:1e-8
# 		Round 3: -20.72 TATGCGCATKCG T:6.0(32.11%),B:2.7(0.60%),P:1e-8
# 		=Final=: -9.09 TATGCGCATKCG T:3.0(18.75%),B:2.1(0.62%),P:1e-3
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	5 of 25 Initial Sequence: AAACGCGTCTAT... (-6.869)
# 		Round 1: -11.14 AGAAGCCTCTAT T:4.0(22.75%),B:0.0(0.00%),P:1e-4
# 		Round 2: -11.89 AGCAGCCTCTTT T:6.0(32.11%),B:7.3(2.07%),P:1e-5
# 		Round 3: -17.90 ARCMGCMKYRWK T:9.0(44.06%),B:8.2(2.36%),P:1e-7
# 		Round 4: -17.90 ARCMGCMKYRWK T:9.0(44.06%),B:8.2(2.36%),P:1e-7
# 		=Final=: -20.59 ARCMGCMKYRWK T:8.0(50.00%),B:8.2(2.45%),P:1e-8
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	Remaining seeds don't look promising (After initial 5 motifs, logp -6.869 > -7.204)
#
# 	Finalizing Enrichment Statistics (new in v3.4)
# 	Reading input files...
# 	396 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 5 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Output in file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Up_vs_DiffPeakAnno_DM6_DM7_Down/homerMotifs.motifs12
#
# 	(Motifs in homer2 format)
# 	Determining similar motifs... 15 reduced to 8 motifs
# 	Outputing HTML and sequence logos for motif comparison...
# 	Checking de novo motifs against known motifs...
# 	Formatting HTML page...
# 		1 of 8 (1e-11) similar to ERF15(AP2EREBP)/colamp-ERF15-DAP-Seq(GSE60143)/Homer(0.751)
# 		2 of 8 (1e-9) similar to WRKY18/MA1077.1/Jaspar(0.730)
# 		3 of 8 (1e-8) similar to At2g41835(C2H2)/col-At2g41835-DAP-Seq(GSE60143)/Homer(0.634)
# 		4 of 8 (1e-7) similar to WRKY50(WRKY)/col-WRKY50-DAP-Seq(GSE60143)/Homer(0.858)
# 		5 of 8 (1e-7) similar to ERF15(AP2EREBP)/colamp-ERF15-DAP-Seq(GSE60143)/Homer(0.617)
# 		6 of 8 (1e-7) similar to AGP1(GATA)/Nicotiana tabacum/AthaMap(0.588)
# 		7 of 8 (1e-6) similar to ATHB-6/MA0953.1/Jaspar(0.764)
# 		8 of 8 (1e-3) similar to LEC2/MA0581.1/Jaspar(0.665)
# 	Job finished - if results look good, please send beer to ..
#
# 	Cleaning up tmp files...
#
#
#
#
# 	Position file = /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Down.bed
# 	Genome = /media/HDD2/Genomes/Ath_Ensembl56/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa
# 	Output Directory = /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Down_vs_DiffPeakAnno_DM6_DM7_Up
# 	background position file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Up.bed
# 	Using 20 CPUs
# 	Using Custom Genome
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 390
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 390
# 		Redundant Peak IDs: 66
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Redunant Peaks found: Remove or rename these or some programs may have trouble...
#
# 	66 duplicate peak IDs out of 390 total peaks
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 16
# 		peakfile formatted lines: 0
# 	Max distance to merge: 200 bp
# 	Calculating co-bound peaks relative to reference: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Down_vs_DiffPeakAnno_DM6_DM7_Up/bg.clean.pos
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 	**	/media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Down_vs_DiffPeakAnno_DM6_DM7_Up/target.clean..pos	0	0.00	0.00
#
# 	**	Pairwise stats are approx with fixed distance (-d 200) and -cobound #
# 		They get worse as the size increases and peaks from a single file start overlapping
# 		To get accurate ones, adjust peak sizes first with adjustPeakFile.pl and
# 		then rerun mergePeaks with the "-d given" option (only applies to -cobound #)
#
# 	Co-bound by 0 peaks: 16
# 	Co-bound by 1 peaks: 0 (max: 0 effective total)
# 	Custom genome sequence file: /media/HDD2/Genomes/Ath_Ensembl56/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa
#
# 	Extracting sequences from file: /media/HDD2/Genomes/Ath_Ensembl56/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa
# 	Looking for peak sequences in a single file (/media/HDD2/Genomes/Ath_Ensembl56/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa)
# 	Extracting 95 sequences from 1
# 	Extracting 73 sequences from 2
# 	Extracting 76 sequences from 3
# 	Extracting 71 sequences from 4
# 	Extracting 91 sequences from 5
#
# 	Not removing redundant sequences
#
#
# 	Sequences processed:
# 		Auto detected maximum sequence length of 201 bp
# 		406 total
#
# 	Frequency Bins: 0.2 0.25 0.3 0.35 0.4 0.45 0.5 0.6 0.7 0.8
# 	Freq	Bin	Count
# 	0.25	1	5
# 	0.3	2	65
# 	0.35	3	174
# 	0.4	4	124
# 	0.45	5	33
# 	0.5	6	4
# 	0.6	7	1
# 	Bin	# Targets	# Background	Background Weight
# 	2	64	1	2.695
# 	3	169	5	1.423
# 	4	117	7	0.704
# 	5	30	3	0.421
# 	Normalizing lower order oligos using homer2
#
# 	Reading input files...
# 	396 total sequences read
# 	Autonormalization: 1-mers (4 total)
# 		A	33.01%	32.89%	1.004
# 		C	16.99%	17.11%	0.993
# 		G	16.99%	17.11%	0.993
# 		T	33.01%	32.89%	1.004
# 	Autonormalization: 2-mers (16 total)
# 		AA	11.63%	10.94%	1.063
# 		CA	6.65%	6.62%	1.004
# 		GA	5.96%	5.58%	1.068
# 		TA	8.76%	9.72%	0.901
# 		AC	5.49%	5.67%	0.969
# 		CC	3.24%	2.52%	1.287
# 		GC	2.30%	3.33%	0.691
# 		TC	5.96%	5.58%	1.068
# 		AG	5.23%	5.57%	0.940
# 		CG	1.86%	2.41%	0.773
# 		GG	3.24%	2.52%	1.287
# 		TG	6.65%	6.62%	1.004
# 		AT	10.67%	10.74%	0.993
# 		CT	5.23%	5.57%	0.940
# 		GT	5.49%	5.67%	0.969
# 		TT	11.63%	10.94%	1.063
# 	Autonormalization: 3-mers (64 total)
# 	Normalization weights can be found in file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Down_vs_DiffPeakAnno_DM6_DM7_Up/seq.autonorm.tsv
# 	Converging on autonormalization solution:
# 	...............................................................................
# 	Final normalization:	Autonormalization: 1-mers (4 total)
# 		A	33.01%	32.52%	1.015
# 		C	16.99%	17.48%	0.972
# 		G	16.99%	17.48%	0.972
# 		T	33.01%	32.52%	1.015
# 	Autonormalization: 2-mers (16 total)
# 		AA	11.63%	10.98%	1.060
# 		CA	6.65%	6.63%	1.002
# 		GA	5.96%	6.03%	0.987
# 		TA	8.76%	8.84%	0.991
# 		AC	5.49%	5.54%	0.990
# 		CC	3.24%	2.93%	1.106
# 		GC	2.30%	2.95%	0.779
# 		TC	5.96%	6.03%	0.987
# 		AG	5.23%	5.56%	0.940
# 		CG	1.86%	2.37%	0.785
# 		GG	3.24%	2.93%	1.106
# 		TG	6.65%	6.63%	1.002
# 		AT	10.67%	10.46%	1.020
# 		CT	5.23%	5.56%	0.940
# 		GT	5.49%	5.54%	0.990
# 		TT	11.63%	10.98%	1.060
# 	Autonormalization: 3-mers (64 total)
# 	Finished preparing sequence/group files
#
# 	----------------------------------------------------------
# 	Known motif enrichment
#
# 	Reading input files...
# 	396 total sequences read
# 	506 motifs loaded
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 506 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Preparing HTML output with sequence logos...
# 		1 of 506 (1e-64) IDD4(C2H2)/col-IDD4-DAP-Seq(GSE60143)/Homer
# 		2 of 506 (1e-57) OBP4(C2C2dof)/col-OBP4-DAP-Seq(GSE60143)/Homer
# 		3 of 506 (1e-52) dof45(C2C2dof)/col-dof45-DAP-Seq(GSE60143)/Homer
# 		4 of 506 (1e-48) Adof1(C2C2dof)/col-Adof1-DAP-Seq(GSE60143)/Homer
# 		5 of 506 (1e-46) IDD5(C2H2)/colamp-IDD5-DAP-Seq(GSE60143)/Homer
# 		6 of 506 (1e-45) dof24(C2C2dof)/col-dof24-DAP-Seq(GSE60143)/Homer
# 		7 of 506 (1e-42) SPCH(bHLH)/Seedling-SPCH-ChIP-Seq(GSE57497)/Homer
# 		8 of 506 (1e-41) PIF4(bHLH)/Seedling-PIF4-ChIP-Seq(GSE35315)/Homer
# 		9 of 506 (1e-36) AT5G66940(C2C2dof)/col-AT5G66940-DAP-Seq(GSE60143)/Homer
# 		10 of 506 (1e-36) LHY(Myb)/Seedling-LHY-ChIP-Seq(GSE52175)/Homer
# 		11 of 506 (1e-33) BIM2(bHLH)/col-BIM2-DAP-Seq(GSE60143)/Homer
# 		12 of 506 (1e-33) PIF5ox(bHLH)/Arabidopsis-PIF5ox-ChIP-Seq(GSE35062)/Homer
# 		13 of 506 (1e-30) IBL1(bHLH)/Seedling-IBL1-ChIP-Seq(GSE51120)/Homer
# 		14 of 506 (1e-29) At3g45610(C2C2dof)/col-At3g45610-DAP-Seq(GSE60143)/Homer
# 		15 of 506 (1e-28) AT2G20110(CPP)/colamp-AT2G20110-DAP-Seq(GSE60143)/Homer
# 		16 of 506 (1e-28) SPL15(SBP)/colamp-SPL15-DAP-Seq(GSE60143)/Homer
# 		17 of 506 (1e-28) AT5G02460(C2C2dof)/col-AT5G02460-DAP-Seq(GSE60143)/Homer
# 		18 of 506 (1e-28) CCA(Myb)/Arabidopsis-CCA.GFP-ChIP-Seq(GSE70533)/Homer
# 		19 of 506 (1e-27) DAG2(C2C2dof)/col-DAG2-DAP-Seq(GSE60143)/Homer
# 		20 of 506 (1e-26) AT1G47655(C2C2dof)/colamp-AT1G47655-DAP-Seq(GSE60143)/Homer
# 		21 of 506 (1e-26) MYB83(MYB)/colamp-MYB83-DAP-Seq(GSE60143)/Homer
# 		22 of 506 (1e-26) KANADI1(Myb)/Seedling-KAN1-ChIP-Seq(GSE48081)/Homer
# 		23 of 506 (1e-23) AT1G49560(G2like)/colamp-AT1G49560-DAP-Seq(GSE60143)/Homer
# 		24 of 506 (1e-22) FUS3(ABI3VP1)/col-FUS3-DAP-Seq(GSE60143)/Homer
# 		25 of 506 (1e-20) MYB107(MYB)/col-MYB107-DAP-Seq(GSE60143)/Homer
# 		26 of 506 (1e-20) AT5G63260(C3H)/col-AT5G63260-DAP-Seq(GSE60143)/Homer
# 		27 of 506 (1e-20) AT2G38300(G2like)/col-AT2G38300-DAP-Seq(GSE60143)/Homer
# 		28 of 506 (1e-19) SEP3(MADS)/Arabidoposis-Flower-Sep3-ChIP-Seq/Homer
# 		29 of 506 (1e-19) AT5G47660(Trihelix)/colamp-AT5G47660-DAP-Seq(GSE60143)/Homer
# 		30 of 506 (1e-19) KAN2(G2like)/colamp-KAN2-DAP-Seq(GSE60143)/Homer
# 		31 of 506 (1e-19) RVE1(MYBrelated)/col-RVE1-DAP-Seq(GSE60143)/Homer
# 		32 of 506 (1e-18) ATHB34(ZFHD)/colamp-ATHB34-DAP-Seq(GSE60143)/Homer
# 		33 of 506 (1e-18) LBD18(LOBAS2)/colamp-LBD18-DAP-Seq(GSE60143)/Homer
# 		34 of 506 (1e-18) MYB70(MYB)/col-MYB70-DAP-Seq(GSE60143)/Homer
# 		35 of 506 (1e-16) At1g74840(MYBrelated)/col100-At1g74840-DAP-Seq(GSE60143)/Homer
# 		36 of 506 (1e-16) MYB3(MYB)/Arabidopsis-MYB3-ChIP-Seq(GSE80564)/Homer
# 		37 of 506 (1e-16) MYB61(MYB)/colamp-MYB61-DAP-Seq(GSE60143)/Homer
# 		38 of 506 (1e-15) HY5(bZIP)/colamp-HY5-DAP-Seq(GSE60143)/Homer
# 		39 of 506 (1e-15) At4g38000(C2C2dof)/col-At4g38000-DAP-Seq(GSE60143)/Homer
# 		40 of 506 (1e-14) OBP1(C2C2dof)/col-OBP1-DAP-Seq(GSE60143)/Homer
# 		41 of 506 (1e-14) At4g01280(MYBrelated)/colamp-At4g01280-DAP-Seq(GSE60143)/Homer
# 		42 of 506 (1e-13) AT3G51470(DBP)/col-AT3G51470-DAP-Seq(GSE60143)/Homer
# 		43 of 506 (1e-13) GTL1(Trihelix)/colamp-GTL1-DAP-Seq(GSE60143)/Homer
# 		44 of 506 (1e-13) At1g64620(C2C2dof)/colamp-At1g64620-DAP-Seq(GSE60143)/Homer
# 		45 of 506 (1e-13) MYB113(MYB)/col-MYB113-DAP-Seq(GSE60143)/Homer
# 		46 of 506 (1e-13) NLP7(RWPRK)/col-NLP7-DAP-Seq(GSE60143)/Homer
# 		47 of 506 (1e-12) AGL63(MADS)/col-AGL63-DAP-Seq(GSE60143)/Homer
# 		48 of 506 (1e-12) MYB49(MYB)/col-MYB49-DAP-Seq(GSE60143)/Homer
# 		49 of 506 (1e-11) At5g52660(MYBrelated)/colamp-At5g52660-DAP-Seq(GSE60143)/Homer
# 		50 of 506 (1e-11) MS188(MYB)/colamp-MS188-DAP-Seq(GSE60143)/Homer
# 		51 of 506 (1e-11) MYB62(MYB)/colamp-MYB62-DAP-Seq(GSE60143)/Homer
# 		52 of 506 (1e-10) TCX2(CPP)/colamp-TCX2-DAP-Seq(GSE60143)/Homer
# 		53 of 506 (1e-10) Unknown4/Arabidopsis-Promoters/Homer
# 		54 of 506 (1e-10) SOL1(CPP)/colamp-SOL1-DAP-Seq(GSE60143)/Homer
# 		55 of 506 (1e-10) At3g09600(MYBrelated)/colamp-At3g09600-DAP-Seq(GSE60143)/Homer
# 		56 of 506 (1e-10) TCP3(TCP)/colamp-TCP3-DAP-Seq(GSE60143)/Homer
# 		57 of 506 (1e-9) OBP3(C2C2dof)/col-OBP3-DAP-Seq(GSE60143)/Homer
# 		58 of 506 (1e-8) NAP(NAC)/col-NAP-DAP-Seq(GSE60143)/Homer
# 		59 of 506 (1e-8) GAGA-repeat/Arabidopsis-Promoters/Homer
# 		60 of 506 (1e-7) SPL1(SBP)/colamp-SPL1-DAP-Seq(GSE60143)/Homer
# 		61 of 506 (1e-7) AT3G10113(MYBrelated)/col-AT3G10113-DAP-Seq(GSE60143)/Homer
# 		62 of 506 (1e-7) At3g60580(C2H2)/col-At3g60580-DAP-Seq(GSE60143)/Homer
# 		63 of 506 (1e-7) At1g25550(G2like)/colamp-At1g25550-DAP-Seq(GSE60143)/Homer
# 		64 of 506 (1e-7) MYB55(MYB)/colamp-MYB55-DAP-Seq(GSE60143)/Homer
# 		65 of 506 (1e-7) MYB93(MYB)/colamp-MYB93-DAP-Seq(GSE60143)/Homer
# 		66 of 506 (1e-7) MYB81(MYB)/col-MYB81-DAP-Seq(GSE60143)/Homer
# 		67 of 506 (1e-6) ATY13(MYB)/col-ATY13-DAP-Seq(GSE60143)/Homer
# 		68 of 506 (1e-6) GATA15(C2C2gata)/col-GATA15-DAP-Seq(GSE60143)/Homer
# 		69 of 506 (1e-6) ATHB20(Homeobox)/colamp-ATHB20-DAP-Seq(GSE60143)/Homer
# 		70 of 506 (1e-6) JGL(C2H2)/col-JGL-DAP-Seq(GSE60143)/Homer
# 		71 of 506 (1e-6) MYB77(MYB)/col-MYB77-DAP-Seq(GSE60143)/Homer
# 		72 of 506 (1e-5) RAV1(RAV)/colamp-RAV1-DAP-Seq(GSE60143)/Homer
# 		73 of 506 (1e-5) BPC1(BBRBPC)/colamp-BPC1-DAP-Seq(GSE60143)/Homer
# 		74 of 506 (1e-5) At5g58900(MYBrelated)/colamp-At5g58900-DAP-Seq(GSE60143)/Homer
# 		75 of 506 (1e-5) ABF1(bZIP)/Arabidopsis-ABF1-ChIP-Seq(GSE80564)/Homer
# 		76 of 506 (1e-5) At1g68670(G2like)/colamp-At1g68670-DAP-Seq(GSE60143)/Homer
# 		77 of 506 (1e-5) AT4G26030(C2H2)/col-AT4G26030-DAP-Seq(GSE60143)/Homer
# 		78 of 506 (1e-5) EPR1(MYBrelated)/colamp-EPR1-DAP-Seq(GSE60143)/Homer
# 		79 of 506 (1e-5) LHY1(MYBrelated)/col-LHY1-DAP-Seq(GSE60143)/Homer
# 		80 of 506 (1e-5) REM19(REM)/colamp-REM19-DAP-Seq(GSE60143)/Homer
# 		81 of 506 (1e-4) MYB67(MYB)/col-MYB67-DAP-Seq(GSE60143)/Homer
# 		82 of 506 (1e-4) MYB96(MYB)/colamp-MYB96-DAP-Seq(GSE60143)/Homer
# 		83 of 506 (1e-4) GT2(Trihelix)/colamp-GT2-DAP-Seq(GSE60143)/Homer
# 		84 of 506 (1e-4) ANAC038(NAC)/col-ANAC038-DAP-Seq(GSE60143)/Homer
# 		85 of 506 (1e-4) MYB58(MYB)/colamp-MYB58-DAP-Seq(GSE60143)/Homer
# 		86 of 506 (1e-4) AT2G40260(G2like)/colamp-AT2G40260-DAP-Seq(GSE60143)/Homer
# 		87 of 506 (1e-4) RIN(MADS)/Tomato-RIN-ChIP-Seq(GSE116581)/Homer
# 		88 of 506 (1e-4) ANL2(HB)/col-ANL2-DAP-Seq(GSE60143)/Homer
# 		89 of 506 (1e-3) MYB4(MYB)/col200-MYB4-DAP-Seq(GSE60143)/Homer
# 		90 of 506 (1e-3) ATHB24(ZFHD)/colamp-ATHB24-DAP-Seq(GSE60143)/Homer
# 		91 of 506 (1e-3) MYB105(MYB)/colamp-MYB105-DAP-Seq(GSE60143)/Homer
# 		92 of 506 (1e-3) MYB74(MYB)/colamp-MYB74-DAP-Seq(GSE60143)/Homer
# 		93 of 506 (1e-3) MYB99(MYB)/colamp-MYB99-DAP-Seq(GSE60143)/Homer
# 		94 of 506 (1e-3) SPL11(SBP)/col100-SPL11-DAP-Seq(GSE60143)/Homer
# 		95 of 506 (1e-3) TF3A(C2H2)/col-TF3A-DAP-Seq(GSE60143)/Homer
# 		96 of 506 (1e-2) AT2G28810(C2C2dof)/colamp-AT2G28810-DAP-Seq(GSE60143)/Homer
# 		97 of 506 (1e-2) At5g62940(C2C2dof)/col-At5g62940-DAP-Seq(GSE60143)/Homer
# 		98 of 506 (1e-2) AT3G25990(Trihelix)/colamp-AT3G25990-DAP-Seq(GSE60143)/Homer
# 		99 of 506 (1e-2) bZIP3(bZIP)/col-bZIP3-DAP-Seq(GSE60143)/Homer
# 		100 of 506 (1e-2) SGR5(C2H2)/colamp-SGR5-DAP-Seq(GSE60143)/Homer
# 		101 of 506 (1e-2) MYB101(MYB)/colamp-MYB101-DAP-Seq(GSE60143)/Homer
# 		102 of 506 (1e-2) SPL5(SBP)/colamp-SPL5-DAP-Seq(GSE60143)/Homer
# 		103 of 506 (1e-2) ANAC046(NAC)/colamp-ANAC046-DAP-Seq(GSE60143)/Homer
# 		104 of 506 (1e-2) ASHR1(ND)/col-ASHR1-DAP-Seq(GSE60143)/Homer
# 		105 of 506 (1e-2) AT1G04880(ARID)/colamp-AT1G04880-DAP-Seq(GSE60143)/Homer
# 		106 of 506 (1e-2) BOS1(MYB)/col-BOS1-DAP-Seq(GSE60143)/Homer
# 		107 of 506 (1e-2) PHV(HB)/col-PHV-DAP-Seq(GSE60143)/Homer
# 	----------------------------------------------------------
# 	De novo motif finding (HOMER)
#
# 	Number of Trial motifs (-T) set to 20 (from 10) to work well with 20 CPUs
# 	Scanning input files...
# 	Parsing sequences...
# 	|0%                                   50%                                  100%|
# 	==================================================================================================
# 	Total number of Oligos: 21761
# 	Autoadjustment for sequence coverage in background: 1.00x
#
# 	Oligos: 21761 of 34497 max
# 	Tree  : 47564 of 172485 max
# 	Optimizing memory usage...
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Global Optimization Phase: Looking for enriched oligos with up to 2 mismatches...
#
# 	Screening oligos 21761 (allowing 0 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		2.19% skipped, 97.81% checked (21284 of 21761), of those checked:
# 		2.19% not in target, 0.00% increased p-value, 0.00% high p-value
#
# 	Screening oligos 21761 (allowing 1 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		2.19% skipped, 97.81% checked (21284 of 21761), of those checked:
# 		0.00% not in target, 7.13% increased p-value, 41.38% high p-value
#
# 	Screening oligos 21761 (allowing 2 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		43.60% skipped, 56.40% checked (12274 of 21761), of those checked:
# 		0.00% not in target, 42.44% increased p-value, 0.00% high p-value
# 	Reading input files...
# 	396 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Local Optimization Phase:
# 	1 of 25 Initial Sequence: CATGAGGA... (-489.209)
# 		Round 1: -498.21 AATAAAAA T:443.0(68.88%),B:1.1(6.18%),P:1e-216
# 		Round 2: -681.23 AAATAAAA T:641.0(81.53%),B:2.3(11.98%),P:1e-295
# 		Round 3: -754.84 AAAAMAAA T:742.0(85.85%),B:2.4(11.98%),P:1e-327
# 		Round 4: -754.84 AAAAMAAA T:742.0(85.85%),B:2.4(11.98%),P:1e-327
# 		=Final=: -463.89 AAAAMAAA T:251.0(66.05%),B:1.3(8.20%),P:1e-201
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	2 of 25 Initial Sequence: GTTGGGCC... (-453.828)
# 		Round 1: -453.83 GTTGGGCC T:404.0(65.51%),B:2.0(11.98%),P:1e-197
# 		Round 2: -453.83 GTTGGGCC T:404.0(65.51%),B:2.0(11.98%),P:1e-197
# 		=Final=: -265.81 GTTGGGCC T:238.0(62.63%),B:2.0(12.56%),P:1e-115
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	3 of 25 Initial Sequence: TATATAGA... (-392.465)
# 		Round 1: -392.46 TATATAGA T:351.0(60.34%),B:2.6(11.98%),P:1e-170
# 		Round 2: -392.46 TATATAGA T:351.0(60.34%),B:2.6(11.98%),P:1e-170
# 		=Final=: -144.87 TATATAGA T:182.0(47.89%),B:2.2(14.02%),P:1e-62
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	4 of 25 Initial Sequence: GTGAGGGG... (-367.823)
# 		Round 1: -367.82 GTGAGGGG T:333.0(58.42%),B:0.7(0.00%),P:1e-159
# 		Round 2: -367.82 GTGAGGGG T:333.0(58.42%),B:0.7(0.00%),P:1e-159
# 		=Final=: -306.40 GTGAGGGG T:200.0(52.63%),B:0.5(3.31%),P:1e-133
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	5 of 25 Initial Sequence: TATTATAA... (-252.223)
# 		Round 1: -389.35 AATAATAA T:349.0(60.13%),B:2.8(11.98%),P:1e-169
# 		Round 2: -389.35 AATAATAA T:349.0(60.13%),B:2.8(11.98%),P:1e-169
# 		=Final=: -214.35 AATAATAA T:165.0(43.42%),B:1.7(10.82%),P:1e-93
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	6 of 25 Initial Sequence: TTTTGTAT... (-176.610)
# 		Round 1: -176.61 TTTTGTAT T:190.0(39.39%),B:2.8(11.98%),P:1e-76
# 		Round 2: -176.61 TTTTGTAT T:190.0(39.39%),B:2.8(11.98%),P:1e-76
# 		=Final=: -101.57 TTTTGTAT T:157.0(41.32%),B:2.8(17.52%),P:1e-44
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	7 of 25 Initial Sequence: ATGCATCC... (-160.096)
# 		Round 1: -160.10 ATGCATCC T:535.0(75.58%),B:6.2(31.81%),P:1e-69
# 		Round 2: -160.10 ATGCATCC T:535.0(75.58%),B:6.2(31.81%),P:1e-69
# 		=Final=: -134.19 ATGCATCC T:245.0(64.47%),B:4.3(26.57%),P:1e-58
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	8 of 25 Initial Sequence: AGAGATAG... (-154.444)
# 		Round 1: -154.44 AGAGATAG T:173.0(36.61%),B:2.2(11.98%),P:1e-67
# 		Round 2: -154.44 AGAGATAG T:173.0(36.61%),B:2.2(11.98%),P:1e-67
# 		=Final=: -15.11 AGAGATAG T:83.0(21.84%),B:2.2(13.99%),P:1e-6
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	9 of 25 Initial Sequence: TCCTCTTC... (-116.578)
# 		Round 1: -195.14 TCTTCTTC T:203.0(41.43%),B:1.5(6.18%),P:1e-84
# 		Round 2: -195.14 TCTTCTTC T:203.0(41.43%),B:1.5(6.18%),P:1e-84
# 		=Final=: -156.61 TCTTCTTC T:140.0(36.84%),B:1.5(9.67%),P:1e-68
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	10 of 25 Initial Sequence: AGATATTT... (-111.617)
# 		Round 1: -111.62 AGATATTT T:142.0(31.21%),B:2.3(11.98%),P:1e-48
# 		Round 2: -111.62 AGATATTT T:142.0(31.21%),B:2.3(11.98%),P:1e-48
# 		=Final=: -46.54 AGATATTT T:117.0(30.79%),B:2.3(14.22%),P:1e-20
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	11 of 25 Initial Sequence: TCATAAAA... (-104.056)
# 		Round 1: -154.44 TSATAAAA T:173.0(36.61%),B:1.4(6.18%),P:1e-67
# 		Round 2: -154.44 TSATAAAA T:173.0(36.61%),B:1.4(6.18%),P:1e-67
# 		=Final=: -131.37 TSATAAAA T:128.0(33.68%),B:1.8(11.25%),P:1e-57
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	12 of 25 Initial Sequence: TGTACGTT... (-93.974)
# 		Round 1: -93.97 TGTACGTT T:399.0(65.05%),B:6.4(31.81%),P:1e-40
# 		Round 2: -93.97 TGTACGTT T:399.0(65.05%),B:6.4(31.81%),P:1e-40
# 		=Final=: -84.39 TGTACGTT T:240.0(63.16%),B:5.8(36.13%),P:1e-36
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	13 of 25 Initial Sequence: TAATTTCA... (-70.935)
# 		Round 1: -70.94 TAATTTCA T:110.0(25.16%),B:1.9(6.18%),P:1e-30
# 		Round 2: -70.94 TAATTTCA T:110.0(25.16%),B:1.9(6.18%),P:1e-30
# 		=Final=: -66.15 TAATTTCA T:92.0(24.21%),B:1.9(12.13%),P:1e-28
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	14 of 25 Initial Sequence: AATAAAGA... (-61.491)
# 		Round 1: -61.49 AATAAAGA T:102.0(23.57%),B:3.0(11.98%),P:1e-26
# 		Round 2: -61.49 AATAAAGA T:102.0(23.57%),B:3.0(11.98%),P:1e-26
# 		=Final=: -21.09 AATAAAGA T:91.0(23.95%),B:3.0(18.48%),P:1e-9
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	15 of 25 Initial Sequence: CAAAATTT... (-59.967)
# 		Round 1: -59.97 CAAAATTT T:100.0(23.16%),B:2.8(11.98%),P:1e-26
# 		Round 2: -59.97 CAAAATTT T:100.0(23.16%),B:2.8(11.98%),P:1e-26
# 		=Final=: -11.24 CAAAATTT T:77.0(20.26%),B:2.8(17.41%),P:1e-4
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	16 of 25 Initial Sequence: TTCACATG... (-45.551)
# 		Round 1: -70.94 GTCACATG T:110.0(25.16%),B:2.1(11.98%),P:1e-30
# 		Round 2: -70.94 GTCACATG T:110.0(25.16%),B:2.1(11.98%),P:1e-30
# 		=Final=: -29.21 GTCACATG T:65.0(17.11%),B:0.4(2.66%),P:1e-12
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	17 of 25 Initial Sequence: ATCATCAA... (-42.854)
# 		Round 1: -42.85 ATCATCAA T:85.0(20.07%),B:0.2(0.00%),P:1e-18
# 		Round 2: -42.85 ATCATCAA T:85.0(20.07%),B:0.2(0.00%),P:1e-18
# 		=Final=: -32.73 ATCATCAA T:68.0(17.89%),B:0.2(1.26%),P:1e-14
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	18 of 25 Initial Sequence: ATTTCAAA... (-35.157)
# 		Round 1: -35.16 ATTTCAAA T:78.0(18.58%),B:2.4(11.98%),P:1e-15
# 		Round 2: -35.16 ATTTCAAA T:78.0(18.58%),B:2.4(11.98%),P:1e-15
# 		=Final=: -5.19 ATTTCAAA T:65.0(17.11%),B:2.4(14.87%),P:1e-2
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	19 of 25 Initial Sequence: ATTCTATT... (-30.366)
# 		Round 1: -30.37 ATTCTATT T:73.0(17.50%),B:1.3(6.18%),P:1e-13
# 		Round 2: -30.37 ATTCTATT T:73.0(17.50%),B:1.3(6.18%),P:1e-13
# 		=Final=: -33.93 ATTCTATT T:69.0(18.16%),B:1.3(7.85%),P:1e-14
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	20 of 25 Initial Sequence: TAGTTTAT... (-28.078)
# 		Round 1: -28.08 TAGTTTAT T:71.0(17.06%),B:2.0(6.18%),P:1e-12
# 		Round 2: -28.08 TAGTTTAT T:71.0(17.06%),B:2.0(6.18%),P:1e-12
# 		=Final=: -25.86 TAGTTTAT T:62.0(16.32%),B:2.0(12.28%),P:1e-11
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	21 of 25 Initial Sequence: TTGTCTCT... (-21.659)
# 		Round 1: -55.48 TTCTCTCT T:97.0(22.55%),B:2.8(11.98%),P:1e-24
# 		Round 2: -55.48 TTCTCTCT T:97.0(22.55%),B:2.8(11.98%),P:1e-24
# 		=Final=: -6.92 TTCTCTCT T:40.0(10.53%),B:0.0(0.00%),P:1e-3
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	22 of 25 Initial Sequence: TTAATTTT... (-20.657)
# 		Round 1: -20.66 TTAATTTT T:62.0(15.07%),B:2.0(11.98%),P:1e-8
# 		Round 2: -20.66 TTAATTTT T:62.0(15.07%),B:2.0(11.98%),P:1e-8
# 		=Final=: -0.00 TTAATTTT T:65.0(17.11%),B:4.6(28.44%),P:1e0
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	23 of 25 Initial Sequence: GAAAAGAG... (-15.952)
# 		Round 1: -29.21 TAAAAGAG T:72.0(17.28%),B:1.9(6.18%),P:1e-12
# 		Round 2: -29.21 TAAAAGAG T:72.0(17.28%),B:1.9(6.18%),P:1e-12
# 		=Final=: -28.08 TAAAAGAG T:64.0(16.84%),B:1.9(11.76%),P:1e-12
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	24 of 25 Initial Sequence: ATGACAAG... (-13.383)
# 		Round 1: -13.38 ATGACAAG T:53.0(13.03%),B:0.9(0.00%),P:1e-5
# 		Round 2: -13.38 ATGACAAG T:53.0(13.03%),B:0.9(0.00%),P:1e-5
# 		=Final=: -15.07 ATGACAAG T:51.0(13.42%),B:0.4(2.66%),P:1e-6
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	25 of 25 Initial Sequence: ACCACAAT... (-13.383)
# 		Round 1: -44.19 ACCACMAK T:86.0(20.28%),B:2.8(11.98%),P:1e-19
# 		Round 2: -44.19 ACCACMAK T:86.0(20.28%),B:2.8(11.98%),P:1e-19
# 		=Final=: -36.40 ACCACMAK T:71.0(18.68%),B:1.8(11.33%),P:1e-15
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
#
# 	Finalizing Enrichment Statistics (new in v3.4)
# 	Reading input files...
# 	396 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 25 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Output in file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Down_vs_DiffPeakAnno_DM6_DM7_Up/homerMotifs.motifs8
#
#
# 	Number of Trial motifs (-T) set to 20 (from 10) to work well with 20 CPUs
# 	Scanning input files...
# 	Parsing sequences...
# 	|0%                                   50%                                  100%|
# 	==================================================================================================
# 	Total number of Oligos: 59758
# 	Autoadjustment for sequence coverage in background: 1.00x
#
# 	Oligos: 59758 of 76032 max
# 	Tree  : 156784 of 380160 max
# 	Optimizing memory usage...
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Global Optimization Phase: Looking for enriched oligos with up to 2 mismatches...
#
# 	Screening oligos 59758 (allowing 0 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		3.83% skipped, 96.17% checked (57469 of 59758), of those checked:
# 		3.83% not in target, 0.00% increased p-value, 0.00% high p-value
#
# 	Screening oligos 59758 (allowing 1 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		3.83% skipped, 96.17% checked (57469 of 59758), of those checked:
# 		0.00% not in target, 6.78% increased p-value, 87.25% high p-value
#
# 	Screening oligos 59758 (allowing 2 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		91.08% skipped, 8.92% checked (5330 of 59758), of those checked:
# 		0.00% not in target, 1.53% increased p-value, 1.99% high p-value
# 	Reading input files...
# 	396 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Local Optimization Phase:
# 	1 of 25 Initial Sequence: AAAAAAAAAA... (-559.375)
# 		Round 1: -570.56 AAAAAAAAAA T:511.0(73.99%),B:2.9(11.98%),P:1e-247
# 		Round 2: -589.47 AAAAAAAAAA T:534.0(75.52%),B:2.9(11.98%),P:1e-256
# 		Round 3: -589.47 AAAAAAAAAA T:534.0(75.52%),B:2.9(11.98%),P:1e-256
# 		=Final=: -135.46 AAAAAAAAAA T:130.0(34.21%),B:0.0(0.00%),P:1e-58
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	2 of 25 Initial Sequence: GTGTATATAT... (-519.378)
# 		Round 1: -519.38 GTGTATATAT T:462.0(70.40%),B:2.4(11.98%),P:1e-225
# 		Round 2: -519.38 GTGTATATAT T:462.0(70.40%),B:2.4(11.98%),P:1e-225
# 		=Final=: -273.39 GTGTATATAT T:188.0(49.47%),B:1.6(9.85%),P:1e-118
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	3 of 25 Initial Sequence: TTTTTTAAAA... (-421.027)
# 		Round 1: -421.03 TTTTTTAAAA T:374.0(62.68%),B:2.3(11.98%),P:1e-182
# 		Round 2: -421.03 TTTTTTAAAA T:374.0(62.68%),B:2.3(11.98%),P:1e-182
# 		=Final=: -239.34 TTTTTTAAAA T:175.0(46.05%),B:1.9(11.60%),P:1e-103
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	4 of 25 Initial Sequence: AGAAGAAGAA... (-247.036)
# 		Round 1: -247.04 AGAAGAAGAA T:240.0(46.87%),B:2.2(11.98%),P:1e-107
# 		Round 2: -247.04 AGAAGAAGAA T:240.0(46.87%),B:2.2(11.98%),P:1e-107
# 		=Final=: -75.97 AGAAGAAGAA T:140.0(36.84%),B:2.2(13.75%),P:1e-32
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	5 of 25 Initial Sequence: AAATAAAATT... (-283.316)
# 		Round 1: -283.32 AAATAAAATT T:395.0(64.68%),B:3.9(17.42%),P:1e-123
# 		Round 2: -283.32 AAATAAAATT T:395.0(64.68%),B:3.9(17.42%),P:1e-123
# 		=Final=: -166.16 AAATAAAATT T:231.0(60.79%),B:3.9(24.35%),P:1e-72
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	6 of 25 Initial Sequence: TCACATGCAT... (-148.013)
# 		Round 1: -346.83 TCACATGCMT T:316.0(56.51%),B:2.9(11.98%),P:1e-150
# 		Round 2: -346.83 TCACATGCMT T:316.0(56.51%),B:2.9(11.98%),P:1e-150
# 		=Final=: -190.51 TCACATGCMT T:205.0(53.95%),B:2.6(16.17%),P:1e-82
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	7 of 25 Initial Sequence: GAGAGAGTGA... (-126.754)
# 		Round 1: -126.75 GAGAGAGTGA T:230.0(45.45%),B:3.8(17.42%),P:1e-55
# 		Round 2: -126.75 GAGAGAGTGA T:230.0(45.45%),B:3.8(17.42%),P:1e-55
# 		=Final=: -13.10 GAGAGAGTGA T:80.0(21.05%),B:2.1(13.28%),P:1e-5
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	8 of 25 Initial Sequence: CAATAAACAA... (-119.374)
# 		Round 1: -119.37 CAATAAACAA T:148.0(32.29%),B:1.5(6.18%),P:1e-51
# 		Round 2: -119.37 CAATAAACAA T:148.0(32.29%),B:1.5(6.18%),P:1e-51
# 		=Final=: -44.27 CAATAAACAA T:115.0(30.26%),B:2.6(16.41%),P:1e-19
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	9 of 25 Initial Sequence: TTGTGGTCCA... (-70.935)
# 		Round 1: -141.68 ATGTGGTCCA T:164.0(35.09%),B:2.8(11.98%),P:1e-61
# 		Round 2: -141.68 ATGTGGTCCA T:164.0(35.09%),B:2.8(11.98%),P:1e-61
# 		=Final=: -63.59 ATGTGGTCCA T:165.0(43.42%),B:3.2(20.11%),P:1e-27
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	10 of 25 Initial Sequence: CAATAAATAA... (-38.930)
# 		Round 1: -38.93 CAATAAATAA T:82.0(19.43%),B:2.0(11.98%),P:1e-16
# 		Round 2: -38.93 CAATAAATAA T:82.0(19.43%),B:2.0(11.98%),P:1e-16
# 		=Final=: -11.84 CAATAAATAA T:78.0(20.53%),B:2.0(12.56%),P:1e-5
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	11 of 25 Initial Sequence: TTATTTGTTG... (-28.078)
# 		Round 1: -28.08 TTATTTGTTG T:70.0(16.84%),B:2.2(11.98%),P:1e-12
# 		Round 2: -28.08 TTATTTGTTG T:70.0(16.84%),B:2.2(11.98%),P:1e-12
# 		=Final=: -30.37 TTATTTGTTG T:66.0(17.37%),B:1.6(10.21%),P:1e-13
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	12 of 25 Initial Sequence: GTATTTATTT... (-21.659)
# 		Round 1: -21.66 GTATTTATTT T:63.0(15.30%),B:2.9(11.98%),P:1e-9
# 		Round 2: -21.66 GTATTTATTT T:63.0(15.30%),B:2.9(11.98%),P:1e-9
# 		=Final=: -0.08 GTATTTATTT T:61.0(16.05%),B:3.1(19.09%),P:1e0
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	13 of 25 Initial Sequence: GTATTTATGT... (-25.863)
# 		Round 1: -25.86 GTATTTATGT T:68.0(16.40%),B:0.4(0.00%),P:1e-11
# 		Round 2: -25.86 GTATTTATGT T:68.0(16.40%),B:0.4(0.00%),P:1e-11
# 		=Final=: -30.37 GTATTTATGT T:66.0(17.37%),B:0.4(2.66%),P:1e-13
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	14 of 25 Initial Sequence: TCTATAAATA... (-15.952)
# 		Round 1: -127.32 TCTATAWATA T:153.0(33.18%),B:2.9(11.98%),P:1e-55
# 		Round 2: -127.32 TCTATAWATA T:153.0(33.18%),B:2.9(11.98%),P:1e-55
# 		=Final=: -89.54 TCTATAWATA T:106.0(27.89%),B:1.3(7.91%),P:1e-38
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	15 of 25 Initial Sequence: TATTTGTTTA... (-18.713)
# 		Round 1: -33.93 TATTTGTTTA T:77.0(18.36%),B:0.4(0.00%),P:1e-14
# 		Round 2: -33.93 TATTTGTTTA T:77.0(18.36%),B:0.4(0.00%),P:1e-14
# 		=Final=: -15.07 TATTTGTTTA T:51.0(13.42%),B:0.0(0.00%),P:1e-6
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	16 of 25 Initial Sequence: AGAAAAAAGG... (-15.952)
# 		Round 1: -35.16 AGAAAAAAGG T:78.0(18.58%),B:2.4(11.98%),P:1e-15
# 		Round 2: -38.93 RGRAAAAWGG T:82.0(19.43%),B:1.1(6.18%),P:1e-16
# 		Round 3: -44.19 DGGAAAAWGG T:86.0(20.28%),B:1.1(6.18%),P:1e-19
# 		Round 4: -44.19 DGGAAAAWGG T:86.0(20.28%),B:1.1(6.18%),P:1e-19
# 		=Final=: -8.18 DGGAAAAWGG T:42.0(11.05%),B:0.9(5.54%),P:1e-3
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	17 of 25 Initial Sequence: TCTTCTTTAT... (-14.217)
# 		Round 1: -14.22 TCTTCTTTAT T:54.0(13.26%),B:1.6(6.18%),P:1e-6
# 		Round 2: -14.22 TCTTCTTTAT T:54.0(13.26%),B:1.6(6.18%),P:1e-6
# 		=Final=: -0.00 TCTTCTTTAT T:52.0(13.68%),B:4.6(28.44%),P:1e0
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	18 of 25 Initial Sequence: CTTTATTTTG... (-17.772)
# 		Round 1: -28.08 CTTTATTTTG T:70.0(16.84%),B:1.8(6.18%),P:1e-12
# 		Round 2: -28.08 CTTTATTTTG T:70.0(16.84%),B:1.8(6.18%),P:1e-12
# 		=Final=: -37.66 CTTTATTTTG T:72.0(18.95%),B:1.1(6.94%),P:1e-16
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	19 of 25 Initial Sequence: TTCTTATTTC... (-8.856)
# 		Round 1: -18.71 TTCTTATTTC T:60.0(14.62%),B:2.4(11.98%),P:1e-8
# 		Round 2: -18.71 TTCTTATTTC T:60.0(14.62%),B:2.4(11.98%),P:1e-8
# 		=Final=: -11.78 TTCTTATTTC T:47.0(12.37%),B:0.0(0.00%),P:1e-5
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	20 of 25 Initial Sequence: ATATATAACT... (-8.856)
# 		Round 1: -69.33 ATATMTAACW T:108.0(24.77%),B:1.9(6.18%),P:1e-30
# 		Round 2: -69.33 ATATMTAACW T:108.0(24.77%),B:1.9(6.18%),P:1e-30
# 		=Final=: -24.78 ATATMTAACW T:61.0(16.05%),B:0.4(2.66%),P:1e-10
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	21 of 25 Initial Sequence: TGTTTTGTTT... (-11.781)
# 		Round 1: -63.03 TGTTTTGTTT T:103.0(23.77%),B:2.9(11.98%),P:1e-27
# 		Round 2: -63.03 TGTTTTGTTT T:103.0(23.77%),B:2.9(11.98%),P:1e-27
# 		=Final=: -21.66 TGTTTTGTTT T:58.0(15.26%),B:1.3(7.85%),P:1e-9
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	Remaining seeds don't look promising (After initial 5 motifs, logp -5.752 > -8.580)
#
# 	Finalizing Enrichment Statistics (new in v3.4)
# 	Reading input files...
# 	396 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 21 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Output in file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Down_vs_DiffPeakAnno_DM6_DM7_Up/homerMotifs.motifs10
#
#
# 	Number of Trial motifs (-T) set to 20 (from 10) to work well with 20 CPUs
# 	-blen automatically set to 2
# 	Scanning input files...
# 	Parsing sequences...
# 	|0%                                   50%                                  100%|
# 	==================================================================================================
# 	Total number of Oligos: 72467
# 	Autoadjustment for sequence coverage in background: 1.00x
#
# 	Oligos: 72467 of 75240 max
# 	Tree  : 214804 of 376200 max
# 	Optimizing memory usage...
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Global Optimization Phase: Looking for enriched oligos with up to 2 mismatches...
#
# 	Screening oligos 72467 (allowing 0 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		4.07% skipped, 95.93% checked (69518 of 72467), of those checked:
# 		4.07% not in target, 0.00% increased p-value, 0.00% high p-value
#
# 	Screening oligos 72467 (allowing 1 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		4.07% skipped, 95.93% checked (69518 of 72467), of those checked:
# 		0.00% not in target, 24.78% increased p-value, 54.15% high p-value
#
# 	Screening oligos 72467 (allowing 2 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		58.22% skipped, 41.78% checked (30276 of 72467), of those checked:
# 		0.00% not in target, 2.87% increased p-value, 39.66% high p-value
# 	Reading input files...
# 	396 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
#
# 	Local Optimization Phase:
# 	1 of 25 Initial Sequence: TTTTTTTTTTTA... (-522.950)
# 		Round 1: -522.95 TTTTTTTTTTTA T:465.0(70.63%),B:0.4(0.00%),P:1e-227
# 		Round 2: -522.95 TTTTTTTTTTTA T:465.0(70.63%),B:0.4(0.00%),P:1e-227
# 		=Final=: -167.61 TTTTTTTTTTTA T:145.0(38.16%),B:0.4(2.66%),P:1e-72
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	2 of 25 Initial Sequence: TTTATATATATA... (-195.136)
# 		Round 1: -195.14 TTTATATATATA T:203.0(41.43%),B:2.1(11.98%),P:1e-84
# 		Round 2: -195.14 TTTATATATATA T:203.0(41.43%),B:2.1(11.98%),P:1e-84
# 		=Final=: -27.98 TTTATATATATA T:99.0(26.05%),B:2.1(13.28%),P:1e-12
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	3 of 25 Initial Sequence: AGAGAAAGAGAG... (-158.788)
# 		Round 1: -158.79 AGAGAAAGAGAG T:177.0(37.27%),B:2.6(11.98%),P:1e-68
# 		Round 2: -158.79 AGAGAAAGAGAG T:177.0(37.27%),B:2.6(11.98%),P:1e-68
# 		=Final=: -2.22 AGAGAAAGAGAG T:56.0(14.74%),B:2.6(16.41%),P:1e0
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	4 of 25 Initial Sequence: TTTTTTTTTATT... (-32.726)
# 		Round 1: -44.19 TTTTGTTTTGTT T:87.0(20.49%),B:0.7(0.00%),P:1e-19
# 		Round 2: -44.19 TTTTGTTTTGTT T:87.0(20.49%),B:0.7(0.00%),P:1e-19
# 		=Final=: -41.53 TTTTGTTTTGTT T:75.0(19.74%),B:0.7(4.55%),P:1e-18
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	5 of 25 Initial Sequence: TTTTTCTTTTTT... (-15.074)
# 		Round 1: -109.71 TTTTTCTTYTTT T:140.0(30.85%),B:2.4(11.98%),P:1e-47
# 		Round 2: -109.71 TTTTTCTTYTTT T:140.0(30.85%),B:2.4(11.98%),P:1e-47
# 		=Final=: -18.25 TTTTTCTTYTTT T:221.0(58.16%),B:7.5(46.75%),P:1e-7
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	Remaining seeds don't look promising (After initial 5 motifs, logp -7.539 > -8.580)
#
# 	Finalizing Enrichment Statistics (new in v3.4)
# 	Reading input files...
# 	396 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 5 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Output in file: /media/HDD2/donghui/bulk_ATAC_DM1_DM2d/diffbind_results_DM1_DM2d_DM6_DM7/motif_DiffPeakAnno_DM6_DM7/DiffPeakAnno_DM6_DM7_Down_vs_DiffPeakAnno_DM6_DM7_Up/homerMotifs.motifs12
#
# 	(Motifs in homer2 format)
# 	Determining similar motifs... 51 reduced to 19 motifs
# 	Outputing HTML and sequence logos for motif comparison...
# 	Checking de novo motifs against known motifs...
# 	Formatting HTML page...
# 		1 of 19 (1e-201) similar to REM19(REM)/colamp-REM19-DAP-Seq(GSE60143)/Homer(0.871)
# 		2 of 19 (1e-170) similar to ALFIN1(HD-PHD)/Medicago sativa/AthaMap(0.650)
# 		3 of 19 (1e-123) similar to PCF/Arabidopsis-Promoters/Homer(0.810)
# 		4 of 19 (1e-122) similar to PEND/MA0127.1/Jaspar(0.798)
# 		5 of 19 (1e-119) similar to TBP(- other)/several species/AthaMap(0.691)
# 		6 of 19 (1e-110) similar to FUS3/MA0565.2/Jaspar(0.817)
# 		7 of 19 (1e-104) similar to ATHB20/MA1209.1/Jaspar(0.746)
# 		8 of 19 (1e-71) similar to SPL9(SBP)/colamp-SPL9-DAP-Seq(GSE60143)/Homer(0.822)
# 		9 of 19 (1e-61) similar to Unknown4/Arabidopsis-Promoters/Homer(0.768)
# 		10 of 19 (1e-58) similar to AGL42/MA1201.1/Jaspar(0.758)
# 		11 of 19 (1e-47) similar to TCP3(TCP)/colamp-TCP3-DAP-Seq(GSE60143)/Homer(0.815)
# 		12 of 19 (1e-33) similar to CCA1/MA0972.1/Jaspar(0.998)
# 		13 of 19 (1e-28) similar to TSO1/MA1161.1/Jaspar(0.658)
# 		14 of 19 (1e-24) similar to TCX3/MA1682.1/Jaspar(0.792)
# 		15 of 19 (1e-24) similar to dof42(C2C2dof)/col-dof42-DAP-Seq(GSE60143)/Homer(0.835)
# 		16 of 19 (1e-19) similar to AT1G47655/MA1275.1/Jaspar(0.675)
# 		17 of 19 (1e-18) similar to AT2G40260/MA1385.1/Jaspar(0.765)
# 		18 of 19 (1e-12) similar to RAMOSA1/MA1416.1/Jaspar(0.782)
# 		19 of 19 (1e-10) similar to ARF4/MA1697.1/Jaspar(0.826)
# 	Job finished - if results look good, please send beer to ..
#
# 	Cleaning up tmp files...
