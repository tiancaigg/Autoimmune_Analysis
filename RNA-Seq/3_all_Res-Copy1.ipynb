# %% [markdown]
# # load and import

# %%
R.version.string
library('dplyr')

library('stringr')
library('tidyr')
library('ggplot2')

library(ggh4x)
# library(tidyverse)
# Load necessary libraries
# library(magick)
library(cowplot)
library(patchwork)
library(gridExtra)
library(png)
library(grid)
# Out:
# [1] "R version 4.3.1 (2023-06-16)"

# %% [raw]
# # Read the xlsx file
# map_id_name <- readxl::read_excel("../gene_table_and_other_scripts/gene_table.xlsx")
# map_id_name <- map_id_name %>% mutate(gene_name = gene_name %>% str_remove("'"))
# sample_n(map_id_name, 2)

# %%
map_id_name <- read.csv('../gene_table_and_other_scripts/bioMartR_Ath_all_genes_info_googled.csv')
map_id_name <- map_id_name %>% dplyr::rename('gene_name' = 'external_gene_name', 'gene_id' = 'ensembl_gene_id')
sample_n(map_id_name, 2)
# Out:
#   gene_id   gene_name
# 1 AT4G16420 ADA2B
# 2 AT3G27910 AT3G27910

# %%
source('../gene_table_and_other_scripts/theme_Publication.R')
# Out:
# aakar already registered with pdfFont().
#
# Abyssinica SIL already registered with pdfFont().
#
# Andale Mono already registered with pdfFont().
#
# Ani already registered with pdfFont().
#
# AnjaliOldLipi already registered with pdfFont().
#
# Arial already registered with pdfFont().
#
# Arial Black already registered with pdfFont().
#
# Chandas already registered with pdfFont().
#
# Comic Sans MS already registered with pdfFont().
#
# Courier New already registered with pdfFont().
#
# DejaVu Sans already registered with pdfFont().
#
# DejaVu Sans Mono already registered with pdfFont().
#
# DejaVu Serif already registered with pdfFont().
#
# Dhurjati already registered with pdfFont().
#
# Droid Sans Fallback already registered with pdfFont().
#
# Dyuthi already registered with pdfFont().
#
# FreeMono already registered with pdfFont().
#
# FreeSans already registered with pdfFont().
#
# FreeSerif already registered with pdfFont().
#
# Gargi already registered with pdfFont().
#
# Garuda already registered with pdfFont().
#
# Georgia already registered with pdfFont().
#
# Gidugu already registered with pdfFont().
#
# Gubbi already registered with pdfFont().
#
# Gurajada already registered with pdfFont().
#
# Impact already registered with pdfFont().
#
# Jamrul already registered with pdfFont().
#
# KacstArt already registered with pdfFont().
#
# KacstBook already registered with pdfFont().
#
# KacstDecorative already registered with pdfFont().
#
# KacstDigital already registered with pdfFont().
#
# KacstFarsi already registered with pdfFont().
#
# KacstLetter already registered with pdfFont().
#
# KacstNaskh already registered with pdfFont().
#
# KacstOffice already registered with pdfFont().
#
# KacstOne already registered with pdfFont().
#
# KacstPen already registered with pdfFont().
#
# KacstPoster already registered with pdfFont().
#
# KacstQurn already registered with pdfFont().
#
# KacstScreen already registered with pdfFont().
#
# KacstTitle already registered with pdfFont().
#
# KacstTitleL already registered with pdfFont().
#
# Kalapi already registered with pdfFont().
#
# Kalimati already registered with pdfFont().
#
# Karumbi already registered with pdfFont().
#
# Keraleeyam already registered with pdfFont().
#
# Khmer OS already registered with pdfFont().
#
# Khmer OS System already registered with pdfFont().
#
# More than one version of regular/bold/italic found for Kinnari. Skipping setup for this font.
#
# LakkiReddy already registered with pdfFont().
#
# Laksaman already registered with pdfFont().
#
# More than one version of regular/bold/italic found for Liberation Mono. Skipping setup for this font.
#
# More than one version of regular/bold/italic found for Liberation Sans. Skipping setup for this font.
#
# Liberation Sans Narrow already registered with pdfFont().
#
# More than one version of regular/bold/italic found for Liberation Serif. Skipping setup for this font.
#
# Likhan already registered with pdfFont().
#
# LKLUG already registered with pdfFont().
#
# Lohit Assamese already registered with pdfFont().
#
# Lohit Bengali already registered with pdfFont().
#
# Lohit Devanagari already registered with pdfFont().
#
# Lohit Gujarati already registered with pdfFont().
#
# Lohit Gurmukhi already registered with pdfFont().
#
# Lohit Kannada already registered with pdfFont().
#
# Lohit Malayalam already registered with pdfFont().
#
# Lohit Odia already registered with pdfFont().
#
# Lohit Tamil already registered with pdfFont().
#
# Lohit Tamil Classical already registered with pdfFont().
#
# Lohit Telugu already registered with pdfFont().
#
# Loma already registered with pdfFont().
#
# Mallanna already registered with pdfFont().
#
# Mandali already registered with pdfFont().
#
# Meera already registered with pdfFont().
#
# Mitra  already registered with pdfFont().
#
# mry_KacstQurn already registered with pdfFont().
#
# More than one version of regular/bold/italic found for Mukti. Skipping setup for this font.
#
# Nakula already registered with pdfFont().
#
# NATS already registered with pdfFont().
#
# Navilu already registered with pdfFont().
#
# More than one version of regular/bold/italic found for Norasi. Skipping setup for this font.
#
# Noto Mono already registered with pdfFont().
#
# Noto Sans Mono already registered with pdfFont().
#
# NTR already registered with pdfFont().
#
# OpenSymbol already registered with pdfFont().
#
# Padauk already registered with pdfFont().
#
# Padauk Book already registered with pdfFont().
#
# More than one version of regular/bold/italic found for padmaa. Skipping setup for this font.
#
# No regular (non-bold, non-italic) version of padmaa-Bold.1.1. Skipping setup for this font.
#
# Pagul already registered with pdfFont().
#
# Peddana already registered with pdfFont().
#
# Phetsarath OT already registered with pdfFont().
#
# Ponnala already registered with pdfFont().
#
# Pothana2000 already registered with pdfFont().
#
# Potti Sreeramulu already registered with pdfFont().
#
# Purisa already registered with pdfFont().
#
# Rachana already registered with pdfFont().
#
# RaghuMalayalamSans already registered with pdfFont().
#
# Ramabhadra already registered with pdfFont().
#
# Ramaraja already registered with pdfFont().
#
# Rasa already registered with pdfFont().
#
# Rasa Light already registered with pdfFont().
#
# Rasa Medium already registered with pdfFont().
#
# Rasa SemiBold already registered with pdfFont().
#
# RaviPrakash already registered with pdfFont().
#
# Rekha already registered with pdfFont().
#
# Saab already registered with pdfFont().
#
# Sahadeva already registered with pdfFont().
#
# Samanata already registered with pdfFont().
#
# Samyak Devanagari already registered with pdfFont().
#
# Samyak Gujarati already registered with pdfFont().
#
# Samyak Malayalam already registered with pdfFont().
#
# Samyak Tamil already registered with pdfFont().
#
# Sarai already registered with pdfFont().
#
# Sawasdee already registered with pdfFont().
#
# Sree Krushnadevaraya already registered with pdfFont().
#
# Suranna already registered with pdfFont().
#
# Suravaram already registered with pdfFont().
#
# Suruma already registered with pdfFont().
#
# Syamala Ramana already registered with pdfFont().
#
# TenaliRamakrishna already registered with pdfFont().
#
# Tibetan Machine Uni already registered with pdfFont().
#
# Times New Roman already registered with pdfFont().
#
# Timmana already registered with pdfFont().
#
# Tlwg Typist already registered with pdfFont().
#
# Tlwg Typo already registered with pdfFont().
#
# TlwgMono already registered with pdfFont().
#
# TlwgTypewriter already registered with pdfFont().
#
# Trebuchet MS already registered with pdfFont().
#
# Ubuntu already registered with pdfFont().
#
# Ubuntu Condensed already registered with pdfFont().
#
# Ubuntu Light already registered with pdfFont().
#
# Ubuntu Mono already registered with pdfFont().
#
# Ubuntu Thin already registered with pdfFont().
#
# More than one version of regular/bold/italic found for Umpush. Skipping setup for this font.
#
# Uroob already registered with pdfFont().
#
# utkal already registered with pdfFont().
#
# Vemana2000 already registered with pdfFont().
#
# Verdana already registered with pdfFont().
#
# Waree already registered with pdfFont().
#
# Webdings already registered with pdfFont().
#
# Yrsa already registered with pdfFont().
#
# Yrsa Light already registered with pdfFont().
#
# Yrsa Medium already registered with pdfFont().
#
# Yrsa SemiBold already registered with pdfFont().
#
# aakar already registered with postscriptFont().
#
# Abyssinica SIL already registered with postscriptFont().
#
# Andale Mono already registered with postscriptFont().
#
# Ani already registered with postscriptFont().
#
# AnjaliOldLipi already registered with postscriptFont().
#
# Arial already registered with postscriptFont().
#
# Arial Black already registered with postscriptFont().
#
# Chandas already registered with postscriptFont().
#
# Comic Sans MS already registered with postscriptFont().
#
# Courier New already registered with postscriptFont().
#
# DejaVu Sans already registered with postscriptFont().
#
# DejaVu Sans Mono already registered with postscriptFont().
#
# DejaVu Serif already registered with postscriptFont().
#
# Dhurjati already registered with postscriptFont().
#
# Droid Sans Fallback already registered with postscriptFont().
#
# Dyuthi already registered with postscriptFont().
#
# FreeMono already registered with postscriptFont().
#
# FreeSans already registered with postscriptFont().
#
# FreeSerif already registered with postscriptFont().
#
# Gargi already registered with postscriptFont().
#
# Garuda already registered with postscriptFont().
#
# Georgia already registered with postscriptFont().
#
# Gidugu already registered with postscriptFont().
#
# Gubbi already registered with postscriptFont().
#
# Gurajada already registered with postscriptFont().
#
# Impact already registered with postscriptFont().
#
# Jamrul already registered with postscriptFont().
#
# KacstArt already registered with postscriptFont().
#
# KacstBook already registered with postscriptFont().
#
# KacstDecorative already registered with postscriptFont().
#
# KacstDigital already registered with postscriptFont().
#
# KacstFarsi already registered with postscriptFont().
#
# KacstLetter already registered with postscriptFont().
#
# KacstNaskh already registered with postscriptFont().
#
# KacstOffice already registered with postscriptFont().
#
# KacstOne already registered with postscriptFont().
#
# KacstPen already registered with postscriptFont().
#
# KacstPoster already registered with postscriptFont().
#
# KacstQurn already registered with postscriptFont().
#
# KacstScreen already registered with postscriptFont().
#
# KacstTitle already registered with postscriptFont().
#
# KacstTitleL already registered with postscriptFont().
#
# Kalapi already registered with postscriptFont().
#
# Kalimati already registered with postscriptFont().
#
# Karumbi already registered with postscriptFont().
#
# Keraleeyam already registered with postscriptFont().
#
# Khmer OS already registered with postscriptFont().
#
# Khmer OS System already registered with postscriptFont().
#
# More than one version of regular/bold/italic found for Kinnari. Skipping setup for this font.
#
# LakkiReddy already registered with postscriptFont().
#
# Laksaman already registered with postscriptFont().
#
# More than one version of regular/bold/italic found for Liberation Mono. Skipping setup for this font.
#
# More than one version of regular/bold/italic found for Liberation Sans. Skipping setup for this font.
#
# Liberation Sans Narrow already registered with postscriptFont().
#
# More than one version of regular/bold/italic found for Liberation Serif. Skipping setup for this font.
#
# Likhan already registered with postscriptFont().
#
# LKLUG already registered with postscriptFont().
#
# Lohit Assamese already registered with postscriptFont().
#
# Lohit Bengali already registered with postscriptFont().
#
# Lohit Devanagari already registered with postscriptFont().
#
# Lohit Gujarati already registered with postscriptFont().
#
# Lohit Gurmukhi already registered with postscriptFont().
#
# Lohit Kannada already registered with postscriptFont().
#
# Lohit Malayalam already registered with postscriptFont().
#
# Lohit Odia already registered with postscriptFont().
#
# Lohit Tamil already registered with postscriptFont().
#
# Lohit Tamil Classical already registered with postscriptFont().
#
# Lohit Telugu already registered with postscriptFont().
#
# Loma already registered with postscriptFont().
#
# Mallanna already registered with postscriptFont().
#
# Mandali already registered with postscriptFont().
#
# Meera already registered with postscriptFont().
#
# Mitra  already registered with postscriptFont().
#
# mry_KacstQurn already registered with postscriptFont().
#
# More than one version of regular/bold/italic found for Mukti. Skipping setup for this font.
#
# Nakula already registered with postscriptFont().
#
# NATS already registered with postscriptFont().
#
# Navilu already registered with postscriptFont().
#
# More than one version of regular/bold/italic found for Norasi. Skipping setup for this font.
#
# Noto Mono already registered with postscriptFont().
#
# Noto Sans Mono already registered with postscriptFont().
#
# NTR already registered with postscriptFont().
#
# OpenSymbol already registered with postscriptFont().
#
# Padauk already registered with postscriptFont().
#
# Padauk Book already registered with postscriptFont().
#
# More than one version of regular/bold/italic found for padmaa. Skipping setup for this font.
#
# No regular (non-bold, non-italic) version of padmaa-Bold.1.1. Skipping setup for this font.
#
# Pagul already registered with postscriptFont().
#
# Peddana already registered with postscriptFont().
#
# Phetsarath OT already registered with postscriptFont().
#
# Ponnala already registered with postscriptFont().
#
# Pothana2000 already registered with postscriptFont().
#
# Potti Sreeramulu already registered with postscriptFont().
#
# Purisa already registered with postscriptFont().
#
# Rachana already registered with postscriptFont().
#
# RaghuMalayalamSans already registered with postscriptFont().
#
# Ramabhadra already registered with postscriptFont().
#
# Ramaraja already registered with postscriptFont().
#
# Rasa already registered with postscriptFont().
#
# Rasa Light already registered with postscriptFont().
#
# Rasa Medium already registered with postscriptFont().
#
# Rasa SemiBold already registered with postscriptFont().
#
# RaviPrakash already registered with postscriptFont().
#
# Rekha already registered with postscriptFont().
#
# Saab already registered with postscriptFont().
#
# Sahadeva already registered with postscriptFont().
#
# Samanata already registered with postscriptFont().
#
# Samyak Devanagari already registered with postscriptFont().
#
# Samyak Gujarati already registered with postscriptFont().
#
# Samyak Malayalam already registered with postscriptFont().
#
# Samyak Tamil already registered with postscriptFont().
#
# Sarai already registered with postscriptFont().
#
# Sawasdee already registered with postscriptFont().
#
# Sree Krushnadevaraya already registered with postscriptFont().
#
# Suranna already registered with postscriptFont().
#
# Suravaram already registered with postscriptFont().
#
# Suruma already registered with postscriptFont().
#
# Syamala Ramana already registered with postscriptFont().
#
# TenaliRamakrishna already registered with postscriptFont().
#
# Tibetan Machine Uni already registered with postscriptFont().
#
# Times New Roman already registered with postscriptFont().
#
# Timmana already registered with postscriptFont().
#
# Tlwg Typist already registered with postscriptFont().
#
# Tlwg Typo already registered with postscriptFont().
#
# TlwgMono already registered with postscriptFont().
#
# TlwgTypewriter already registered with postscriptFont().
#
# Trebuchet MS already registered with postscriptFont().
#
# Ubuntu already registered with postscriptFont().
#
# Ubuntu Condensed already registered with postscriptFont().
#
# Ubuntu Light already registered with postscriptFont().
#
# Ubuntu Mono already registered with postscriptFont().
#
# Ubuntu Thin already registered with postscriptFont().
#
# More than one version of regular/bold/italic found for Umpush. Skipping setup for this font.
#
# Uroob already registered with postscriptFont().
#
# utkal already registered with postscriptFont().
#
# Vemana2000 already registered with postscriptFont().
#
# Verdana already registered with postscriptFont().
#
# Waree already registered with postscriptFont().
#
# Webdings already registered with postscriptFont().
#
# Yrsa already registered with postscriptFont().
#
# Yrsa Light already registered with postscriptFont().
#
# Yrsa Medium already registered with postscriptFont().
#
# Yrsa SemiBold already registered with postscriptFont().
#
# aakar already registered with pdfFont().
#
# Abyssinica SIL already registered with pdfFont().
#
# Andale Mono already registered with pdfFont().
#
# Ani already registered with pdfFont().
#
# AnjaliOldLipi already registered with pdfFont().
#
# Arial already registered with pdfFont().
#
# Arial Black already registered with pdfFont().
#
# Chandas already registered with pdfFont().
#
# Comic Sans MS already registered with pdfFont().
#
# Courier New already registered with pdfFont().
#
# DejaVu Sans already registered with pdfFont().
#
# DejaVu Sans Mono already registered with pdfFont().
#
# DejaVu Serif already registered with pdfFont().
#
# Dhurjati already registered with pdfFont().
#
# Droid Sans Fallback already registered with pdfFont().
#
# Dyuthi already registered with pdfFont().
#
# FreeMono already registered with pdfFont().
#
# FreeSans already registered with pdfFont().
#
# FreeSerif already registered with pdfFont().
#
# Gargi already registered with pdfFont().
#
# Garuda already registered with pdfFont().
#
# Georgia already registered with pdfFont().
#
# Gidugu already registered with pdfFont().
#
# Gubbi already registered with pdfFont().
#
# Gurajada already registered with pdfFont().
#
# Impact already registered with pdfFont().
#
# Jamrul already registered with pdfFont().
#
# KacstArt already registered with pdfFont().
#
# KacstBook already registered with pdfFont().
#
# KacstDecorative already registered with pdfFont().
#
# KacstDigital already registered with pdfFont().
#
# KacstFarsi already registered with pdfFont().
#
# KacstLetter already registered with pdfFont().
#
# KacstNaskh already registered with pdfFont().
#
# KacstOffice already registered with pdfFont().
#
# KacstOne already registered with pdfFont().
#
# KacstPen already registered with pdfFont().
#
# KacstPoster already registered with pdfFont().
#
# KacstQurn already registered with pdfFont().
#
# KacstScreen already registered with pdfFont().
#
# KacstTitle already registered with pdfFont().
#
# KacstTitleL already registered with pdfFont().
#
# Kalapi already registered with pdfFont().
#
# Kalimati already registered with pdfFont().
#
# Karumbi already registered with pdfFont().
#
# Keraleeyam already registered with pdfFont().
#
# Khmer OS already registered with pdfFont().
#
# Khmer OS System already registered with pdfFont().
#
# More than one version of regular/bold/italic found for Kinnari. Skipping setup for this font.
#
# LakkiReddy already registered with pdfFont().
#
# Laksaman already registered with pdfFont().
#
# More than one version of regular/bold/italic found for Liberation Mono. Skipping setup for this font.
#
# More than one version of regular/bold/italic found for Liberation Sans. Skipping setup for this font.
#
# Liberation Sans Narrow already registered with pdfFont().
#
# More than one version of regular/bold/italic found for Liberation Serif. Skipping setup for this font.
#
# Likhan already registered with pdfFont().
#
# LKLUG already registered with pdfFont().
#
# Lohit Assamese already registered with pdfFont().
#
# Lohit Bengali already registered with pdfFont().
#
# Lohit Devanagari already registered with pdfFont().
#
# Lohit Gujarati already registered with pdfFont().
#
# Lohit Gurmukhi already registered with pdfFont().
#
# Lohit Kannada already registered with pdfFont().
#
# Lohit Malayalam already registered with pdfFont().
#
# Lohit Odia already registered with pdfFont().
#
# Lohit Tamil already registered with pdfFont().
#
# Lohit Tamil Classical already registered with pdfFont().
#
# Lohit Telugu already registered with pdfFont().
#
# Loma already registered with pdfFont().
#
# Mallanna already registered with pdfFont().
#
# Mandali already registered with pdfFont().
#
# Meera already registered with pdfFont().
#
# Mitra  already registered with pdfFont().
#
# mry_KacstQurn already registered with pdfFont().
#
# More than one version of regular/bold/italic found for Mukti. Skipping setup for this font.
#
# Nakula already registered with pdfFont().
#
# NATS already registered with pdfFont().
#
# Navilu already registered with pdfFont().
#
# More than one version of regular/bold/italic found for Norasi. Skipping setup for this font.
#
# Noto Mono already registered with pdfFont().
#
# Noto Sans Mono already registered with pdfFont().
#
# NTR already registered with pdfFont().
#
# OpenSymbol already registered with pdfFont().
#
# Padauk already registered with pdfFont().
#
# Padauk Book already registered with pdfFont().
#
# More than one version of regular/bold/italic found for padmaa. Skipping setup for this font.
#
# No regular (non-bold, non-italic) version of padmaa-Bold.1.1. Skipping setup for this font.
#
# Pagul already registered with pdfFont().
#
# Peddana already registered with pdfFont().
#
# Phetsarath OT already registered with pdfFont().
#
# Ponnala already registered with pdfFont().
#
# Pothana2000 already registered with pdfFont().
#
# Potti Sreeramulu already registered with pdfFont().
#
# Purisa already registered with pdfFont().
#
# Rachana already registered with pdfFont().
#
# RaghuMalayalamSans already registered with pdfFont().
#
# Ramabhadra already registered with pdfFont().
#
# Ramaraja already registered with pdfFont().
#
# Rasa already registered with pdfFont().
#
# Rasa Light already registered with pdfFont().
#
# Rasa Medium already registered with pdfFont().
#
# Rasa SemiBold already registered with pdfFont().
#
# RaviPrakash already registered with pdfFont().
#
# Rekha already registered with pdfFont().
#
# Saab already registered with pdfFont().
#
# Sahadeva already registered with pdfFont().
#
# Samanata already registered with pdfFont().
#
# Samyak Devanagari already registered with pdfFont().
#
# Samyak Gujarati already registered with pdfFont().
#
# Samyak Malayalam already registered with pdfFont().
#
# Samyak Tamil already registered with pdfFont().
#
# Sarai already registered with pdfFont().
#
# Sawasdee already registered with pdfFont().
#
# Sree Krushnadevaraya already registered with pdfFont().
#
# Suranna already registered with pdfFont().
#
# Suravaram already registered with pdfFont().
#
# Suruma already registered with pdfFont().
#
# Syamala Ramana already registered with pdfFont().
#
# TenaliRamakrishna already registered with pdfFont().
#
# Tibetan Machine Uni already registered with pdfFont().
#
# Times New Roman already registered with pdfFont().
#
# Timmana already registered with pdfFont().
#
# Tlwg Typist already registered with pdfFont().
#
# Tlwg Typo already registered with pdfFont().
#
# TlwgMono already registered with pdfFont().
#
# TlwgTypewriter already registered with pdfFont().
#
# Trebuchet MS already registered with pdfFont().
#
# Ubuntu already registered with pdfFont().
#
# Ubuntu Condensed already registered with pdfFont().
#
# Ubuntu Light already registered with pdfFont().
#
# Ubuntu Mono already registered with pdfFont().
#
# Ubuntu Thin already registered with pdfFont().
#
# More than one version of regular/bold/italic found for Umpush. Skipping setup for this font.
#
# Uroob already registered with pdfFont().
#
# utkal already registered with pdfFont().
#
# Vemana2000 already registered with pdfFont().
#
# Verdana already registered with pdfFont().
#
# Waree already registered with pdfFont().
#
# Webdings already registered with pdfFont().
#
# Yrsa already registered with pdfFont().
#
# Yrsa Light already registered with pdfFont().
#
# Yrsa Medium already registered with pdfFont().
#
# Yrsa SemiBold already registered with pdfFont().

# %% [markdown]
# # GO terms

# %%
GO_ID_terms <-  readRDS('../Pathway_plot//Rdata/GO_ID_terms.rds')

# %%
JA <- GO_ID_terms %>% filter(GO_ID == 'GO:0009753', code != 'IEA') %>% select(AGI)

# %%
PCD <- GO_ID_terms %>% filter(GO_ID == 'GO:0012501', code != 'IEA') %>% select(AGI)

# %% [markdown]
# **<span style="color:red">### remove TIR  and P-loop, only have 2 AGI</span>**

# %% [markdown]
# # Pathways

# %%
NLRs_and_TIRs <- read.csv(file = "../gene_table_and_other_scripts/NLRs_and_TIR_only.csv")

# %%
NLRs_and_TIRs
# Out:
#     AGI       Class        Symbol    Organization
# 1   AT1G09665 TIR          AT1G09665 NA
# 2   AT1G47370 TIR          AT1G47370 NA
# 3   AT1G51270 TIR          AT1G51270 NA
# 4   AT1G52900 TIR          AT1G52900 NA
# 5   AT1G57630 TIR          AT1G57630 NA
# 6   AT1G57670 TIR          AT1G57670 NA
# 7   AT1G57830 TIR          AT1G57830 NA
# 8   AT1G57850 TIR          AT1G57850 NA
# 9   AT1G60320 TIR          AT1G60320 NA
# 10  AT1G61105 TIR          AT1G61105 NA
# 11  AT1G65390 TIR          PP2-A5    NA
# 12  AT2G03030 TIR          AT2G03030 NA
# 13  AT2G03300 TIR          AT2G03300 NA
# 14  AT2G17055 TIR          AT2G17055 NA
# 15  AT2G20142 TIR          AT2G20142 NA
# 16  AT2G32140 TIR          AT2G32140 NA
# 17  AT4G04110 TIR          AT4G04110 NA
# 18  AT4G11340 TIR          AT4G11340 NA
# 19  AT4G19910 TIR          AT4G19910 NA
# 20  AT4G19920 TIR          AT4G19920 NA
# 21  AT4G19925 TIR          AT4G19925 NA
# 22  AT4G23510 TIR          AT4G23510 NA
# 23  AT4G23515 TIR          AT4G23515 NA
# 24  AT5G44900 TIR          AT5G44900 NA
# 25  AT5G44910 TIR          AT5G44910 NA
# 26  AT5G44920 TIR          AT5G44920 NA
# 27  AT5G45000 TIR          AT5G45000 NA
# 28  AT5G45070 TIR          PP2-A8    NA
# 29  AT5G45080 TIR          PP2-A6    NA
# 30  AT5G45090 TIR          PP2-A7    NA
# ⋮   ⋮         ⋮            ⋮         ⋮
# 168 AT5G45050 TIR-NBS-LRR  WRKY16    clustered
# 169 AT5G45060 TIR-NBS-LRR  AT5G45060 clustered
# 170 AT5G45200 TIR-NBS-LRR  AT5G45200 NA
# 171 AT5G45210 TIR-NBS-LRR  AT5G45210 NA
# 172 AT5G45220 TIR-NBS-LRR  AT5G45220 clustered
# 173 AT5G45230 TIR-NBS-LRR  AT5G45230 NA
# 174 AT5G45240 TIR-NBS-LRR  AT5G45240 NA
# 175 AT5G45250 TIR-NBS-LRR  RPS4      clustered
# 176 AT5G45260 TIR-NBS-LRR  RRS1      clustered
# 177 AT5G45440 P-loop       AT5G45440 NA
# 178 AT5G45490 P-loop       AT5G45490 NA
# 179 AT5G46260 TIR-NBS-LRR  AT5G46260 clustered
# 180 AT5G46270 TIR-NBS-LRR  AT5G46270 NA
# 181 AT5G46450 TIR-NBS-LRR  AT5G46450 NA
# 182 AT5G46470 TIR-NBS-LRR  RPS6      clustered
# 183 AT5G46490 TIR-NBS-LRR  AT5G46490 clustered
# 184 AT5G46510 TIR-NBS-LRR  VICTL     clustered
# 185 AT5G46520 TIR-NBS-LRR  ACQOS     clustered
# 186 AT5G47250 CC-NBS-LRR   AT5G47250 clustered
# 187 AT5G47260 CC-NBS-LRR   AT5G47260 NA
# 188 AT5G47280 RPW8-NBS-LRR ADR1-L3   clustered
# 189 AT5G48620 CC-NBS-LRR   AT5G48620 NA
# 190 AT5G48770 TIR-NBS-LRR  AT5G48770 clustered
# 191 AT5G48780 TIR-NBS      TN20      clustered
# 192 AT5G49140 TIR-NBS-LRR  AT5G49140 NA
# 193 AT5G51630 TIR-NBS-LRR  AT5G51630 singleton
# 194 AT5G58120 TIR-NBS-LRR  DM10      singleton
# 195 AT5G63020 CC-NBS-LRR   SUT1      singleton
# 196 AT5G66900 RPW8-NBS-LRR NRG1.1    clustered
# 197 AT5G66910 RPW8-NBS-LRR NRG1.2    clustered

# %%
Pathways_Ngou_2021 <- readxl::read_excel("../gene_table_and_other_scripts/Ngou_2021_Nature_figure2E_pathways_mod.xlsx")

# %%
Pathways <- Pathways_Ngou_2021 %>% dplyr::select(Target, GeneFamily)
Pathways <- Pathways %>%as.data.frame  %>% dplyr::rename('AGI' = 'Target')
LRRs <- Pathways %>% filter(GeneFamily %>% str_detect('LRR'))

# %%
LRRs
# Out:
#     AGI       GeneFamily
# 1   AT1G51820 LRR-RLKs
# 2   AT2G19190 LRR-RLKs
# 3   AT1G17750 LRR-RLKs
# 4   AT1G55610 LRR-RLKs
# 5   AT1G51890 LRR-RLKs
# 6   AT1G74360 LRR-RLKs
# 7   AT1G73080 LRR-RLKs
# 8   AT3G13380 LRR-RLKs
# 9   AT1G56140 LRR-RLKs
# 10  AT1G51800 LRR-RLKs
# 11  AT1G51860 LRR-RLKs
# 12  AT5G25930 LRR-RLKs
# 13  AT1G09970 LRR-RLKs
# 14  AT1G51850 LRR-RLKs
# 15  AT5G48380 LRR-RLKs
# 16  AT1G53440 LRR-RLKs
# 17  AT4G33430 LRR-RLKs
# 18  AT4G39270 LRR-RLKs
# 19  AT1G56145 LRR-RLKs
# 20  AT4G28490 LRR-RLKs
# 21  AT5G41180 LRR-RLKs
# 22  AT2G13790 LRR-RLKs
# 23  AT3G02880 LRR-RLKs
# 24  AT5G01950 LRR-RLKs
# 25  AT5G45840 LRR-RLKs
# 26  AT5G46330 LRR-RLKs
# 27  AT2G02220 LRR-RLKs
# 28  AT3G14840 LRR-RLKs
# 29  AT1G34420 LRR-RLKs
# 30  AT1G53430 LRR-RLKs
# ⋮   ⋮         ⋮
# 183 AT4G13920 LRR-RLPs
# 184 AT3G05650 LRR-RLPs
# 185 AT3G05370 LRR-RLPs
# 186 AT4G04220 LRR-RLPs
# 187 AT1G58190 LRR-RLPs
# 188 AT2G15080 LRR-RLPs
# 189 AT3G23010 LRR-RLPs
# 190 AT3G25020 LRR-RLPs
# 191 AT1G07390 LRR-RLPs
# 192 AT2G32680 LRR-RLPs
# 193 AT3G24900 LRR-RLPs
# 194 AT3G11010 LRR-RLPs
# 195 AT4G13900 LRR-RLPs
# 196 AT3G25010 LRR-RLPs
# 197 AT4G13880 LRR-RLPs
# 198 AT1G74170 LRR-RLPs
# 199 AT1G74200 LRR-RLPs
# 200 AT3G53240 LRR-RLPs
# 201 AT1G74180 LRR-RLPs
# 202 AT1G28340 LRR-RLPs
# 203 AT2G33060 LRR-RLPs
# 204 AT4G18760 LRR-RLPs
# 205 AT1G80080 LRR-RLPs
# 206 AT3G23110 LRR-RLPs
# 207 AT4G13810 LRR-RLPs
# 208 AT1G65380 LRR-RLPs
# 209 AT5G49290 LRR-RLPs
# 210 AT5G65830 LRR-RLPs
# 211 AT1G17250 LRR-RLPs
# 212 AT2G33050 LRR-RLPs

# %% [markdown]
# ## add GO terms

# %% [raw]
# Pathways <- Pathways %>% rbind(JA %>% mutate(GeneFamily ='JA reponse')) %>%
#     rbind(PCD %>% mutate(GeneFamily ='PCD'))

# %% [markdown]
# # Res

# %%
Res_adr1s <-  readRDS('../JC14_and_DMs/Rdata/Res_adr1.rds')
Res_3DM <-  readRDS('../3DM_shoot/Rds_Rdata/Res_3DM.2023-04-21 14:05:06rds')
Res_3DM_and_adr1s <- Res_3DM  %>% rbind(Res_adr1s)

# %%
Res_3DM
# Out:
#       AGI       baseMean     log2FoldChange lfcSE     stat
# 1     AT1G30814   30.3735985  5.18459620    1.1880403  4.36399006
# 2     AT1G78930  229.5290030  0.01991274    0.2313721  0.08606374
# 3     AT1G71695 4279.2158462 -2.30890364    0.3467650 -6.65841044
# 4     AT1G58983  160.5416134 -0.17951020    0.9294748 -0.19313078
# 5     AT1G12980    5.5871965  2.27948272    1.4560934  1.56547838
# 6     AT1G56250   66.5033746  0.77412597    0.7988443  0.96905738
# 7     AT1G66852    0.2392222  0.00000000    6.5584380  0.00000000
# 8     AT1G69810  174.6157257  2.76176191    0.6470886  4.26798103
# 9     AT1G72450 2731.0180974 -0.41945456    0.3845236 -1.09084205
# 10    AT1G76280  768.8420702 -0.42485352    0.1882657 -2.25667011
# 11    AT1G65630    4.2710497 -2.65909162    2.1405773 -1.24223104
# 12    AT1G71390  138.2415697  4.94242971    0.8212988  6.01782144
shoot  DM10/DM11 DM10/DM11_vs_Parents_DM10_DM11
# 79105 5.627868e-04 8.953411e-04 Shoot  DM10/DM11 DM10/DM11_vs_Parents_DM10_DM11
# 79106 3.543305e-02 4.844883e-02 Shoot  DM10/DM11 DM10/DM11_vs_Parents_DM10_DM11
# 79107 2.613901e-02 3.626115e-02 Shoot  DM10/DM11 DM10/DM11_vs_Parents_DM10_DM11
#       gene_name
# 1     AT1G30814
# 2     AT1G78930
# 3     AT1G71695
# 4     AT1G58983
# 5     ESR1
# 6     PP2-B14
# 7     AT1G66852
# 8     WRKY36
# 9     JAZ6
# 10    AT1G76280
# 11    DEG3
# 12    RLP11
# 13    ABCG35
# 14    AT1G15250
# 15    WRI4
# 16    HDG11
# 17    AT1G16360
# 18    AT1G10225
# 19    VTI1B
# 20    AT1G52200
# 21    VIM5
# 22    AT1G69460
# 23    ERS2
# 24    ACA7
# 25    AT1G75550
# 26    SUC5
# 27    AT1G05430
# 28    AT1G80870
# 29    AUL1
# 30    SEC1A
# ⋮     ⋮
# 79078 NA
# 79079 NA
# 79080 NA
# 79081 NA
# 79082 NA
# 79083 NA
# 79084 NA
# 79085 NA
# 79086 NA
# 79087 NA
# 79088 NA
# 79089 NA
# 79090 NA
# 79091 NA
# 79092 NA
# 79093 NA
# 79094 NA
# 79095 NA
# 79096 NA
# 79097 NA
# 79098 NA
# 79099 NA
# 79100 NA
# 79101 NA
# 79102 NA
# 79103 NA
# 79104 NA
# 79105 NA
# 79106 NA
# 79107 NA

# %%
Res_Pathogen <- readRDS('../RNA_seq_Pathogen/Rds_Rdata_hisat2//Res2023-04-21 15:54:40.rdata') %>% filter(Contrast %>% str_detect('Mock') ) %>%filter(Contrast %>% str_detect('Avr'))
Res_Pathogen <- Res_Pathogen %>% select(Gene, log2FoldChange, Contrast)  %>% dplyr::rename('source' = 'Contrast', 'AGI' = 'Gene')

# %%
Res_Pathogen %>% distinct()
# Out:
#        AGI       log2FoldChange source
# 1      AT1G30814 -0.829686864   AvrRpt2-6h_vs_Mock-6h
# 2      AT1G78930 -0.011894928   AvrRpt2-6h_vs_Mock-6h
# 3      AT1G71695 -0.098855557   AvrRpt2-6h_vs_Mock-6h
# 4      AT1G58983  0.083782797   AvrRpt2-6h_vs_Mock-6h
# 5      AT1G12980 -2.460711255   AvrRpt2-6h_vs_Mock-6h
# 6      AT1G56250  0.254901801   AvrRpt2-6h_vs_Mock-6h
# 7      AT1G69810  0.661998002   AvrRpt2-6h_vs_Mock-6h
# 8      AT1G72450  1.784604326   AvrRpt2-6h_vs_Mock-6h
# 9      AT1G76280 -0.340306572   AvrRpt2-6h_vs_Mock-6h
# 10     AT1G65630  3.550340403   AvrRpt2-6h_vs_Mock-6h
# 11     AT1G71390  0.123862863   AvrRpt2-6h_vs_Mock-6h
# 12     AT1G15210  0.632287388   AvrRpt2-6h_vs_Mock-6h
# 13     AT1G15250  0.017734817   AvrRpt2-6h_vs_Mock-6h
# 14     AT1G79700  0.251224736   AvrRpt2-6h_vs_Mock-6h
# 15     AT1G73360 -0.138606596   AvrRpt2-6h_vs_Mock-6h
# 16     AT1G16360 -0.342953918   AvrRpt2-6h_vs_Mock-6h
# 17     AT1G10225 -0.958616702   AvrRpt2-6h_vs_Mock-6h
# 152464 ATCG00920  0.18194569    AvrRps4-20h_vs_Mock-20h
# 152465 ATCG01180 -0.05034659    AvrRps4-20h_vs_Mock-20h
# 152466 ATCG00950 -0.02832499    AvrRps4-20h_vs_Mock-20h

# %%
Res_adr1s <-  readRDS('../JC14_and_DMs/Rdata/Res_adr1.rds')
Res_adr1s <-  Res_adr1s %>% select(AGI, log2FoldChange, line) %>% dplyr::rename('source' = 'line')

Res_3DM <-  readRDS('../3DM_shoot/Rds_Rdata/Res_3DM.2023-04-21 14:05:06rds')
Res_3DM <- Res_3DM %>% select(AGI, log2FoldChange, line)%>% dplyr::rename('source' = 'line')

# Res_Pathogen <- readRDS('../RNA_seq_Pathogen/Rds_Rdata_hisat2//Res2023-04-21 15:54:40.rdata')
# Res_Pathogen <- Res_Pathogen %>% select(Gene, log2FoldChange, Contrast)  %>% dplyr::rename('source' = 'Contrast', 'AGI' = 'Gene')
# Res_Pathogen <- Res_Pathogen %>% filter( source %>% str_detect('control', negate = T) )# %>% pull(source) %>% unique

Res_combined <- Res_3DM %>% rbind(Res_Pathogen)  %>% rbind(Res_adr1s)
Res_combined <- Res_combined %>% dplyr::rename('log2FC' = 'log2FoldChange')
Res_combined <- Res_combined %>% mutate(source = source %>% str_remove('_vs_Mock-\\d{1,2}h$'))

# %% [raw]
# Res_combined %>% saveRDS('./Rdata/Res_combined.rds')

# %%
Res_combined %>% pull(source) %>% unique
# Out:
#  [1] "DM6/DM7"        "DM1/DM2d"       "DM10/DM11"      "AvrRpt2-6h"
#  [5] "AvrRpt2-12h"    "AvrRpt2-20h"    "AvrRps4-6h"     "AvrRps4-12h"
#  [9] "AvrRps4-20h"    "DM1/DM2d_adr1s" "DM6/DM7_adr1s"  "Col-0_adr1s"

# %%
Res_combined <- Res_combined %>% mutate(source = factor(source, levels = c('DM10/DM11','DM1/DM2d','DM1/DM2d_adr1s','DM6/DM7','DM6/DM7_adr1s','Col-0_adr1s','AvrRpt2-6h','AvrRpt2-12h','AvrRpt2-20h','AvrRps4-6h','AvrRps4-12h','AvrRps4-20h')) )
Res_combined$source %>% unique
# Out:
#  [1] DM6/DM7        DM1/DM2d       DM10/DM11      AvrRpt2-6h     AvrRpt2-12h
#  [6] AvrRpt2-20h    AvrRps4-6h     AvrRps4-12h    AvrRps4-20h    DM1/DM2d_adr1s
# [11] DM6/DM7_adr1s  Col-0_adr1s
# 12 Levels: DM10/DM11 DM1/DM2d DM1/DM2d_adr1s DM6/DM7 ... AvrRps4-20h

# %%
Res_combined %>% filter(AGI == 'AT4G36150')
# Out:
#    AGI       log2FC     source
# 1  AT4G36150  1.3264480 DM6/DM7
# 2  AT4G36150  1.4379916 DM1/DM2d
# 3  AT4G36150  2.5587729 DM10/DM11
# 4  AT4G36150 -0.3341114 AvrRpt2-6h
# 5  AT4G36150  0.5390591 AvrRpt2-12h
# 6  AT4G36150  1.4327750 AvrRpt2-20h
# 7  AT4G36150 -0.5822040 AvrRps4-6h
# 8  AT4G36150  0.3559742 AvrRps4-12h
# 9  AT4G36150  1.2998659 AvrRps4-20h
# 10 AT4G36150  1.3423115 DM6/DM7_adr1s
# 11 AT4G36150  0.8942393 DM1/DM2d_adr1s
# 12 AT4G36150  0.3176976 Col-0_adr1s

# %%
custom_colors <- c(
  "DM6/DM7" = "#F8766D", 'DM1/DM2d' = '#FB61D7', 'DM10/DM11' = '#A58AFF',
  'Col-0_12' = '#9ccf2d', 'Col-0_14' = '#00C094',
  'Tuescha-9' = '#07a822', 'Cdm-0' = '#00A9FF',
  "control" = "#72A063",
  "Mock-6h" = "#94B6CD", "Mock-12h" = "#6D9AB9", "Mock-20h" = "#4579A1", 
  # "AvrRps4-6h" = "#d5bae3", "AvrRps4-12h" = "#a57dba", "AvrRps4-20h" = "#C452B5", 
  # "AvrRpt2-6h" = "#e3c79a", "AvrRpt2-12h" = "#F2AB5C", "AvrRpt2-20h" = "#EE8237",
    "AvrRps4-6h" = "#dcc0eb", "AvrRps4-12h" = "#a884ba", "AvrRps4-20h" = "#cfa3e6", 
  "AvrRpt2-6h" = "#e8bea0", "AvrRpt2-12h" = "#f0b48b", "AvrRpt2-20h" = "#f09f67",
  'DM6/DM7_adr1s' = '#ffc14d', 'DM1/DM2d_adr1s' = '#2a6fdb', 'Col-0_adr1s' = '#ddacf5'
)

bar_colors <-  c("DM6/DM7 vs Col-0" = "#EDC5BF", 'DM1/DM2d vs Col-0' = '#C894B8', 
                                 'DM10/DM11' = '#D1CDE6', 
                   'DM6/DM7_adr1s vs Col-0' = '#008DFA' , 'DM1/DM2d_adr1s vs Col-0' = '#008DFA', 
                 'Col-0_adr1s vs Col-0' = '#008DFA',
                  "AvrRps4-6h" = "#dcc0eb", "AvrRps4-12h" = "#a884ba", "AvrRps4-20h" = "#cfa3e6", 
  "AvrRpt2-6h" = "#e8bea0", "AvrRpt2-12h" = "#f0b48b", "AvrRpt2-20h" = "#f09f67")

# %%
custom_colors <- c(
  "DM6/DM7" = "#F8766D", 'DM1/DM2d' = '#FB61D7', 'DM10/DM11' = '#A58AFF',
  'Col-0_12' = '#9ccf2d', 'Col-0_14' = '#00C094',
  'Tuescha-9' = '#07a822', 'Cdm-0' = '#00A9FF',
  "control" = "#72A063",
  "Mock-6h" = "#94B6CD", "Mock-12h" = "#6D9AB9", "Mock-20h" = "#4579A1", 
  # "AvrRps4-6h" = "#d5bae3", "AvrRps4-12h" = "#a57dba", "AvrRps4-20h" = "#C452B5", 
  # "AvrRpt2-6h" = "#e3c79a", "AvrRpt2-12h" = "#F2AB5C", "AvrRpt2-20h" = "#EE8237",
    "AvrRps4-6h" = "#dcc0eb", "AvrRps4-12h" = "#a884ba", "AvrRps4-20h" = "#cfa3e6", 
  "AvrRpt2-6h" = "#e8bea0", "AvrRpt2-12h" = "#f0b48b", "AvrRpt2-20h" = "#f09f67",
  'DM6/DM7_adr1s' = '#ffc14d', 'DM1/DM2d_adr1s' = '#2a6fdb', 'Col-0_adr1s' = '#ddacf5'
)

bar_colors <-  c("DM6/DM7 vs Col-0" = "#EDC5BF", 'DM1/DM2d vs Col-0' = '#C894B8', 
                                 'DM10/DM11' = '#D1CDE6', 
                   'DM6/DM7_adr1s vs Col-0' = '#008DFA' , 'DM1/DM2d_adr1s vs Col-0' = '#008DFA', 
                 'Col-0_adr1s vs Col-0' = '#008DFA',
                 "DM6/DM7" = "#EDC5BF", 'DM1/DM2d' = '#C894B8', 
                                 'DM10/DM11' = '#D1CDE6', 
                   'DM6/DM7_adr1s' = '#008DFA' , 'DM1/DM2d_adr1s' = '#008DFA', 
                 'Col-0_adr1s' = '#008DFA',
                  "AvrRps4-6h" = "#dcc0eb", "AvrRps4-12h" = "#cfa3e6", "AvrRps4-20h" = "#a884ba", 
  "AvrRpt2-6h" = "#e8bea0", "AvrRpt2-12h" = "#f0b48b", "AvrRpt2-20h" = "#cf8655")

# %% [markdown]
# # Venn

# %%
NLRs_Res_3DM_and_adr1s <- Res_3DM_and_adr1s %>% right_join(NLRs_and_TIRs, by = 'AGI')

# %%
up_NLRs <- list(
  'DM6/DM7' = NLRs_Res_3DM_and_adr1s %>% filter(baseMean > 5, log2FoldChange > 2, line == 'DM6/DM7', padj < 0.05) %>%
    arrange(desc(log2FoldChange)) %>% ##by default arrange is ascending
    pull(AGI),
  'DM1/DM2d' = NLRs_Res_3DM_and_adr1s %>% filter(baseMean > 5, log2FoldChange > 2, line == 'DM1/DM2d', padj < 0.05) %>%
    arrange(desc(log2FoldChange)) %>% ##by default arrange is ascending
    pull(AGI),
  'DM10/DM11' = NLRs_Res_3DM_and_adr1s %>% filter(baseMean > 5, log2FoldChange > 2, line == 'DM10/DM11', padj < 0.05) %>%
    arrange(desc(log2FoldChange)) %>% ##by default arrange is ascending
    pull(AGI),
  'DM1/DM2d_adr1s' = NLRs_Res_3DM_and_adr1s %>% filter(baseMean > 5, line == 'DM1/DM2d_adr1s', padj < 0.05, log2FoldChange > 2) %>%
    arrange(desc(log2FoldChange)) %>%
    pull(AGI),
  'DM6/DM7_adr1s' = NLRs_Res_3DM_and_adr1s %>% filter(baseMean > 5, line == 'DM6/DM7_adr1s', padj < 0.05, log2FoldChange > 2) %>%
    arrange(desc(log2FoldChange)) %>%
    pull(AGI),
  'Col-0_adr1s' = NLRs_Res_3DM_and_adr1s %>% filter(baseMean > 5, line == 'Col-0_adr1s', padj < 0.05, log2FoldChange > 2) %>%
    arrange(desc(log2FoldChange)) %>%
    pull(AGI)
    
)
up_NLRs
# Out:
# $`DM6/DM7`
#  [1] "AT4G23515" "AT5G44900" "AT5G38344" "AT4G11170" "AT4G27220" "AT5G44920"
#  [7] "AT3G04220" "AT5G45000" "AT5G38350" "AT5G45090" "AT1G72860" "AT2G17050"
# [13] "AT1G17615" "AT2G20142" "AT3G25510" "AT1G58390" "AT5G18350" "AT5G44910"
# [19] "AT5G41750" "AT1G59780" "AT3G44400" "AT4G23510" "AT2G17060" "AT5G38340"
# [25] "AT5G45070" "AT1G65850" "AT2G16870" "AT4G14370" "AT2G32140" "AT5G41550"
# [31] "AT5G46260" "AT4G33300" "AT5G18360" "AT1G57650" "AT1G72950" "AT1G72900"
# [37] "AT1G12290" "AT5G05400" "AT1G15890" "AT1G33560"
#
# 5      ESR1
# 6      PP2-B14
# 7      AT1G66852
# 8      WRKY36
# 9      JAZ6
# 10     AT1G76280
# 11     DEG3
# 12     RLP11
# 13     ABCG35
# 14     AT1G15250
# 15     WRI4
# 16     HDG11
# 17     AT1G16360
# 18     AT1G10225
# 19     VTI1B
# 20     AT1G52200
# 21     VIM5
# 22     AT1G69460
# 23     ERS2
# 24     ACA7
# 25     AT1G75550
# 26     SUC5
# 27     AT1G05430
# 28     AT1G80870
# 29     AUL1
# 30     SEC1A
# ⋮      ⋮
# 159235 DPBF2
# 159236 NA
# 159237 AT3G01313
# 159238 NA
# 159239 NA
# 159240 NA
# 159241 AT3G04975
# 159242 MPC
# 159243 AT5G44310
# 159244 AT3G13433
# 159245 NA
# 159246 AT2G08820
# 159247 AT5G22470
# 159248 AT2G42560
# 159249 HDG8
# 159250 AT1G71000
# 159251 AT3G25240
# 159252 AT3G17520
# 159253 AT2G17680
# 159254 SESA1
# 159255 SESA2
# 159256 AT3G24750
# 159257 DDF1
# 159258 LEA7
# 159259 BSMT1
# 159260 AT5G44310
# 159261 AT4G21020
# 159262 AT1G04560
# 159263 AT1G72100
# 159264 PUP15

# %% [raw]
# draw_venn_diagram <- function(df = up, fontfamily = 'sans', alpha = c(0.5, 0.5, 0.5, 0.5, 0.5),
#                               fill = c("#F8766D", "#FB61D7", "#A58AFF", '#2a6fdb', '#ffc14d'),
#                               plot_title = 'DEG', filename = paste0("./plots/Venn", Sys.time(), ".pdf")) {
#
#   venn_plot <- venn.diagram(df, fill = fill,
#                             alpha = alpha,
#                             filename = NULL, cat.dist = 0.07,
#                             lty = 'blank', sub.fontfamily = fontfamily,
#                             cat.fontfamily = fontfamily,
#                             main = plot_title,
#                             main.pos = c(0.5, 1.1), main.fontface = "plain",
#                             main.fontfamily = fontfamily, main.col = "black",
#                             main.cex = 1.5, cat.cex = 1.5, cex = 1,  # font size of plot title, category, and label(number)
#                             fontfamily = fontfamily,
#                             ggplot = T)
#
#   pdf(file = filename, width = 6, height = 6)
#   grid.newpage()
#   grid.draw(venn_plot)
#   dev.off()
# }
#
# draw_venn_diagram(df = up_DEG[1:5], fontfamily = 'sans', plot_title = '',
#                   filename = paste0("./plots/Up_Venn_NLRs", Sys.time(), ".pdf"), alpha = c(0.5, 0.5, 0.5, 0.5, 0.5))

# %% [raw]
# DMs_5_common <- tibble(AGI = Reduce(intersect, up_DEG[1:5])) %>% left_join( NLRs_and_TIRs , by ='AGI')
# DMs_5_common

# %% [raw]
# DMs_3_common <- tibble(AGI = Reduce(intersect, up_DEG[1:3])) %>% left_join( NLRs_and_TIRs , by ='AGI')
# DMs_3_common

# %% [raw]
# DMs_3_common %>% anti_join(DMs_5_common, by = 'AGI')

# %% [markdown]
# # Bar plot of NLRs

# %%
Res_combined %>% filter(AGI  == 'AT4G14390')
# Out:
#    AGI       log2FC      source
# 1  AT4G14390  6.35565974 DM6/DM7
# 2  AT4G14390  8.05872953 DM1/DM2d
# 3  AT4G14390  8.98735730 DM10/DM11
# 4  AT4G14390  0.04927757 AvrRpt2-6h
# 5  AT4G14390  0.00000000 AvrRpt2-12h
# 6  AT4G14390  0.17014255 AvrRpt2-20h
# 7  AT4G14390  0.06511173 AvrRps4-6h
# 8  AT4G14390  3.58068134 AvrRps4-12h
# 9  AT4G14390  1.63150265 AvrRps4-20h
# 10 AT4G14390  8.21308555 DM1/DM2d_adr1s
# 11 AT4G14390  3.66828427 DM6/DM7_adr1s
# 12 AT4G14390 -4.24298296 Col-0_adr1s

# %%
library(glue)
library(ggtext)

# %%
options(repr.plot.width=8, repr.plot.height=4)
cols_text <- c( 'TIR-NBS-LRR' =  "#386cb0",
          'TIR'= "#a6cee3", "TIR-NBS" = "#2581ba",
          
          "CC-NBS-LRR" = "#fdb462",'CC-NBS' =  "#fb9a99", 'RPW8-NBS-LRR' = "#984ea3",
          
          'NBS-LRR' = "#b3b330", 
          'P-loop' = "#7fc97f"
         )

# show_col(cols_text, ncol = 6)
# cols_text
cols_text_2 <- cols_text %>% as.data.frame() %>%  tibble::rownames_to_column("Class") %>% rename(label_color = 2)

# %%
Res_NLRs <- Res_combined %>% right_join(NLRs_and_TIRs, by = 'AGI')

# %%
Res_NLRs <- Res_NLRs %>% 
    mutate(plot_label = paste0(Symbol, '_', AGI) %>% str_remove('AT\\d{1}G\\d{5}_') ) %>% 
    left_join(cols_text_2, by = 'Class')

# %%
# Extract plot_label and label_color from Res_NLRs_up
plot_label_color <- Res_NLRs %>% select(plot_label, label_color)

# Create a named list with label_color as content and plot_label as names
color_list <- setNames(as.list(plot_label_color$label_color), plot_label_color$plot_label)

# %% [raw]
# color_list

# %%
Res_NLRs_color <- Res_NLRs %>% mutate(label_color_markdown =
        glue("<i style='color: {color_list[plot_label]}'>{plot_label}</i>"))

# %% [markdown]
# <i style='color: #386cb0'>AT1G65850</i>

# %% [markdown]
# <i style='color: green'>the idea here is that pre set order x = reorder(label_color_markdown, log2FoldChange) is not preserved, I have to plot 3 geom_bar first, then put the hundreds layers of each NLRs geom_bar over it. </i>

# %%
keep_NLRs <-  c (Res_NLRs_color %>% filter(abs(log2FC) > 2) %>% pull(AGI) %>% unique(),
                 'AT5G66900') #add nrg1.1

# %%
Res_NLRs_color <- Res_NLRs_color %>% dplyr::filter(AGI %in% keep_NLRs )
Res_NLRs_color <- Res_NLRs_color %>% arrange(desc(log2FC))

# %%
Res_NLRs_color <- Res_NLRs_color %>% mutate(category = source %>% str_remove('_adr1s') %>% str_remove('-\\d{1,2}h$'))

# %%
each_NLR_max_log2FC <- Res_NLRs_color %>% group_by(AGI) %>% slice_head(n=1) %>% ungroup %>% arrange(desc(log2FC))

# %%
each_NLR_Col_log2FC <- Res_NLRs_color %>% filter(source == 'Col-0_adr1s' ) %>%
     arrange(desc(log2FC))

# %%
Res_NLRs_color <- Res_NLRs_color %>% mutate(source = source %>% str_replace('DM6/DM7$', 'DM6/DM7 vs Col-0') %>%
        str_replace('DM6/DM7_adr1s', 'DM6/DM7_adr1s vs Col-0') %>%
        str_replace('DM1/DM2d$', 'DM1/DM2d vs Col-0') %>% str_replace('DM1/DM2d_adr1s', 'DM1/DM2d_adr1s vs Col-0') %>%
        str_replace('Col-0_adr1s', 'Col-0_adr1s vs Col-0')
                         )

# %%
library(ggplot2)
library(dplyr)

# Define the mapping of facet levels to colors
facet_colors <- data.frame(
  module = c("MEblue", "MEpurple", "MEdarkturquoise", "MEcyan", "MEdarkred", "MEgreenyellow", "MEsalmon", "MEtan", "MEdarkgreen", "MEmidnightblue"),
  color = c("#0000FF", "#800080", "#00CED1", "#00FFFF", "#8B0000", "#ADFF2F", "#FA8072", "#D2B48C", "#006400", "#00009C")
)

# %%
options(repr.plot.width=8.4, repr.plot.height=6, repr.plot.res = 50)


plot_NLRs_overlay_bar <- function(Res = Res_NLRs_color, Res_base = each_NLR_Col_log2FC,  alpha = 0.6, facet_row = "Class", facet_col = "category") {
  library(purrr)
  library(rlang) # for sym()
    Res <- Res %>% left_join(facet_colors, by = facet_row)
  # Convert facet strings to symbols
  facet_row <- sym(facet_row)
  facet_col <- sym(facet_col)
  
  # Step 1: Split the dataframe based on log2FoldChange
  over0 <- Res %>% filter(log2FC > 0) 
  below0 <- Res %>% filter(log2FC <= 0)

  # Step 2: Create a list to store the dataframes for each layer
  layers <- list()

  # Step 3: Iterate until there are no rows left in over0 and below0
  layer_num <- 1
  while (nrow(over0) > 0 || nrow(below0) > 0) {
    max_over0 <- over0 %>% group_by( AGI) %>% slice_max(log2FC)
    min_below0 <- below0 %>% group_by( AGI) %>% slice_min(log2FC)

    over0 <- suppressMessages(anti_join(over0, max_over0))
    below0 <- suppressMessages(anti_join(below0, min_below0))

    layer <- bind_rows(max_over0, min_below0)
    layers[[layer_num]] <- layer

    layer_num <- layer_num + 1
  }

  # Step 4: Use the layers list to add new layers to the ggplot using geom_bar
  bar_NLRs_base <- Res %>%
      ggplot(aes(x = reorder(label_color_markdown, log2FC), y = log2FC, label = label_color_markdown)) +
      geom_rect(aes(xmin = -Inf, xmax = Inf, ymin = -Inf, ymax = Inf, fill = color), alpha = 0.2) + 
    labs(y = "Log2 FoldChange") +
    coord_flip() +
    guides(fill = guide_legend(reverse = TRUE, nrow = 2)) +
    scale_y_continuous(breaks = c(-8,-6, -4, -2, 0, 2, 4, 6, 8, 10, 12, 14, 16),
                       expand = c(0, 0)) +
    scale_fill_manual(values = bar_colors)+
    theme_Publication() +
    theme(axis.text = element_text(size = 10, face = "bold"),
          axis.title = element_text(size = 12, face = "bold"),
          axis.title.y = element_blank()) +
    theme(text = element_text(size = 12, family = "sans", face = 'bold'), 
          strip.text = element_text(size = 12)) +
    facet_grid(rows = vars(!!facet_row), cols = vars(!!facet_col), scales = "free", space = "free") + # use !! to evaluate symbols
    theme(axis.text.y = element_markdown())   +
    geom_bar(data = Res_base,
                 position="identity", stat='identity', aes(fill=source), width = .8,  alpha = 0 ) +
    

  bar_NLRs <- reduce(layers, function(plot, layer) {
    plot +
      geom_bar(data = layer,
               position = "identity",
               stat = 'identity',
               aes(fill = source),
               width = .8,
               alpha = alpha)
  }, .init = bar_NLRs_base)
  bar_NLRs <- bar_NLRs + geom_hline(yintercept=0,  color = "black", size=0.5)
  # Return the final plot
  return(bar_NLRs)
}

# Usage example
bar_NLRs_plot <- plot_NLRs_overlay_bar(Res_NLRs_color, alpha = 0.7, facet_row = "Class", facet_col = "category")
bar_NLRs_plot

# Save the final plot to a PDF file
bar_NLRs_plot %>% ggsave(file = paste0("./plots/overlap_bar_NLRs", Sys.time(), ".pdf"), width = 14 , height = 28)
# Out:
# Error in `left_join()`:
# ! Join columns in `y` must be present in the data.
# ✖ Problem with `Class`.
# Traceback:
#
# 1. plot_NLRs_overlay_bar(Res_NLRs_color, alpha = 0.7, facet_row = "Class",
#  .     facet_col = "category")
# 2. Res %>% left_join(facet_colors, by = facet_row)   # at line 7 of file <text>
# 3. left_join(., facet_colors, by = facet_row)
# 4. left_join.data.frame(., facet_colors, by = facet_row)
# 5. join_mutate(x = x, y = y, by = by, type = "left", suffix = suffix,
#  .     na_matches = na_matches, keep = keep, multiple = multiple,
#  .     unmatched = unmatched, relationship = relationship, user_env = caller_env())
# 6. join_cols(x_names = x_names, y_names = y_names, by = by, suffix = suffix,
#  .     keep = keep, error_call = error_call)
# 7. check_join_vars(by$y, y_names, by$condition, "y", error_call = error_call)
# 8. abort(bullets, call = error_call)
# 9. signal_abort(cnd, .file)

# %%
NLRs_in_connectivity_table <- read.csv('./WGCNA_output_all/NLRs_and_TIRs_connectivity_table_info.csv')

# %%
Res_NLRs_in_connectivity_table <- NLRs_in_connectivity_table %>% dplyr::rename('AGI' = 'gene') %>% 
    left_join(Res_NLRs_color, by = 'AGI') %>% filter(category != 'DM10/DM11') %>% distinct

# %%
Res_NLRs_in_connectivity_table <- Res_NLRs_in_connectivity_table %>% mutate(module = factor(module, levels = c('MEblue','MEpurple','MEdarkturquoise',   'MEcyan','MEdarkred',
            'MEgreenyellow','MEsalmon','MEtan','MEdarkgreen','MEmidnightblue') %>% rev()))

# %%
Res_NLRs_in_connectivity_table_Col <- Res_NLRs_in_connectivity_table %>% 
        filter(source == 'Col-0_adr1s vs Col-0' ) %>% arrange(desc(log2FC))

# %%
theme_custom <- function() {
  theme(
    text = element_text(family = "Arial", size = 8, face = "plain"),  # Set face = "plain" for all text
    axis.title = element_text(family = "Arial", size = 8, face = "plain"),  # Overrides for axis titles
    axis.text = element_text(family = "Arial", size = 8, face = "plain"),   # Overrides for axis text
    legend.title = element_text(family = "Arial", size = 8, face = "plain"),  # Overrides for legend titles
    legend.text = element_text(family = "Arial", size = 8, face = "plain"),  # Overrides for legend text
    strip.text.x = element_text(family = "Arial", size = 8, face = "plain"),  # Specific adjustment for x facet label
    strip.text.y = element_text(family = "Arial", size = 8, angle = 0, face = "plain")  # Specific adjustment for y facet label
  )
}



width_ = 7.2
height_ = 7.5
options(repr.plot.width= width_ , repr.plot.height= height_ , repr.plot.res = 100)

bar_NLRs_plot <- plot_NLRs_overlay_bar(Res = Res_NLRs_in_connectivity_table , 
                      Res_base = Res_NLRs_in_connectivity_table_Col, 
                      facet_row = "module", alpha = 0.7) + 
                theme( strip.text.y = element_text(angle = 0)) + theme_custom() # Make facet labels horizontal)
# Save the final plot to a PDF file
bar_NLRs_plot
bar_NLRs_plot %>% ggsave(file = paste0("./plots/overlap_bar_NLRs", Sys.time(), ".pdf"),
                         width = width_ , height = height_)
# bar_NLRs_plot %>% ggsave(file = paste0("./plots/overlap_bar_NLRs", Sys.time(), ".png"), width = 14 , height = 10)

# %% [markdown]
# ### ADR1s helps to maintain a basal level of NLRs in WT non-challenged state,

# %%
LRRs_connectivity_table_info <- read.csv('./WGCNA_output_all/LRRs_connectivity_table_info.csv')

# %%
Res_LRRs <- Res_combined %>% left_join(map_id_name, by = c('AGI' = 'gene_id')) %>%
    mutate(label_color_markdown = paste0(gene_name, '_', AGI) %>% str_remove('AT\\d{1}G\\d{5}_') ) %>% 
    right_join(LRRs_connectivity_table_info, by = c('AGI'= 'gene')) %>% mutate(category = source %>% str_remove('_adr1s') %>% str_remove('-\\d{1,2}h$')) %>% filter(category != 'DM10/DM11')

# %%
Res_LRRs <- Res_LRRs %>% mutate(module = factor(module, levels = c('MEblue','MEpurple','MEdarkturquoise',   'MEcyan','MEdarkred',
            'MEgreenyellow','MEsalmon','MEtan','MEdarkgreen','MEmidnightblue') %>% rev()))

# %%
Res_LRRs_Col <- Res_LRRs %>% filter(source == 'Col-0_adr1s' ) %>%
     arrange(desc(log2FC))

# %%
width_ = 8.1
height_ = 4.5
options(repr.plot.width= width_ , repr.plot.height= height_ , repr.plot.res = 100)

bar_LRR <- plot_NLRs_overlay_bar(Res = Res_LRRs %>% filter(GeneFamily %>% str_detect('RLP')) , 
                      Res_base = Res_LRRs_Col  %>% filter(GeneFamily %>% str_detect('RLP')) , 
                      facet_row = "module", alpha = 0.7) + theme( strip.text.y = element_text(angle = 0))  # Make facet labels horizontal)
# Save the final plot to a PDF file
bar_LRR
bar_LRR %>% ggsave(file = paste0("./plots/RLP_overlap_bar_LRRs", Sys.time(), ".pdf"), width = width_ , height = height_)

# %%
Res_LRRs %>% filter(GeneFamily %>% str_detect('RLK')) %>% pull(AGI) %>% unique %>% length

# %%
filtered_RLKs <- Res_LRRs %>% filter(GeneFamily %>% str_detect('RLK')) %>% filter(abs(log2FC) > 2) %>% pull(AGI) %>% unique

# %%
width_ = 8.1
height_ = 13
options(repr.plot.width= width_ , repr.plot.height= height_ , repr.plot.res = 40)

bar_LRR <- plot_NLRs_overlay_bar(Res = Res_LRRs %>% filter(GeneFamily %>% str_detect('RLK')) , 
                      Res_base = Res_LRRs_Col  %>% filter(GeneFamily %>% str_detect('RLK')) , 
                      facet_row = "module", alpha = 0.7) + theme( strip.text.y = element_text(angle = 0))  # Make facet labels horizontal)
# Save the final plot to a PDF file
bar_LRR
bar_LRR %>% ggsave(file = paste0("./plots/all_RLK_overlap_bar_LRRs", Sys.time(), ".pdf"), width = width_ , height = height_)

# %%
Res_LRRs %>% filter(AGI %in% filtered_RLKs) %>% names

# %%
Res_LRRs %>% filter(AGI %in% filtered_RLKs)%>% filter(module == 'MEblue') %>% 
     select(-log2FC, - source, - category) %>% distinct %>% filter(`DM1.DM2d` < -1, `Col.0_adr1s` > 1) %>%
    arrange(`DM1.DM2d`)
    write.csv('./WGCNA_output_all/filtered_RLKs.csv')

# %%
Res_LRRs %>% filter(AGI %in% filtered_RLKs)%>% filter(module == 'MEblue') %>% 
     select(-log2FC, - source, - category) %>% distinct %>% filter(`DM1.DM2d` < -1, `Col.0_adr1s` > 1) %>%
    arrange(`DM1.DM2d`) %>%
    write.csv('./WGCNA_output_all/filtered_RLKs.csv')

# %%
width_ = 8.1
height_ = 11
options(repr.plot.width= width_ , repr.plot.height= height_ , repr.plot.res = 40)

bar_LRR <- plot_NLRs_overlay_bar(Res = Res_LRRs %>% filter(AGI %in% filtered_RLKs) , 
                      Res_base = Res_LRRs_Col  %>% filter(AGI %in% filtered_RLKs) , 
                      facet_row = "module", alpha = 0.7) + theme( strip.text.y = element_text(angle = 0))  # Make facet labels horizontal)
# Save the final plot to a PDF file
bar_LRR
bar_LRR %>% ggsave(file = paste0("./plots/RLK_overlap_bar_LRRs", Sys.time(), ".pdf"), width = width_ , height = height_)

# %%
Res_LRRs %>% pull(AGI) %>% unique %>% length

# %%
filtered_LRRs <- Res_LRRs  %>% filter(abs(log2FC) > 2) %>% pull(AGI) %>% unique 
filtered_LRRs <- c(filtered_LRRs, "AT3G23110")
filtered_LRRs %>% length

# %%
library(glue)
library(ggtext)

generate_Res_color <- function(cols_text, Res) {
  cols_text_2 <- cols_text %>% as.data.frame() %>%  tibble::rownames_to_column("Class") %>% rename(label_color = 2)

  Res <- Res %>% 
      mutate(plot_label = paste0(Symbol, '_', AGI) %>% str_remove('AT\\d{1}G\\d{5}_') ) %>% 
      left_join(cols_text_2, by = 'Class')  

  # Extract plot_label and label_color from Res_NLRs and
  plot_label_color <- Res %>% select(plot_label, label_color)

  # Create a named list with label_color as content and plot_label as names
  color_list <- setNames(as.list(plot_label_color$label_color), plot_label_color$plot_label)

  Res_color <- Res %>% mutate(label_color_markdown =
          glue("<i style='color: {color_list[plot_label]}'>{plot_label}</i>")) 

  return(Res_color)
}

# %%
Res_LRRs %>% names

# %%
cols_text_LRRs <- c( 'LRR-RLKs' =  "#386cb0",
                 'LRR-RLPs' = "#984ea3" )
Res_LRRs_color <- generate_Res_color(cols_text_LRRs, Res_LRRs %>% filter(AGI %in% filtered_LRRs) %>% dplyr::rename('Symbol' = 'gene_name.x', 'Class' = 'GeneFamily') )

# %%
Res_LRRs_color_Col <- Res_LRRs_color %>% filter(category =='Col-0') %>% arrange(log2FC)

# %%
width_ = 8.1
height_ = 12.5
options(repr.plot.width= width_ , repr.plot.height= height_ , repr.plot.res = 100)

bar_NLRs_plot <- plot_NLRs_overlay_bar(Res = Res_LRRs_color , 
                      Res_base = Res_LRRs_color_Col, 
                      facet_row = "module", alpha = 0.7) + theme( strip.text.y = element_text(angle = 0))  # Make facet labels horizontal)
# Save the final plot to a PDF file
bar_NLRs_plot
bar_NLRs_plot %>% ggsave(file = paste0("./plots/overlap_bar_LRRs", Sys.time(), ".pdf"),
                         width = width_ , height = height_)

# %%
Res_LRRs_color

# %%
Res_LRRs_color %>% group_by(source) %>% summarise(mean_log2FC = mean(log2FC))
